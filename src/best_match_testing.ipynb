# %%
import json
import dotenv
import os
import requests
from constants import *
from graph_constructor import construct_pool_graph, pool_graph_to_dict
from pathfinder import find_shortest_paths, validate_all_paths, create_path_graph, path_graph_to_dict
from path_crawler import calculate_routes, get_final_route

# global routes variable for testing
ROUTES = []

# open pool_dict from data
with open('data/pool_dict.json') as f:
    pool_dict = json.load(f)

DEX_LIST = (
    UNISWAP_V2,
    UNISWAP_V3,
    SUSHISWAP_V2,
    CURVE,
    BALANCER_V1,
    BALANCER_V2,
    DODO,
    PANCAKESWAP_V3
)

DEX_LIQUIDITY_METRIC_MAP = {
    UNISWAP_V2: 'reserveUSD',
    UNISWAP_V3: 'totalValueLockedUSD',
    SUSHISWAP_V2: 'liquidityUSD',
    CURVE: 'reserveUSD',
    BALANCER_V1: 'reserveUSD',
    BALANCER_V2: 'reserveUSD',
    DODO: 'reserveUSD',
    PANCAKESWAP_V3: 'totalValueLockedUSD'
}

# load coinmarketcap api key from .env
dotenv.load_dotenv()
COINMARKETCAP_API_KEY = os.getenv("COINMARKETCAP_API_KEY")

def get_token_price_usd(symbol, convert_to_symbol="USD"):
    url = f"https://pro-api.coinmarketcap.com/v1/tools/price-conversion?amount=1&symbol={symbol}&convert={convert_to_symbol}"
    headers = {
        "Accepts": "application/json",
        "X-CMC_PRO_API_KEY": COINMARKETCAP_API_KEY
    }
    response = requests.get(url, headers=headers)
    response_data = json.loads(response.text)
    return response_data["data"]["quote"][convert_to_symbol]["price"]

def find_max_liquidity(pool_dict, n=10):
    most_liquid_pools = sorted(pool_dict.items(), key=lambda x: float(x[1][DEX_LIQUIDITY_METRIC_MAP[x[1]['protocol']]]), reverse=True)[:n]
    return float(most_liquid_pools[0][1][DEX_LIQUIDITY_METRIC_MAP[most_liquid_pools[0][1]['protocol']]])

def find_max_price(pool_dict, n=10):
    most_expensive_pools = sorted(pool_dict.items(), key=lambda x: max(float(x[1]['token0'].get('priceUSD', 0)), float(x[1]['token1'].get('priceUSD', 0))), reverse=True)[:n]
    return max(float(most_expensive_pools[0][1]['token0'].get('priceUSD', 0)), float(most_expensive_pools[0][1]['token1'].get('priceUSD', 0)))

def calculate_score(pool, trade_value, max_trade_value, max_price, max_liquidity):
    # Normalize the factors
    normalized_price = max(float(pool['token0'].get('priceUSD', 0)), float(pool['token1'].get('priceUSD', 0))) / max_price
    normalized_liquidity = float(pool[DEX_LIQUIDITY_METRIC_MAP[pool['protocol']]]) / max_liquidity

    # Adjust the weights based on the trade value
    w1 = trade_value / max_trade_value  # Liquidity weight increases with trade value
    w2 = 1 - w1  # Price weight decreases with trade value

    # Calculate the score
    score = w1 * normalized_liquidity + w2 * normalized_price

    return score
#              filter_pools(sell_symbol: str, sell_ID: str, buy_symbol: str, buy_ID: str, exchanges=None, X: int = 50) -> list:
def filter_pools_best_match(sell_symbol: str, sell_ID: str, sell_amount: float, exchanges=None, X: int = 20, Y: int = 20):
    global pool_dict
    # Calculate trade value
    avg_sell_token_price_usd = get_token_price_usd(sell_symbol)
    trade_value = sell_amount * avg_sell_token_price_usd
    max_trade_value = 100000000  # Arbitrarily set
    
    # Get max_price and max_liquidity from all pools
    max_price = find_max_price(pool_dict)
    max_liquidity = find_max_liquidity(pool_dict)
    
    pool_scores = []
    for pool in pool_dict.values():
        # Exclude pools whose exchange is not in the exchanges list
        if exchanges is not None and pool['protocol'] not in exchanges:
            continue
        
        # Calculate pool score
        score = calculate_score(pool, trade_value, max_trade_value, max_price, max_liquidity)
        pool_scores.append((pool, score))

    # Sort the pools based on score
    sorted_pool_scores = sorted(pool_scores, key=lambda x: x[1], reverse=True)
    # Get the top X pools by score
    top_X_pools = [pool_score[0] for pool_score in sorted_pool_scores[:X]]
    # Get the top Y pools that contain the sell_token
    top_Y_sell_token_pools = [pool_score[0] for pool_score in sorted_pool_scores if sell_ID in (pool_score[0]['token0']['id'], pool_score[0]['token1']['id'])][:Y]
    # Return a list combining the two sets of pools
    return top_X_pools + top_Y_sell_token_pools

def route_orders(sell_symbol: str, sell_ID: str, sell_amount: float, buy_symbol: str, buy_ID: str, exchanges, split=False, routing_strategy='default') -> dict:
    result = {}
    
    # get the pools
    if routing_strategy == 'best_match':
        filt_pools = filter_pools_best_match(sell_symbol, sell_ID, sell_amount, exchanges=exchanges)
    else:
        filt_pools = filter_pools(sell_symbol, sell_ID, buy_symbol, buy_ID, exchanges=exchanges)
    
    if len(filt_pools) < 5:
        time.sleep(5)
        filter_pools(sell_symbol, sell_ID, buy_symbol, buy_ID, exchanges=DEX_LIST)
    
    # construct the pool graph
    G = construct_pool_graph(filt_pools)
    
    # get the graph dict
    graph_dict = pool_graph_to_dict(G)
    
    # append the dict to the result
    result['pool_graph'] = graph_dict
    
    # find the shortest paths
    paths = find_shortest_paths(G, sell_symbol, buy_symbol)
    
    # validate the paths
    if routing_strategy == 'best_match': # all paths are valid if it doesn't matter what our output token is, any paths that somehow still involve selling a token to a pool not accepted will be filtered out by the price impact calculation anyway
        valid_paths = paths
    else:
        valid_paths = validate_all_paths(G, paths, sell_ID, buy_ID)
    
    # create the path graph
    path_graph = create_path_graph(valid_paths)
    
    # get the path graph dict
    path_graph_dict = path_graph_to_dict(path_graph)
    
    # append the dict to the result
    result['path_graph'] = path_graph_dict
    
    # calculate the routes (traverse the paths and calculate price impact at each swap)
    routes = calculate_routes(G, valid_paths, sell_amount, sell_symbol, buy_symbol)

    # Loop over routes and calculate price_usd and amount_out_usd
    for route_name, route_dict in routes:
        # Get the swap keys
        swap_keys = [key for key in route_dict.keys() if "swap_" in key]

        # Sort the keys by the number following 'swap_'
        swap_keys.sort(key=lambda x: int(x.split('_')[1]))

        # Get the last swap key
        last_swap_key = swap_keys[-1]

        # Get the last swap
        last_swap = route_dict[last_swap_key]

        # Get the output token and pool ID
        output_token = last_swap['output_token']
        pool_id = last_swap['pool']

        # Retrieve the pool information
        pool = G.nodes[pool_id]['pool']  # assuming that the pool data is contained within G

        # Find the price in USD for the output token
        price_usd = None
        if pool['token0']['symbol'] == output_token:
            price_usd = float(pool['token0']['priceUSD'])
        elif pool['token1']['symbol'] == output_token:
            price_usd = float(pool['token1']['priceUSD'])

        # Calculate the amount out in USD
        amount_out_usd = price_usd * float(last_swap['output_amount'])

        # Add these to the route dictionary
        route_dict['price_usd'] = price_usd
        route_dict['amount_out_usd'] = amount_out_usd

    if routing_strategy == 'best_match':
        # Sort the routes by amount_out_usd
        routes.sort(key=lambda x: x[1]['amount_out_usd'], reverse=True)
    
    for route in routes:
        ROUTES.append(route)

    if split:
        final_route = get_final_route(G, routes, sell_amount, sell_symbol)
        result['routes'] = final_route
    else:
        result['routes'] = routes[:MAX_ROUTES]


    return result

# %%
# test best match without splitting
unsplit = route_orders("MKR", "0x9f8f72aa9304c8b593d555f12ef6589cc3a579a2", 100, "USDC", "0xA0b86991c6218b36c1d19D4a2e9Eb0cE3606eB48", ('Uniswap_V2', 'Uniswap_V3', 'Sushiswap_V2', 'Curve', 'DODO', 'PancakeSwap_V3'), split=False, routing_strategy='best_match')
# Out:
# {'actual_return': 60876.154873132706, 'price_impact': 0.006613777546071731, 'buy_symbol': 'USDC', 'description': 'Sell 33.76670726268958 WETH for USDC in Uniswap V3 0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640\n    \nExpected return: 60876.154873132706 USDC\n    \nPrice impact: 0.006613777546071731%\n    '}
# values type:<class 'dict'>
# Sell token not accepted by pool: 0xc486ad2764d55c7dc033487d634195d6e4a6917e
# 0xc486ad2764d55c7dc033487d634195d6e4a6917e
# values type:<class 'str'>
# string indices must be integers
# Sell token not accepted by pool: 0x936198fcac6d8cdec3815f24ba250041f593f6c3
# 0x936198fcac6d8cdec3815f24ba250041f593f6c3
# values type:<class 'str'>
# string indices must be integers
# {'actual_return': 6915.227019309998, 'price_impact': 0.0007512925106589741, 'buy_symbol': 'USDC', 'description': 'Sell 3.835504355303116 WETH for USDC in Uniswap V3 0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640\n    \nExpected return: 6915.227019309998 USDC\n    \nPrice impact: 0.0007512925106589741%\n    '}
# values type:<class 'dict'>
# Sell token not accepted by pool: 0xc486ad2764d55c7dc033487d634195d6e4a6917e
# 0xc486ad2764d55c7dc033487d634195d6e4a6917e
# values type:<class 'str'>
# string indices must be integers
# Sell token not accepted by pool: 0x936198fcac6d8cdec3815f24ba250041f593f6c3
# 0x936198fcac6d8cdec3815f24ba250041f593f6c3
# values type:<class 'str'>
# string indices must be integers
# {'actual_return': 56269.73544251919, 'price_impact': 0.006113321485590184, 'buy_symbol': 'USDC', 'description': 'Sell 31.211468249450604 WETH for USDC in Uniswap V3 0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640\n    \nExpected return: 56269.73544251919 USDC\n    \nPrice impact: 0.006113321485590184%\n    '}
# values type:<class 'dict'>
# Sell token not accepted by pool: 0xc486ad2764d55c7dc033487d634195d6e4a6917e
# 0xc486ad2764d55c7dc033487d634195d6e4a6917e
# values type:<class 'str'>
# string indices must be integers
# Sell token not accepted by pool: 0x936198fcac6d8cdec3815f24ba250041f593f6c3
# 0x936198fcac6d8cdec3815f24ba250041f593f6c3
# values type:<class 'str'>
# string indices must be integers
# {'actual_return': 46209.95631110668, 'price_impact': 0.005020395257748778, 'buy_symbol': 'USDC', 'description': 'Sell 25.631270682474067 WETH for USDC in Uniswap V3 0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640\n    \nExpected return: 46209.95631110668 USDC\n    \nPrice impact: 0.005020395257748778%\n    '}
# values type:<class 'dict'>
# Sell token not accepted by pool: 0xc486ad2764d55c7dc033487d634195d6e4a6917e
# 0xc486ad2764d55c7dc033487d634195d6e4a6917e
# values type:<class 'str'>
# string indices must be integers
# Sell token not accepted by pool: 0x936198fcac6d8cdec3815f24ba250041f593f6c3
# 0x936198fcac6d8cdec3815f24ba250041f593f6c3
# values type:<class 'str'>
# string indices must be integers
# Sell token not accepted by pool: 0xc486ad2764d55c7dc033487d634195d6e4a6917e
# 0xc486ad2764d55c7dc033487d634195d6e4a6917e
# values type:<class 'str'>
# string indices must be integers
# Sell token not accepted by pool: 0x936198fcac6d8cdec3815f24ba250041f593f6c3
# 0x936198fcac6d8cdec3815f24ba250041f593f6c3
# values type:<class 'str'>
# string indices must be integers
# Sell token not accepted by pool: 0xc486ad2764d55c7dc033487d634195d6e4a6917e
# 0xc486ad2764d55c7dc033487d634195d6e4a6917e
# values type:<class 'str'>
# string indices must be integers
# Sell token not accepted by pool: 0x936198fcac6d8cdec3815f24ba250041f593f6c3
# 0x936198fcac6d8cdec3815f24ba250041f593f6c3
# values type:<class 'str'>
# string indices must be integers
# Calculating price impact for DODO pool: 0x86b32fa55943c9af8c12961d8d2ad7040eeb2f2f
#
# {'actual_return': 6265.662239, 'price_impact': 8.788460026387668e-06, 'buy_symbol': 'USDT', 'description': 'Sell 6266.289260541243 USDC for USDT in DODO 0x86b32fa55943c9af8c12961d8d2ad7040eeb2f2f\nExpected return: 6265.662239 USDT\nPrice impact: 8.788460026387668e-06%'}
# values type:<class 'dict'>
# {'actual_return': 6270.187205079514, 'price_impact': 0.0, 'buy_symbol': 'FRAX', 'description': 'Sell 6266.289260541243 USDC for FRAX in Curve 0xdcef968d416a41cdac0ed8702fac8128a64241a2\n    \nExpected return: 6270.187205079514 FRAX\n    \nPrice impact: 0.0%\n    '}
# values type:<class 'dict'>
# {'actual_return': 3.475523723696824, 'price_impact': 0.0006807863146107707, 'buy_symbol': 'WETH', 'description': 'Sell 6266.289260541243 USDC for WETH in Uniswap V3 0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640\n    \nExpected return: 3.475523723696824 WETH\n    \nPrice impact: 0.0006807863146107707%\n    '}
# values type:<class 'dict'>
# {'actual_return': 0.0, 'price_impact': 100.0, 'buy_symbol': 'MKR', 'description': 'Sell 6266.289260541243 USDC for MKR in Uniswap V3 0x936198fcac6d8cdec3815f24ba250041f593f6c3\n    \nExpected return: 0.0 MKR\n    \nPrice impact: 100.0%\n    '}
# values type:<class 'dict'>
# Sell token not accepted by pool: 0xc486ad2764d55c7dc033487d634195d6e4a6917e
# 0xc486ad2764d55c7dc033487d634195d6e4a6917e
# values type:<class 'str'>
# string indices must be integers
# Sell token not accepted by pool: 0x936198fcac6d8cdec3815f24ba250041f593f6c3
# 0x936198fcac6d8cdec3815f24ba250041f593f6c3
# values type:<class 'str'>
# string indices must be integers
# Sell token not accepted by pool: 0xc486ad2764d55c7dc033487d634195d6e4a6917e
# 0xc486ad2764d55c7dc033487d634195d6e4a6917e
# values type:<class 'str'>
# string indices must be integers
# Sell token not accepted by pool: 0x936198fcac6d8cdec3815f24ba250041f593f6c3
# 0x936198fcac6d8cdec3815f24ba250041f593f6c3
# values type:<class 'str'>
# string indices must be integers
# Sell token not accepted by pool: 0xc486ad2764d55c7dc033487d634195d6e4a6917e
# 0xc486ad2764d55c7dc033487d634195d6e4a6917e
# values type:<class 'str'>
# string indices must be integers
# Sell token not accepted by pool: 0x936198fcac6d8cdec3815f24ba250041f593f6c3
# 0x936198fcac6d8cdec3815f24ba250041f593f6c3
# values type:<class 'str'>
# string indices must be integers
# float division by zero
# Sell token not accepted by pool: 0xc486ad2764d55c7dc033487d634195d6e4a6917e
# 0xc486ad2764d55c7dc033487d634195d6e4a6917e
# values type:<class 'str'>
# string indices must be integers
# Sell token not accepted by pool: 0x936198fcac6d8cdec3815f24ba250041f593f6c3
# 0x936198fcac6d8cdec3815f24ba250041f593f6c3
# values type:<class 'str'>
# string indices must be integers
# Sell token not accepted by pool: 0xc486ad2764d55c7dc033487d634195d6e4a6917e
# 0xc486ad2764d55c7dc033487d634195d6e4a6917e
# values type:<class 'str'>
# string indices must be integers
# Sell token not accepted by pool: 0x936198fcac6d8cdec3815f24ba250041f593f6c3
# 0x936198fcac6d8cdec3815f24ba250041f593f6c3
# values type:<class 'str'>
# string indices must be integers
# Calculating price impact for DODO pool: 0x86b32fa55943c9af8c12961d8d2ad7040eeb2f2f
# ValueError float division by zero: 0x86b32fa55943c9af8c12961d8d2ad7040eeb2f2f
#
# {'actual_return': 0, 'price_impact': inf, 'buy_symbol': 'USDT', 'description': 'pool 0x86b32fa55943c9af8c12961d8d2ad7040eeb2f2f is not active'}
# values type:<class 'dict'>
# float division by zero
# float division by zero
# float division by zero
# {'actual_return': 60876.154873132706, 'price_impact': 0.006613777546071731, 'buy_symbol': 'USDC', 'description': 'Sell 33.76670726268958 WETH for USDC in Uniswap V3 0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640\n    \nExpected return: 60876.154873132706 USDC\n    \nPrice impact: 0.006613777546071731%\n    '}
# values type:<class 'dict'>
# Calculating price impact for DODO pool: 0x86b32fa55943c9af8c12961d8d2ad7040eeb2f2f
#
# {'actual_return': 60870.03019, 'price_impact': 6.341866246595274e-05, 'buy_symbol': 'USDT', 'description': 'Sell 60876.154873132706 USDC for USDT in DODO 0x86b32fa55943c9af8c12961d8d2ad7040eeb2f2f\nExpected return: 60870.03019 USDT\nPrice impact: 6.341866246595274e-05%'}
# values type:<class 'dict'>
# {'actual_return': 60876.154873132706, 'price_impact': 0.006613777546071731, 'buy_symbol': 'USDC', 'description': 'Sell 33.76670726268958 WETH for USDC in Uniswap V3 0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640\n    \nExpected return: 60876.154873132706 USDC\n    \nPrice impact: 0.006613777546071731%\n    '}
# values type:<class 'dict'>
# {'actual_return': 60914.022878507574, 'price_impact': 0.0, 'buy_symbol': 'FRAX', 'description': 'Sell 60876.154873132706 USDC for FRAX in Curve 0xdcef968d416a41cdac0ed8702fac8128a64241a2\n    \nExpected return: 60914.022878507574 FRAX\n    \nPrice impact: 0.0%\n    '}
# values type:<class 'dict'>
# {'actual_return': 6915.227019309998, 'price_impact': 0.0007512925106589741, 'buy_symbol': 'USDC', 'description': 'Sell 3.835504355303116 WETH for USDC in Uniswap V3 0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640\n    \nExpected return: 6915.227019309998 USDC\n    \nPrice impact: 0.0007512925106589741%\n    '}
# values type:<class 'dict'>
# Calculating price impact for DODO pool: 0x86b32fa55943c9af8c12961d8d2ad7040eeb2f2f
#
# {'actual_return': 6914.535018, 'price_impact': 9.444087534227208e-06, 'buy_symbol': 'USDT', 'description': 'Sell 6915.227019309998 USDC for USDT in DODO 0x86b32fa55943c9af8c12961d8d2ad7040eeb2f2f\nExpected return: 6914.535018 USDT\nPrice impact: 9.444087534227208e-06%'}
# values type:<class 'dict'>
# {'actual_return': 6915.227019309998, 'price_impact': 0.0007512925106589741, 'buy_symbol': 'USDC', 'description': 'Sell 3.835504355303116 WETH for USDC in Uniswap V3 0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640\n    \nExpected return: 6915.227019309998 USDC\n    \nPrice impact: 0.0007512925106589741%\n    '}
# values type:<class 'dict'>
# {'actual_return': 6919.528635509007, 'price_impact': 0.0, 'buy_symbol': 'FRAX', 'description': 'Sell 6915.227019309998 USDC for FRAX in Curve 0xdcef968d416a41cdac0ed8702fac8128a64241a2\n    \nExpected return: 6919.528635509007 FRAX\n    \nPrice impact: 0.0%\n    '}
# values type:<class 'dict'>
# {'actual_return': 56269.73544251919, 'price_impact': 0.006113321485590184, 'buy_symbol': 'USDC', 'description': 'Sell 31.211468249450604 WETH for USDC in Uniswap V3 0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640\n    \nExpected return: 56269.73544251919 USDC\n    \nPrice impact: 0.006113321485590184%\n    '}
# values type:<class 'dict'>
# Calculating price impact for DODO pool: 0x86b32fa55943c9af8c12961d8d2ad7040eeb2f2f
#
# {'actual_return': 56264.076797, 'price_impact': 5.881393315698702e-05, 'buy_symbol': 'USDT', 'description': 'Sell 56269.73544251919 USDC for USDT in DODO 0x86b32fa55943c9af8c12961d8d2ad7040eeb2f2f\nExpected return: 56264.076797 USDT\nPrice impact: 5.881393315698702e-05%'}
# values type:<class 'dict'>
# {'actual_return': 56269.73544251919, 'price_impact': 0.006113321485590184, 'buy_symbol': 'USDC', 'description': 'Sell 31.211468249450604 WETH for USDC in Uniswap V3 0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640\n    \nExpected return: 56269.73544251919 USDC\n    \nPrice impact: 0.006113321485590184%\n    '}
# values type:<class 'dict'>
# {'actual_return': 56304.73802519906, 'price_impact': 0.0, 'buy_symbol': 'FRAX', 'description': 'Sell 56269.73544251919 USDC for FRAX in Curve 0xdcef968d416a41cdac0ed8702fac8128a64241a2\n    \nExpected return: 56304.73802519906 FRAX\n    \nPrice impact: 0.0%\n    '}
# values type:<class 'dict'>
# {'actual_return': 46209.95631110668, 'price_impact': 0.005020395257748778, 'buy_symbol': 'USDC', 'description': 'Sell 25.631270682474067 WETH for USDC in Uniswap V3 0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640\n    \nExpected return: 46209.95631110668 USDC\n    \nPrice impact: 0.005020395257748778%\n    '}
# values type:<class 'dict'>
# Calculating price impact for DODO pool: 0x86b32fa55943c9af8c12961d8d2ad7040eeb2f2f
#
# {'actual_return': 46205.313956, 'price_impact': 4.8749611725185105e-05, 'buy_symbol': 'USDT', 'description': 'Sell 46209.95631110668 USDC for USDT in DODO 0x86b32fa55943c9af8c12961d8d2ad7040eeb2f2f\nExpected return: 46205.313956 USDT\nPrice impact: 4.8749611725185105e-05%'}
# values type:<class 'dict'>
# {'actual_return': 46209.95631110668, 'price_impact': 0.005020395257748778, 'buy_symbol': 'USDC', 'description': 'Sell 25.631270682474067 WETH for USDC in Uniswap V3 0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640\n    \nExpected return: 46209.95631110668 USDC\n    \nPrice impact: 0.005020395257748778%\n    '}
# values type:<class 'dict'>
# {'actual_return': 46238.70120929561, 'price_impact': 0.0, 'buy_symbol': 'FRAX', 'description': 'Sell 46209.95631110668 USDC for FRAX in Curve 0xdcef968d416a41cdac0ed8702fac8128a64241a2\n    \nExpected return: 46238.70120929561 FRAX\n    \nPrice impact: 0.0%\n    '}
# values type:<class 'dict'>
# Sell token not accepted by pool: 0xc486ad2764d55c7dc033487d634195d6e4a6917e
# 0xc486ad2764d55c7dc033487d634195d6e4a6917e
# values type:<class 'str'>
# string indices must be integers
# Sell token not accepted by pool: 0xc486ad2764d55c7dc033487d634195d6e4a6917e
# 0xc486ad2764d55c7dc033487d634195d6e4a6917e
# values type:<class 'str'>
# string indices must be integers
# Sell token not accepted by pool: 0xe8c6c9227491c0a8156a0106a0204d881bb7e531
# 0xe8c6c9227491c0a8156a0106a0204d881bb7e531
# values type:<class 'str'>
# string indices must be integers
# Sell token not accepted by pool: 0xc486ad2764d55c7dc033487d634195d6e4a6917e
# 0xc486ad2764d55c7dc033487d634195d6e4a6917e
# values type:<class 'str'>
# string indices must be integers
# Sell token not accepted by pool: 0xc486ad2764d55c7dc033487d634195d6e4a6917e
# 0xc486ad2764d55c7dc033487d634195d6e4a6917e
# values type:<class 'str'>
# string indices must be integers
# Sell token not accepted by pool: 0xe8c6c9227491c0a8156a0106a0204d881bb7e531
# 0xe8c6c9227491c0a8156a0106a0204d881bb7e531
# values type:<class 'str'>
# string indices must be integers
# Sell token not accepted by pool: 0xc486ad2764d55c7dc033487d634195d6e4a6917e
# 0xc486ad2764d55c7dc033487d634195d6e4a6917e
# values type:<class 'str'>
# string indices must be integers
# Sell token not accepted by pool: 0xc486ad2764d55c7dc033487d634195d6e4a6917e
# 0xc486ad2764d55c7dc033487d634195d6e4a6917e
# values type:<class 'str'>
# string indices must be integers
# Sell token not accepted by pool: 0xe8c6c9227491c0a8156a0106a0204d881bb7e531
# 0xe8c6c9227491c0a8156a0106a0204d881bb7e531
# values type:<class 'str'>
# string indices must be integers
# Sell token not accepted by pool: 0xc486ad2764d55c7dc033487d634195d6e4a6917e
# 0xc486ad2764d55c7dc033487d634195d6e4a6917e
# values type:<class 'str'>
# string indices must be integers
# Sell token not accepted by pool: 0xc486ad2764d55c7dc033487d634195d6e4a6917e
# 0xc486ad2764d55c7dc033487d634195d6e4a6917e
# values type:<class 'str'>
# string indices must be integers
# Sell token not accepted by pool: 0xe8c6c9227491c0a8156a0106a0204d881bb7e531
# 0xe8c6c9227491c0a8156a0106a0204d881bb7e531
# values type:<class 'str'>
# string indices must be integers
# Sell token not accepted by pool: 0xc486ad2764d55c7dc033487d634195d6e4a6917e
# 0xc486ad2764d55c7dc033487d634195d6e4a6917e
# values type:<class 'str'>
# string indices must be integers
# Sell token not accepted by pool: 0xc486ad2764d55c7dc033487d634195d6e4a6917e
# 0xc486ad2764d55c7dc033487d634195d6e4a6917e
# values type:<class 'str'>
# string indices must be integers
# Sell token not accepted by pool: 0xe8c6c9227491c0a8156a0106a0204d881bb7e531
# 0xe8c6c9227491c0a8156a0106a0204d881bb7e531
# values type:<class 'str'>
# string indices must be integers
# float division by zero
# float division by zero
# Sell token not accepted by pool: 0xc486ad2764d55c7dc033487d634195d6e4a6917e
# 0xc486ad2764d55c7dc033487d634195d6e4a6917e
# values type:<class 'str'>
# string indices must be integers
# Sell token not accepted by pool: 0xc486ad2764d55c7dc033487d634195d6e4a6917e
# 0xc486ad2764d55c7dc033487d634195d6e4a6917e
# values type:<class 'str'>
# string indices must be integers
# Sell token not accepted by pool: 0xe8c6c9227491c0a8156a0106a0204d881bb7e531
# 0xe8c6c9227491c0a8156a0106a0204d881bb7e531
# values type:<class 'str'>
# string indices must be integers

# %%
ROUTES
# Out:
# [('route_11',
#   {'swap_0': {'pool': 'MKR_WETH_0xe8c6c9227491c0a8156a0106a0204d881bb7e531',
#     'exchange': 'Uniswap_V3',
#     'dangerous': False,
#     'input_token': 'MKR',
#     'input_amount': 100,
#     'input_amount_usd': 254650.06950639523,
#     'output_token': 'WETH',
#     'output_amount': 33.76670726268958,
#     'output_amount_usd': 248575.01003307817,
#     'price_impact': 2.3856500353966914,
#     'price': 2.9614969331195256,
#     'price_usd': 55516725.062558204,
#     'gas_fee': 0.000596348743473,
#     'description': 'Sell 100 MKR for WETH in Uniswap V3 0xe8c6c9227491c0a8156a0106a0204d881bb7e531\n    \nExpected return: 33.76670726268958 WETH\n    \nPrice impact: 2.3856500353966914%\n    '},
#    'swap_1': {'pool': 'USDC_WETH_0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640',
#     'exchange': 'Uniswap_V3',
#     'dangerous': False,
#     'input_token': 'WETH',
#     'input_amount': 33.76670726268958,
#     'input_amount_usd': 28490.449600939042,
#     'output_token': 'USDC',
#     'output_amount': 60876.154873132706,
#     'output_amount_usd': 28488.565305980563,
#     'price_impact': 0.006613777546071731,
#     'price': 0.0005546787134151322,
#     'price_usd': 0.21901580428950115,
#     'gas_fee': 0.000596348743473,
#     'description': 'Sell 33.76670726268958 WETH for USDC in Uniswap V3 0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640\n    \nExpected return: 60876.154873132706 USDC\n    \nPrice impact: 0.006613777546071731%\n    '},
#    'swap_2': {'pool': 'USDT_USDC_0x86b32fa55943c9af8c12961d8d2ad7040eeb2f2f',
#     'exchange': 'DODO',
#     'dangerous': False,
#     'input_token': 'USDC',
#     'input_amount': 60876.154873132706,
#     'input_amount_usd': 60871.42009064679,
#     'output_token': 'USDT',
#     'output_amount': 60870.03019,
#     'output_amount_usd': 60875.59445152921,
#     'price_impact': 6.341866246595274e-05,
#     'price': 1.000100619025711,
#     'price_usd': 1.0001142481646244,
#     'gas_fee': 0.000596348743473,
#     'description': 'Sell 60876.154873132706 USDC for USDT in DODO 0x86b32fa55943c9af8c12961d8d2ad7040eeb2f2f\nExpected return: 60870.03019 USDT\nPrice impact: 6.341866246595274e-05%'},
#    'amount_in': 100,
#    'amount_in_usd': 736154.1298631163,
#    'amount_out': 60870.03019,
#    'amount_out_usd': 60875.59445152921,
#    'price': 0.0016428445934371897,
#    'price_usd': 1.0000914121696973,
#    'gas_fee': 0.001789046230419,
#    'path': ['MKR_WETH_0xe8c6c9227491c0a8156a0106a0204d881bb7e531',
#     'USDC_WETH_0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640',
#     'USDT_USDC_0x86b32fa55943c9af8c12961d8d2ad7040eeb2f2f'],
#    'price_impact': 2.392327231605229}),
#  ('route_12',
#   {'swap_0': {'pool': 'MKR_WETH_0xe8c6c9227491c0a8156a0106a0204d881bb7e531',
#     'exchange': 'Uniswap_V3',
#     'dangerous': False,
#     'input_token': 'MKR',
#     'input_amount': 100,
#     'input_amount_usd': 254650.06950639523,
#     'output_token': 'WETH',
#     'output_amount': 33.76670726268958,
#     'output_amount_usd': 248575.01003307817,
#     'price_impact': 2.3856500353966914,
#     'price': 2.9614969331195256,
#     'price_usd': 55516725.062558204,
#     'gas_fee': 0.000596348743473,
#     'description': 'Sell 100 MKR for WETH in Uniswap V3 0xe8c6c9227491c0a8156a0106a0204d881bb7e531\n    \nExpected return: 33.76670726268958 WETH\n    \nPrice impact: 2.3856500353966914%\n    '},
#    'swap_1': {'pool': 'USDC_WETH_0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640',
#     'exchange': 'Uniswap_V3',
#     'dangerous': False,
#     'input_token': 'WETH',
#     'input_amount': 33.76670726268958,
#     'input_amount_usd': 28490.449600939042,
#     'output_token': 'USDC',
#     'output_amount': 60876.154873132706,
#     'output_amount_usd': 28488.565305980563,
#     'price_impact': 0.006613777546071731,
#     'price': 0.0005546787134151322,
#     'price_usd': 0.21901580428950115,
#     'gas_fee': 0.000596348743473,
#     'description': 'Sell 33.76670726268958 WETH for USDC in Uniswap V3 0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640\n    \nExpected return: 60876.154873132706 USDC\n    \nPrice impact: 0.006613777546071731%\n    '},
#    'swap_2': {'pool': 'FRAX_USDC_0xdcef968d416a41cdac0ed8702fac8128a64241a2',
#     'exchange': 'Curve',
#     'dangerous': False,
#     'input_token': 'USDC',
#     'input_amount': 60876.154873132706,
#     'input_amount_usd': 60863.37088060934,
#     'output_token': 'FRAX',
#     'output_amount': 60914.022878507574,
#     'output_amount_usd': 60863.37088060934,
#     'price_impact': 0.0,
#     'price': 0.9993783368166244,
#     'price_usd': 0.9983376261783072,
#     'gas_fee': 0.000596348743473,
#     'description': 'Sell 60876.154873132706 USDC for FRAX in Curve 0xdcef968d416a41cdac0ed8702fac8128a64241a2\n    \nExpected return: 60914.022878507574 FRAX\n    \nPrice impact: 0.0%\n    '},
#    'amount_in': 100,
#    'amount_in_usd': 736154.1298631163,
#    'amount_out': 60914.022878507574,
#    'amount_out_usd': 60863.37088060934,
#    'price': 0.0016416581153973204,
#    'price_usd': 0.9991684673658928,
#    'gas_fee': 0.001789046230419,
#    'path': ['MKR_WETH_0xe8c6c9227491c0a8156a0106a0204d881bb7e531',
#     'USDC_WETH_0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640',
#     'FRAX_USDC_0xdcef968d416a41cdac0ed8702fac8128a64241a2'],
#    'price_impact': 2.392263812942763}),
#  ('route_15',
#   {'swap_0': {'pool': 'MKR_WETH_0xc2adda861f89bbb333c90c492cb837741916a225',
#     'exchange': 'Uniswap_V2',
#     'dangerous': False,
#     'input_token': 'MKR',
#     'input_amount': 100,
#     'input_amount_usd': 124912.27311461946,
#     'output_token': 'WETH',
#     'output_amount': 31.211468249450604,
#     'output_amount_usd': 113131.55601745826,
#     'price_impact': 9.431192630968477,
#     'price': 3.2039505223135487,
#     'price_usd': 14506427.559431907,
#     'gas_fee': 0.000596348743473,
#     'description': 'Sell 100 MKR for WETH in Uniswap V2 0xc2adda861f89bbb333c90c492cb837741916a225\n    \nExpected return: 31.211468249450604 WETH\n    \nPrice impact: 9.431192630968477%\n    '},
#    'swap_1': {'pool': 'USDC_WETH_0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640',
#     'exchange': 'Uniswap_V3',
#     'dangerous': False,
#     'input_token': 'WETH',
#     'input_amount': 31.211468249450604,
#     'input_amount_usd': 26334.48254857921,
#     'output_token': 'USDC',
#     'output_amount': 56269.73544251919,
#     'output_amount_usd': 26332.872636999447,
#     'price_impact': 0.006113321485590184,
#     'price': 0.0005546759373221832,
#     'price_usd': 0.21901470814462431,
#     'gas_fee': 0.000596348743473,
#     'description': 'Sell 31.211468249450604 WETH for USDC in Uniswap V3 0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640\n    \nExpected return: 56269.73544251919 USDC\n    \nPrice impact: 0.006113321485590184%\n    '},
#    'swap_2': {'pool': 'USDT_USDC_0x86b32fa55943c9af8c12961d8d2ad7040eeb2f2f',
#     'exchange': 'DODO',
#     'dangerous': False,
#     'input_token': 'USDC',
#     'input_amount': 56269.73544251919,
#     'input_amount_usd': 56265.35893486335,
#     'output_token': 'USDT',
#     'output_amount': 56264.076797,
#     'output_amount_usd': 56269.22001833603,
#     'price_impact': 5.881393315698702e-05,
#     'price': 1.0001005729737573,
#     'price_usd': 1.0001142021120433,
#     'gas_fee': 0.000596348743473,
#     'description': 'Sell 56269.73544251919 USDC for USDT in DODO 0x86b32fa55943c9af8c12961d8d2ad7040eeb2f2f\nExpected return: 56264.076797 USDT\nPrice impact: 5.881393315698702e-05%'},
#    'amount_in': 100,
#    'amount_in_usd': 362467.90799227986,
#    'amount_out': 56264.076797,
#    'amount_out_usd': 56269.22001833603,
#    'price': 0.001777332992786829,
#    'price_usd': 1.0000914121696973,
#    'gas_fee': 0.001789046230419,
#    'path': ['MKR_WETH_0xc2adda861f89bbb333c90c492cb837741916a225',
#     'USDC_WETH_0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640',
#     'USDT_USDC_0x86b32fa55943c9af8c12961d8d2ad7040eeb2f2f'],
#    'price_impact': 9.437364766387224}),
#  ('route_16',
#   {'swap_0': {'pool': 'MKR_WETH_0xc2adda861f89bbb333c90c492cb837741916a225',
#     'exchange': 'Uniswap_V2',
#     'dangerous': False,
#     'input_token': 'MKR',
#     'input_amount': 100,
#     'input_amount_usd': 124912.27311461946,
#     'output_token': 'WETH',
#     'output_amount': 31.211468249450604,
#     'output_amount_usd': 113131.55601745826,
#     'price_impact': 9.431192630968477,
#     'price': 3.2039505223135487,
#     'price_usd': 14506427.559431907,
#     'gas_fee': 0.000596348743473,
#     'description': 'Sell 100 MKR for WETH in Uniswap V2 0xc2adda861f89bbb333c90c492cb837741916a225\n    \nExpected return: 31.211468249450604 WETH\n    \nPrice impact: 9.431192630968477%\n    '},
#    'swap_1': {'pool': 'USDC_WETH_0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640',
#     'exchange': 'Uniswap_V3',
#     'dangerous': False,
#     'input_token': 'WETH',
#     'input_amount': 31.211468249450604,
#     'input_amount_usd': 26334.48254857921,
#     'output_token': 'USDC',
#     'output_amount': 56269.73544251919,
#     'output_amount_usd': 26332.872636999447,
#     'price_impact': 0.006113321485590184,
#     'price': 0.0005546759373221832,
#     'price_usd': 0.21901470814462431,
#     'gas_fee': 0.000596348743473,
#     'description': 'Sell 31.211468249450604 WETH for USDC in Uniswap V3 0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640\n    \nExpected return: 56269.73544251919 USDC\n    \nPrice impact: 0.006113321485590184%\n    '},
#    'swap_2': {'pool': 'FRAX_USDC_0xdcef968d416a41cdac0ed8702fac8128a64241a2',
#     'exchange': 'Curve',
#     'dangerous': False,
#     'input_token': 'USDC',
#     'input_amount': 56269.73544251919,
#     'input_amount_usd': 56257.91879807626,
#     'output_token': 'FRAX',
#     'output_amount': 56304.73802519906,
#     'output_amount_usd': 56257.91879807625,
#     'price_impact': 0.0,
#     'price': 0.9993783368166244,
#     'price_usd': 0.9983376261783073,
#     'gas_fee': 0.000596348743473,
#     'description': 'Sell 56269.73544251919 USDC for FRAX in Curve 0xdcef968d416a41cdac0ed8702fac8128a64241a2\n    \nExpected return: 56304.73802519906 FRAX\n    \nPrice impact: 0.0%\n    '},
#    'amount_in': 100,
#    'amount_in_usd': 362467.90799227986,
#    'amount_out': 56304.73802519906,
#    'amount_out_usd': 56257.91879807625,
#    'price': 0.0017760494677241056,
#    'price_usd': 0.9991684673658928,
#    'gas_fee': 0.001789046230419,
#    'path': ['MKR_WETH_0xc2adda861f89bbb333c90c492cb837741916a225',
#     'USDC_WETH_0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640',
#     'FRAX_USDC_0xdcef968d416a41cdac0ed8702fac8128a64241a2'],
#    'price_impact': 9.437305952454068}),
#  ('route_0',
#   {'swap_0': {'pool': 'MKR_USDC_0xc486ad2764d55c7dc033487d634195d6e4a6917e',
#     'exchange': 'Uniswap_V3',
#     'dangerous': False,
#     'input_token': 'MKR',
#     'input_amount': 100,
#     'input_amount_usd': 558187.1363728422,
#     'output_token': 'USDC',
#     'output_amount': 6266.289260541243,
#     'output_amount_usd': 55877.37296753924,
#     'price_impact': 89.9894910995914,
#     'price': 0.01595840789375922,
#     'price_usd': 794.3189551366643,
#     'gas_fee': 0.000596348743473,
#     'description': 'Sell 100 MKR for USDC in Uniswap V3 0xc486ad2764d55c7dc033487d634195d6e4a6917e\n    \nExpected return: 6266.289260541243 USDC\n    \nPrice impact: 89.9894910995914%\n    '},
#    'amount_in': 100,
#    'amount_in_usd': 558187.1363728422,
#    'amount_out': 6266.289260541243,
#    'amount_out_usd': 55877.37296753924,
#    'price': 0.01595840789375922,
#    'price_usd': 8.917139098477064,
#    'gas_fee': 0.000596348743473,
#    'path': ['MKR_USDC_0xc486ad2764d55c7dc033487d634195d6e4a6917e'],
#    'price_impact': 89.9894910995914}),
#  ('route_17',
#   {'swap_0': {'pool': 'MKR_WETH_0xba13afecda9beb75de5c56bbaf696b880a5a50dd',
#     'exchange': 'Sushiswap_V2',
#     'dangerous': False,
#     'input_token': 'MKR',
#     'input_amount': 100,
#     'input_amount_usd': 1.2549986654281113e-13,
#     'output_token': 'WETH',
#     'output_amount': 25.631270682474067,
#     'output_amount_usd': 9.270470955933966e-14,
#     'price_impact': 26.13162697849104,
#     'price': 3.901484293885482,
#     'price_usd': 1.7709438332674908e-29,
#     'gas_fee': 0.000596348743473,
#     'description': 'Sell 100 MKR for WETH in Sushiswap V2 0xba13afecda9beb75de5c56bbaf696b880a5a50dd\n    \nExpected return: 25.631270682474067 WETH\n    \nPrice impact: 26.13162697849104%\n    '},
#    'swap_1': {'pool': 'USDC_WETH_0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640',
#     'exchange': 'Uniswap_V3',
#     'dangerous': False,
#     'input_token': 'WETH',
#     'input_amount': 25.631270682474067,
#     'input_amount_usd': 21626.22549797556,
#     'output_token': 'USDC',
#     'output_amount': 46209.95631110668,
#     'output_amount_usd': 21625.13977597623,
#     'price_impact': 0.005020395257748778,
#     'price': 0.000554669874819023,
#     'price_usd': 0.21901231435525848,
#     'gas_fee': 0.000596348743473,
#     'description': 'Sell 25.631270682474067 WETH for USDC in Uniswap V3 0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640\n    \nExpected return: 46209.95631110668 USDC\n    \nPrice impact: 0.005020395257748778%\n    '},
#    'swap_2': {'pool': 'USDT_USDC_0x86b32fa55943c9af8c12961d8d2ad7040eeb2f2f',
#     'exchange': 'DODO',
#     'dangerous': False,
#     'input_token': 'USDC',
#     'input_amount': 46209.95631110668,
#     'input_amount_usd': 46206.362225831865,
#     'output_token': 'USDT',
#     'output_amount': 46205.313956,
#     'output_amount_usd': 46209.537684000265,
#     'price_impact': 4.8749611725185105e-05,
#     'price': 1.0001004723203721,
#     'price_usd': 1.0001141014572863,
#     'gas_fee': 0.000596348743473,
#     'description': 'Sell 46209.95631110668 USDC for USDT in DODO 0x86b32fa55943c9af8c12961d8d2ad7040eeb2f2f\nExpected return: 46205.313956 USDT\nPrice impact: 4.8749611725185105e-05%'},
#    'amount_in': 100,
#    'amount_in_usd': 3.61685968314979e-13,
#    'amount_out': 46205.313956,
#    'amount_out_usd': 46209.537684000265,
#    'price': 0.0021642532305965315,
#    'price_usd': 1.0000914121696973,
#    'gas_fee': 0.001789046230419,
#    'path': ['MKR_WETH_0xba13afecda9beb75de5c56bbaf696b880a5a50dd',
#     'USDC_WETH_0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640',
#     'USDT_USDC_0x86b32fa55943c9af8c12961d8d2ad7040eeb2f2f'],
#    'price_impact': 26.136696123360515}),
#  ('route_18',
#   {'swap_0': {'pool': 'MKR_WETH_0xba13afecda9beb75de5c56bbaf696b880a5a50dd',
#     'exchange': 'Sushiswap_V2',
#     'dangerous': False,
#     'input_token': 'MKR',
#     'input_amount': 100,
#     'input_amount_usd': 1.2549986654281113e-13,
#     'output_token': 'WETH',
#     'output_amount': 25.631270682474067,
#     'output_amount_usd': 9.270470955933966e-14,
#     'price_impact': 26.13162697849104,
#     'price': 3.901484293885482,
#     'price_usd': 1.7709438332674908e-29,
#     'gas_fee': 0.000596348743473,
#     'description': 'Sell 100 MKR for WETH in Sushiswap V2 0xba13afecda9beb75de5c56bbaf696b880a5a50dd\n    \nExpected return: 25.631270682474067 WETH\n    \nPrice impact: 26.13162697849104%\n    '},
#    'swap_1': {'pool': 'USDC_WETH_0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640',
#     'exchange': 'Uniswap_V3',
#     'dangerous': False,
#     'input_token': 'WETH',
#     'input_amount': 25.631270682474067,
#     'input_amount_usd': 21626.22549797556,
#     'output_token': 'USDC',
#     'output_amount': 46209.95631110668,
#     'output_amount_usd': 21625.13977597623,
#     'price_impact': 0.005020395257748778,
#     'price': 0.000554669874819023,
#     'price_usd': 0.21901231435525848,
#     'gas_fee': 0.000596348743473,
#     'description': 'Sell 25.631270682474067 WETH for USDC in Uniswap V3 0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640\n    \nExpected return: 46209.95631110668 USDC\n    \nPrice impact: 0.005020395257748778%\n    '},
#    'swap_2': {'pool': 'FRAX_USDC_0xdcef968d416a41cdac0ed8702fac8128a64241a2',
#     'exchange': 'Curve',
#     'dangerous': False,
#     'input_token': 'USDC',
#     'input_amount': 46209.95631110668,
#     'input_amount_usd': 46200.25222028135,
#     'output_token': 'FRAX',
#     'output_amount': 46238.70120929561,
#     'output_amount_usd': 46200.25222028135,
#     'price_impact': 0.0,
#     'price': 0.9993783368166244,
#     'price_usd': 0.9983376261783073,
#     'gas_fee': 0.000596348743473,
#     'description': 'Sell 46209.95631110668 USDC for FRAX in Curve 0xdcef968d416a41cdac0ed8702fac8128a64241a2\n    \nExpected return: 46238.70120929561 FRAX\n    \nPrice impact: 0.0%\n    '},
#    'amount_in': 100,
#    'amount_in_usd': 3.61685968314979e-13,
#    'amount_out': 46238.70120929561,
#    'amount_out_usd': 46200.25222028135,
#    'price': 0.0021626905035104335,
#    'price_usd': 0.9991684673658928,
#    'gas_fee': 0.001789046230419,
#    'path': ['MKR_WETH_0xba13afecda9beb75de5c56bbaf696b880a5a50dd',
#     'USDC_WETH_0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640',
#     'FRAX_USDC_0xdcef968d416a41cdac0ed8702fac8128a64241a2'],
#    'price_impact': 26.13664737374879}),
#  ('route_2',
#   {'swap_0': {'pool': 'MKR_WETH_0xe8c6c9227491c0a8156a0106a0204d881bb7e531',
#     'exchange': 'Uniswap_V3',
#     'dangerous': False,
#     'input_token': 'MKR',
#     'input_amount': 100,
#     'input_amount_usd': 254650.06950639523,
#     'output_token': 'WETH',
#     'output_amount': 33.76670726268958,
#     'output_amount_usd': 248575.01003307817,
#     'price_impact': 2.3856500353966914,
#     'price': 2.9614969331195256,
#     'price_usd': 55516725.062558204,
#     'gas_fee': 0.000596348743473,
#     'description': 'Sell 100 MKR for WETH in Uniswap V3 0xe8c6c9227491c0a8156a0106a0204d881bb7e531\n    \nExpected return: 33.76670726268958 WETH\n    \nPrice impact: 2.3856500353966914%\n    '},
#    'swap_1': {'pool': 'USDC_WETH_0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640',
#     'exchange': 'Uniswap_V3',
#     'dangerous': False,
#     'input_token': 'WETH',
#     'input_amount': 33.76670726268958,
#     'input_amount_usd': 28490.449600939042,
#     'output_token': 'USDC',
#     'output_amount': 60876.154873132706,
#     'output_amount_usd': 28488.565305980563,
#     'price_impact': 0.006613777546071731,
#     'price': 0.0005546787134151322,
#     'price_usd': 0.21901580428950115,
#     'gas_fee': 0.000596348743473,
#     'description': 'Sell 33.76670726268958 WETH for USDC in Uniswap V3 0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640\n    \nExpected return: 60876.154873132706 USDC\n    \nPrice impact: 0.006613777546071731%\n    '},
#    'amount_in': 100,
#    'amount_in_usd': 736154.1298631163,
#    'amount_out': 60876.154873132706,
#    'amount_out_usd': 28488.565305980563,
#    'price': 0.0016426793086455982,
#    'price_usd': 0.46797576761133125,
#    'gas_fee': 0.001192697486946,
#    'path': ['MKR_WETH_0xe8c6c9227491c0a8156a0106a0204d881bb7e531',
#     'USDC_WETH_0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640'],
#    'price_impact': 2.392263812942763}),
#  ('route_4',
#   {'swap_0': {'pool': 'MKR_WETH_0xc2adda861f89bbb333c90c492cb837741916a225',
#     'exchange': 'Uniswap_V2',
#     'dangerous': False,
#     'input_token': 'MKR',
#     'input_amount': 100,
#     'input_amount_usd': 124912.27311461946,
#     'output_token': 'WETH',
#     'output_amount': 31.211468249450604,
#     'output_amount_usd': 113131.55601745826,
#     'price_impact': 9.431192630968477,
#     'price': 3.2039505223135487,
#     'price_usd': 14506427.559431907,
#     'gas_fee': 0.000596348743473,
#     'description': 'Sell 100 MKR for WETH in Uniswap V2 0xc2adda861f89bbb333c90c492cb837741916a225\n    \nExpected return: 31.211468249450604 WETH\n    \nPrice impact: 9.431192630968477%\n    '},
#    'swap_1': {'pool': 'USDC_WETH_0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640',
#     'exchange': 'Uniswap_V3',
#     'dangerous': False,
#     'input_token': 'WETH',
#     'input_amount': 31.211468249450604,
#     'input_amount_usd': 26334.48254857921,
#     'output_token': 'USDC',
#     'output_amount': 56269.73544251919,
#     'output_amount_usd': 26332.872636999447,
#     'price_impact': 0.006113321485590184,
#     'price': 0.0005546759373221832,
#     'price_usd': 0.21901470814462431,
#     'gas_fee': 0.000596348743473,
#     'description': 'Sell 31.211468249450604 WETH for USDC in Uniswap V3 0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640\n    \nExpected return: 56269.73544251919 USDC\n    \nPrice impact: 0.006113321485590184%\n    '},
#    'amount_in': 100,
#    'amount_in_usd': 362467.90799227986,
#    'amount_out': 56269.73544251919,
#    'amount_out_usd': 26332.872636999447,
#    'price': 0.001777154259098166,
#    'price_usd': 0.46797576761133125,
#    'gas_fee': 0.001192697486946,
#    'path': ['MKR_WETH_0xc2adda861f89bbb333c90c492cb837741916a225',
#     'USDC_WETH_0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640'],
#    'price_impact': 9.437305952454068}),
#  ('route_5',
#   {'swap_0': {'pool': 'MKR_WETH_0xba13afecda9beb75de5c56bbaf696b880a5a50dd',
#     'exchange': 'Sushiswap_V2',
#     'dangerous': False,
#     'input_token': 'MKR',
#     'input_amount': 100,
#     'input_amount_usd': 1.2549986654281113e-13,
#     'output_token': 'WETH',
#     'output_amount': 25.631270682474067,
#     'output_amount_usd': 9.270470955933966e-14,
#     'price_impact': 26.13162697849104,
#     'price': 3.901484293885482,
#     'price_usd': 1.7709438332674908e-29,
#     'gas_fee': 0.000596348743473,
#     'description': 'Sell 100 MKR for WETH in Sushiswap V2 0xba13afecda9beb75de5c56bbaf696b880a5a50dd\n    \nExpected return: 25.631270682474067 WETH\n    \nPrice impact: 26.13162697849104%\n    '},
#    'swap_1': {'pool': 'USDC_WETH_0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640',
#     'exchange': 'Uniswap_V3',
#     'dangerous': False,
#     'input_token': 'WETH',
#     'input_amount': 25.631270682474067,
#     'input_amount_usd': 21626.22549797556,
#     'output_token': 'USDC',
#     'output_amount': 46209.95631110668,
#     'output_amount_usd': 21625.13977597623,
#     'price_impact': 0.005020395257748778,
#     'price': 0.000554669874819023,
#     'price_usd': 0.21901231435525848,
#     'gas_fee': 0.000596348743473,
#     'description': 'Sell 25.631270682474067 WETH for USDC in Uniswap V3 0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640\n    \nExpected return: 46209.95631110668 USDC\n    \nPrice impact: 0.005020395257748778%\n    '},
#    'amount_in': 100,
#    'amount_in_usd': 3.61685968314979e-13,
#    'amount_out': 46209.95631110668,
#    'amount_out_usd': 21625.13977597623,
#    'price': 0.002164035804897845,
#    'price_usd': 0.46797576761133125,
#    'gas_fee': 0.001192697486946,
#    'path': ['MKR_WETH_0xba13afecda9beb75de5c56bbaf696b880a5a50dd',
#     'USDC_WETH_0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640'],
#    'price_impact': 26.13664737374879}),
#  ('route_13',
#   {'swap_0': {'pool': 'MKR_WETH_0x3afdc5e6dfc0b0a507a8e023c9dce2cafc310316',
#     'exchange': 'Uniswap_V3',
#     'dangerous': False,
#     'input_token': 'MKR',
#     'input_amount': 100,
#     'input_amount_usd': 42188053.77814823,
#     'output_token': 'WETH',
#     'output_amount': 3.835504355303116,
#     'output_amount_usd': 4698831.504211075,
#     'price_impact': 88.8621752287495,
#     'price': 26.072190443933703,
#     'price_usd': 13475174639068.195,
#     'gas_fee': 0.000596348743473,
#     'description': 'Sell 100 MKR for WETH in Uniswap V3 0x3afdc5e6dfc0b0a507a8e023c9dce2cafc310316\n    \nExpected return: 3.835504355303116 WETH\n    \nPrice impact: 88.8621752287495%\n    '},
#    'swap_1': {'pool': 'USDC_WETH_0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640',
#     'exchange': 'Uniswap_V3',
#     'dangerous': False,
#     'input_token': 'WETH',
#     'input_amount': 3.835504355303116,
#     'input_amount_usd': 3236.1829857686175,
#     'output_token': 'USDC',
#     'output_amount': 6915.227019309998,
#     'output_amount_usd': 3236.158672568214,
#     'price_impact': 0.0007512925106589741,
#     'price': 0.0005546461952142568,
#     'price_usd': 0.21900296442428455,
#     'gas_fee': 0.000596348743473,
#     'description': 'Sell 3.835504355303116 WETH for USDC in Uniswap V3 0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640\n    \nExpected return: 6915.227019309998 USDC\n    \nPrice impact: 0.0007512925106589741%\n    '},
#    'swap_2': {'pool': 'USDT_USDC_0x86b32fa55943c9af8c12961d8d2ad7040eeb2f2f',
#     'exchange': 'DODO',
#     'dangerous': False,
#     'input_token': 'USDC',
#     'input_amount': 6915.227019309998,
#     'input_amount_usd': 6914.689171677449,
#     'output_token': 'USDT',
#     'output_amount': 6914.535018,
#     'output_amount_usd': 6915.167090648443,
#     'price_impact': 9.444087534227208e-06,
#     'price': 1.0001000792256018,
#     'price_usd': 1.000113708357159,
#     'gas_fee': 0.000596348743473,
#     'description': 'Sell 6915.227019309998 USDC for USDT in DODO 0x86b32fa55943c9af8c12961d8d2ad7040eeb2f2f\nExpected return: 6914.535018 USDT\nPrice impact: 9.444087534227208e-06%'},
#    'amount_in': 100,
#    'amount_in_usd': 122508829.8417466,
#    'amount_out': 6914.535018,
#    'amount_out_usd': 6915.167090648443,
#    'price': 0.014462288460421245,
#    'price_usd': 1.0000914121696973,
#    'gas_fee': 0.001789046230419,
#    'path': ['MKR_WETH_0x3afdc5e6dfc0b0a507a8e023c9dce2cafc310316',
#     'USDC_WETH_0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640',
#     'USDT_USDC_0x86b32fa55943c9af8c12961d8d2ad7040eeb2f2f'],
#    'price_impact': 88.8629359653477}),
#  ('route_14',
#   {'swap_0': {'pool': 'MKR_WETH_0x3afdc5e6dfc0b0a507a8e023c9dce2cafc310316',
#     'exchange': 'Uniswap_V3',
#     'dangerous': False,
#     'input_token': 'MKR',
#     'input_amount': 100,
#     'input_amount_usd': 42188053.77814823,
#     'output_token': 'WETH',
#     'output_amount': 3.835504355303116,
#     'output_amount_usd': 4698831.504211075,
#     'price_impact': 88.8621752287495,
#     'price': 26.072190443933703,
#     'price_usd': 13475174639068.195,
#     'gas_fee': 0.000596348743473,
#     'description': 'Sell 100 MKR for WETH in Uniswap V3 0x3afdc5e6dfc0b0a507a8e023c9dce2cafc310316\n    \nExpected return: 3.835504355303116 WETH\n    \nPrice impact: 88.8621752287495%\n    '},
#    'swap_1': {'pool': 'USDC_WETH_0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640',
#     'exchange': 'Uniswap_V3',
#     'dangerous': False,
#     'input_token': 'WETH',
#     'input_amount': 3.835504355303116,
#     'input_amount_usd': 3236.1829857686175,
#     'output_token': 'USDC',
#     'output_amount': 6915.227019309998,
#     'output_amount_usd': 3236.158672568214,
#     'price_impact': 0.0007512925106589741,
#     'price': 0.0005546461952142568,
#     'price_usd': 0.21900296442428455,
#     'gas_fee': 0.000596348743473,
#     'description': 'Sell 3.835504355303116 WETH for USDC in Uniswap V3 0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640\n    \nExpected return: 6915.227019309998 USDC\n    \nPrice impact: 0.0007512925106589741%\n    '},
#    'swap_2': {'pool': 'FRAX_USDC_0xdcef968d416a41cdac0ed8702fac8128a64241a2',
#     'exchange': 'Curve',
#     'dangerous': False,
#     'input_token': 'USDC',
#     'input_amount': 6915.227019309998,
#     'input_amount_usd': 6913.774821635942,
#     'output_token': 'FRAX',
#     'output_amount': 6919.528635509007,
#     'output_amount_usd': 6913.774821635941,
#     'price_impact': 0.0,
#     'price': 0.9993783368166245,
#     'price_usd': 0.9983376261783073,
#     'gas_fee': 0.000596348743473,
#     'description': 'Sell 6915.227019309998 USDC for FRAX in Curve 0xdcef968d416a41cdac0ed8702fac8128a64241a2\n    \nExpected return: 6919.528635509007 FRAX\n    \nPrice impact: 0.0%\n    '},
#    'amount_in': 100,
#    'amount_in_usd': 122508829.8417466,
#    'amount_out': 6919.528635509007,
#    'amount_out_usd': 6913.774821635941,
#    'price': 0.014451851458035611,
#    'price_usd': 0.9991684673658928,
#    'gas_fee': 0.001789046230419,
#    'path': ['MKR_WETH_0x3afdc5e6dfc0b0a507a8e023c9dce2cafc310316',
#     'USDC_WETH_0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640',
#     'FRAX_USDC_0xdcef968d416a41cdac0ed8702fac8128a64241a2'],
#    'price_impact': 88.86292652126016}),
#  ('route_6',
#   {'swap_0': {'pool': 'MKR_USDC_0xc486ad2764d55c7dc033487d634195d6e4a6917e',
#     'exchange': 'Uniswap_V3',
#     'dangerous': False,
#     'input_token': 'MKR',
#     'input_amount': 100,
#     'input_amount_usd': 558187.1363728422,
#     'output_token': 'USDC',
#     'output_amount': 6266.289260541243,
#     'output_amount_usd': 55877.37296753924,
#     'price_impact': 89.9894910995914,
#     'price': 0.01595840789375922,
#     'price_usd': 794.3189551366643,
#     'gas_fee': 0.000596348743473,
#     'description': 'Sell 100 MKR for USDC in Uniswap V3 0xc486ad2764d55c7dc033487d634195d6e4a6917e\n    \nExpected return: 6266.289260541243 USDC\n    \nPrice impact: 89.9894910995914%\n    '},
#    'swap_1': {'pool': 'USDT_USDC_0x86b32fa55943c9af8c12961d8d2ad7040eeb2f2f',
#     'exchange': 'DODO',
#     'dangerous': False,
#     'input_token': 'USDC',
#     'input_amount': 6266.289260541243,
#     'input_amount_usd': 6265.801885530381,
#     'output_token': 'USDT',
#     'output_amount': 6265.662239,
#     'output_amount_usd': 6266.234996779858,
#     'price_impact': 8.788460026387668e-06,
#     'price': 1.0001000726686702,
#     'price_usd': 1.0001137018001378,
#     'gas_fee': 0.000596348743473,
#     'description': 'Sell 6266.289260541243 USDC for USDT in DODO 0x86b32fa55943c9af8c12961d8d2ad7040eeb2f2f\nExpected return: 6265.662239 USDT\nPrice impact: 8.788460026387668e-06%'},
#    'amount_in': 100,
#    'amount_in_usd': 891.7139098477063,
#    'amount_out': 6265.662239,
#    'amount_out_usd': 6266.234996779858,
#    'price': 0.015960004894224875,
#    'price_usd': 1.0000914121696973,
#    'gas_fee': 0.001192697486946,
#    'path': ['MKR_USDC_0xc486ad2764d55c7dc033487d634195d6e4a6917e',
#     'USDT_USDC_0x86b32fa55943c9af8c12961d8d2ad7040eeb2f2f'],
#    'price_impact': 89.98949988805143}),
#  ('route_7',
#   {'swap_0': {'pool': 'MKR_USDC_0xc486ad2764d55c7dc033487d634195d6e4a6917e',
#     'exchange': 'Uniswap_V3',
#     'dangerous': False,
#     'input_token': 'MKR',
#     'input_amount': 100,
#     'input_amount_usd': 558187.1363728422,
#     'output_token': 'USDC',
#     'output_amount': 6266.289260541243,
#     'output_amount_usd': 55877.37296753924,
#     'price_impact': 89.9894910995914,
#     'price': 0.01595840789375922,
#     'price_usd': 794.3189551366643,
#     'gas_fee': 0.000596348743473,
#     'description': 'Sell 100 MKR for USDC in Uniswap V3 0xc486ad2764d55c7dc033487d634195d6e4a6917e\n    \nExpected return: 6266.289260541243 USDC\n    \nPrice impact: 89.9894910995914%\n    '},
#    'swap_1': {'pool': 'FRAX_USDC_0xdcef968d416a41cdac0ed8702fac8128a64241a2',
#     'exchange': 'Curve',
#     'dangerous': False,
#     'input_token': 'USDC',
#     'input_amount': 6266.289260541243,
#     'input_amount_usd': 6264.973339796528,
#     'output_token': 'FRAX',
#     'output_amount': 6270.187205079514,
#     'output_amount_usd': 6264.973339796528,
#     'price_impact': 0.0,
#     'price': 0.9993783368166244,
#     'price_usd': 0.9983376261783071,
#     'gas_fee': 0.000596348743473,
#     'description': 'Sell 6266.289260541243 USDC for FRAX in Curve 0xdcef968d416a41cdac0ed8702fac8128a64241a2\n    \nExpected return: 6270.187205079514 FRAX\n    \nPrice impact: 0.0%\n    '},
#    'amount_in': 100,
#    'amount_in_usd': 891.7139098477063,
#    'amount_out': 6270.187205079514,
#    'amount_out_usd': 6264.973339796528,
#    'price': 0.01594848713910638,
#    'price_usd': 0.9991684673658928,
#    'gas_fee': 0.001192697486946,
#    'path': ['MKR_USDC_0xc486ad2764d55c7dc033487d634195d6e4a6917e',
#     'FRAX_USDC_0xdcef968d416a41cdac0ed8702fac8128a64241a2'],
#    'price_impact': 89.9894910995914}),
#  ('route_3',
#   {'swap_0': {'pool': 'MKR_WETH_0x3afdc5e6dfc0b0a507a8e023c9dce2cafc310316',
#     'exchange': 'Uniswap_V3',
#     'dangerous': False,
#     'input_token': 'MKR',
#     'input_amount': 100,
#     'input_amount_usd': 42188053.77814823,
#     'output_token': 'WETH',
#     'output_amount': 3.835504355303116,
#     'output_amount_usd': 4698831.504211075,
#     'price_impact': 88.8621752287495,
#     'price': 26.072190443933703,
#     'price_usd': 13475174639068.195,
#     'gas_fee': 0.000596348743473,
#     'description': 'Sell 100 MKR for WETH in Uniswap V3 0x3afdc5e6dfc0b0a507a8e023c9dce2cafc310316\n    \nExpected return: 3.835504355303116 WETH\n    \nPrice impact: 88.8621752287495%\n    '},
#    'swap_1': {'pool': 'USDC_WETH_0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640',
#     'exchange': 'Uniswap_V3',
#     'dangerous': False,
#     'input_token': 'WETH',
#     'input_amount': 3.835504355303116,
#     'input_amount_usd': 3236.1829857686175,
#     'output_token': 'USDC',
#     'output_amount': 6915.227019309998,
#     'output_amount_usd': 3236.158672568214,
#     'price_impact': 0.0007512925106589741,
#     'price': 0.0005546461952142568,
#     'price_usd': 0.21900296442428455,
#     'gas_fee': 0.000596348743473,
#     'description': 'Sell 3.835504355303116 WETH for USDC in Uniswap V3 0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640\n    \nExpected return: 6915.227019309998 USDC\n    \nPrice impact: 0.0007512925106589741%\n    '},
#    'amount_in': 100,
#    'amount_in_usd': 122508829.8417466,
#    'amount_out': 6915.227019309998,
#    'amount_out_usd': 3236.158672568214,
#    'price': 0.014460841230629334,
#    'price_usd': 0.46797576761133125,
#    'gas_fee': 0.001192697486946,
#    'path': ['MKR_WETH_0x3afdc5e6dfc0b0a507a8e023c9dce2cafc310316',
#     'USDC_WETH_0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640'],
#    'price_impact': 88.86292652126016}),
#  ('route_8',
#   {'swap_0': {'pool': 'MKR_USDC_0xc486ad2764d55c7dc033487d634195d6e4a6917e',
#     'exchange': 'Uniswap_V3',
#     'dangerous': False,
#     'input_token': 'MKR',
#     'input_amount': 100,
#     'input_amount_usd': 558187.1363728422,
#     'output_token': 'USDC',
#     'output_amount': 6266.289260541243,
#     'output_amount_usd': 55877.37296753924,
#     'price_impact': 89.9894910995914,
#     'price': 0.01595840789375922,
#     'price_usd': 794.3189551366643,
#     'gas_fee': 0.000596348743473,
#     'description': 'Sell 100 MKR for USDC in Uniswap V3 0xc486ad2764d55c7dc033487d634195d6e4a6917e\n    \nExpected return: 6266.289260541243 USDC\n    \nPrice impact: 89.9894910995914%\n    '},
#    'swap_1': {'pool': 'USDC_WETH_0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640',
#     'exchange': 'Uniswap_V3',
#     'dangerous': False,
#     'input_token': 'USDC',
#     'input_amount': 6266.289260541243,
#     'input_amount_usd': 2932.471526776429,
#     'output_token': 'WETH',
#     'output_amount': 3.475523723696824,
#     'output_amount_usd': 2932.451562911595,
#     'price_impact': 0.0006807863146107707,
#     'price': 1802.9769780641732,
#     'price_usd': 711908.4317025936,
#     'gas_fee': 0.000596348743473,
#     'description': 'Sell 6266.289260541243 USDC for WETH in Uniswap V3 0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640\n    \nExpected return: 3.475523723696824 WETH\n    \nPrice impact: 0.0006807863146107707%\n    '},
#    'amount_in': 100,
#    'amount_in_usd': 558187.1363728422,
#    'amount_out': 3.475523723696824,
#    'amount_out_usd': 2932.451562911595,
#    'price': 28.772642039005447,
#    'price_usd': 843.7437911637738,
#    'gas_fee': 0.001192697486946,
#    'path': ['MKR_USDC_0xc486ad2764d55c7dc033487d634195d6e4a6917e',
#     'USDC_WETH_0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640'],
#    'price_impact': 89.99017188590602}),
#  ('route_1',
#   {'swap_0': {'pool': 'MKR_USDC_0x936198fcac6d8cdec3815f24ba250041f593f6c3',
#     'exchange': 'Uniswap_V3',
#     'dangerous': True,
#     'input_token': 'MKR',
#     'input_amount': 100,
#     'input_amount_usd': 0,
#     'output_token': 'USDC',
#     'output_amount': 0.0,
#     'output_amount_usd': 0,
#     'price_impact': 100.0,
#     'price': inf,
#     'price_usd': inf,
#     'gas_fee': 0.000596348743473,
#     'description': 'Sell 100 MKR for USDC in Uniswap V3 0x936198fcac6d8cdec3815f24ba250041f593f6c3\n    \nExpected return: 0.0 USDC\n    \nPrice impact: 100.0%\n    '},
#    'amount_in': 100,
#    'amount_in_usd': None,
#    'amount_out': 0.0,
#    'amount_out_usd': 0.0,
#    'price': inf,
#    'price_usd': 0.0,
#    'gas_fee': 0.000596348743473,
#    'path': ['MKR_USDC_0x936198fcac6d8cdec3815f24ba250041f593f6c3'],
#    'price_impact': 100.0}),
#  ('route_9',
#   {'swap_0': {'pool': 'MKR_USDC_0xc486ad2764d55c7dc033487d634195d6e4a6917e',
#     'exchange': 'Uniswap_V3',
#     'dangerous': False,
#     'input_token': 'MKR',
#     'input_amount': 100,
#     'input_amount_usd': 558187.1363728422,
#     'output_token': 'USDC',
#     'output_amount': 6266.289260541243,
#     'output_amount_usd': 55877.37296753924,
#     'price_impact': 89.9894910995914,
#     'price': 0.01595840789375922,
#     'price_usd': 794.3189551366643,
#     'gas_fee': 0.000596348743473,
#     'description': 'Sell 100 MKR for USDC in Uniswap V3 0xc486ad2764d55c7dc033487d634195d6e4a6917e\n    \nExpected return: 6266.289260541243 USDC\n    \nPrice impact: 89.9894910995914%\n    '},
#    'swap_1': {'pool': 'MKR_USDC_0x936198fcac6d8cdec3815f24ba250041f593f6c3',
#     'exchange': 'Uniswap_V3',
#     'dangerous': True,
#     'input_token': 'USDC',
#     'input_amount': 6266.289260541243,
#     'input_amount_usd': 0,
#     'output_token': 'MKR',
#     'output_amount': 0.0,
#     'output_amount_usd': 0,
#     'price_impact': 100.0,
#     'price': inf,
#     'price_usd': inf,
#     'gas_fee': 0.000596348743473,
#     'description': 'Sell 6266.289260541243 USDC for MKR in Uniswap V3 0x936198fcac6d8cdec3815f24ba250041f593f6c3\n    \nExpected return: 0.0 MKR\n    \nPrice impact: 100.0%\n    '},
#    'amount_in': 100,
#    'amount_in_usd': None,
#    'amount_out': 0.0,
#    'amount_out_usd': 0.0,
#    'price': inf,
#    'price_usd': 0.0,
#    'gas_fee': 0.001192697486946,
#    'path': ['MKR_USDC_0xc486ad2764d55c7dc033487d634195d6e4a6917e',
#     'MKR_USDC_0x936198fcac6d8cdec3815f24ba250041f593f6c3'],
#    'price_impact': 189.98949109959142}),
#  ('route_10',
#   {'swap_0': {'pool': 'MKR_USDC_0x936198fcac6d8cdec3815f24ba250041f593f6c3',
#     'exchange': 'Uniswap_V3',
#     'dangerous': True,
#     'input_token': 'MKR',
#     'input_amount': 100,
#     'input_amount_usd': 0,
#     'output_token': 'USDC',
#     'output_amount': 0.0,
#     'output_amount_usd': 0,
#     'price_impact': 100.0,
#     'price': inf,
#     'price_usd': inf,
#     'gas_fee': 0.000596348743473,
#     'description': 'Sell 100 MKR for USDC in Uniswap V3 0x936198fcac6d8cdec3815f24ba250041f593f6c3\n    \nExpected return: 0.0 USDC\n    \nPrice impact: 100.0%\n    '},
#    'swap_1': {'pool': 'USDT_USDC_0x86b32fa55943c9af8c12961d8d2ad7040eeb2f2f',
#     'exchange': 'DODO',
#     'dangerous': False,
#     'input_token': 'USDC',
#     'input_amount': 0.0,
#     'input_amount_usd': 0,
#     'output_token': 'USDT',
#     'output_amount': 0,
#     'output_amount_usd': 0,
#     'price_impact': inf,
#     'price': inf,
#     'price_usd': inf,
#     'gas_fee': 0.000596348743473,
#     'description': 'pool 0x86b32fa55943c9af8c12961d8d2ad7040eeb2f2f is not active'},
#    'amount_in': 100,
#    'amount_in_usd': None,
#    'amount_out': 0,
#    'amount_out_usd': 0.0,
#    'price': inf,
#    'price_usd': 1.0000914121696973,
#    'gas_fee': 0.001192697486946,
#    'path': ['MKR_USDC_0x936198fcac6d8cdec3815f24ba250041f593f6c3',
#     'USDT_USDC_0x86b32fa55943c9af8c12961d8d2ad7040eeb2f2f'],
#    'price_impact': inf})]

# %%
unsplit
# Out:
# {'pool_graph': {'GP_WETH_0x7e3a3a525d9d265d11d1d1db3cad678746b47d09': ['GP_WETH_0x7e3a3a525d9d265d11d1d1db3cad678746b47d09',
#    'TFT_WETH_0x43c4ea688e53aef3aab172b537b5df6d82f4c4dc',
#    'PUNKS_WETH_0xa80ccc104349d2ee29998c54d6e6488012f8afe0',
#    'DSD_WETH_0x7206ae46531093cf2dbbab4c74ac6135e6535a91',
#    'WETH_CRT_0xe8202cccda10a211cc9a5d6a0157fb47ba2ab157',
#    'KCC_WETH_0xec3f403b6b23462d8d657a6a24aef59d3cd622b9',
#    'tiger_WETH_0x207a0856d0cc2648260d05dc5cb3ba78bd5022f9',
#    'EGOD_WETH_0xfb57be17b95872fcea940ddfe98dcecdf2ac8377',
#    'JZo2o_WETH_0xcee2e90275af0aa1ac425dd8a41e3857f7acc6ba',
#    'USDC_WETH_0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640',
#    'MKR_WETH_0xe8c6c9227491c0a8156a0106a0204d881bb7e531',
#    'MKR_WETH_0x3afdc5e6dfc0b0a507a8e023c9dce2cafc310316',
#    'MKR_WETH_0xc2adda861f89bbb333c90c492cb837741916a225',
#    'MKR_WETH_0xba13afecda9beb75de5c56bbaf696b880a5a50dd',
#    'MKR_WETH_0x886072a44bdd944495eff38ace8ce75c1eacdaf6'],
#   'TFT_WETH_0x43c4ea688e53aef3aab172b537b5df6d82f4c4dc': ['GP_WETH_0x7e3a3a525d9d265d11d1d1db3cad678746b47d09',
#    'TFT_WETH_0x43c4ea688e53aef3aab172b537b5df6d82f4c4dc',
#    'PUNKS_WETH_0xa80ccc104349d2ee29998c54d6e6488012f8afe0',
#    'DSD_WETH_0x7206ae46531093cf2dbbab4c74ac6135e6535a91',
#    'WETH_CRT_0xe8202cccda10a211cc9a5d6a0157fb47ba2ab157',
#    'KCC_WETH_0xec3f403b6b23462d8d657a6a24aef59d3cd622b9',
#    'tiger_WETH_0x207a0856d0cc2648260d05dc5cb3ba78bd5022f9',
#    'EGOD_WETH_0xfb57be17b95872fcea940ddfe98dcecdf2ac8377',
#    'JZo2o_WETH_0xcee2e90275af0aa1ac425dd8a41e3857f7acc6ba',
#    'USDC_WETH_0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640',
#    'MKR_WETH_0xe8c6c9227491c0a8156a0106a0204d881bb7e531',
#    'MKR_WETH_0x3afdc5e6dfc0b0a507a8e023c9dce2cafc310316',
#    'MKR_WETH_0xc2adda861f89bbb333c90c492cb837741916a225',
#    'MKR_WETH_0xba13afecda9beb75de5c56bbaf696b880a5a50dd',
#    'MKR_WETH_0x886072a44bdd944495eff38ace8ce75c1eacdaf6'],
#   'PUNKS_WETH_0xa80ccc104349d2ee29998c54d6e6488012f8afe0': ['GP_WETH_0x7e3a3a525d9d265d11d1d1db3cad678746b47d09',
#    'TFT_WETH_0x43c4ea688e53aef3aab172b537b5df6d82f4c4dc',
#    'PUNKS_WETH_0xa80ccc104349d2ee29998c54d6e6488012f8afe0',
#    'DSD_WETH_0x7206ae46531093cf2dbbab4c74ac6135e6535a91',
#    'WETH_CRT_0xe8202cccda10a211cc9a5d6a0157fb47ba2ab157',
#    'KCC_WETH_0xec3f403b6b23462d8d657a6a24aef59d3cd622b9',
#    'tiger_WETH_0x207a0856d0cc2648260d05dc5cb3ba78bd5022f9',
#    'EGOD_WETH_0xfb57be17b95872fcea940ddfe98dcecdf2ac8377',
#    'JZo2o_WETH_0xcee2e90275af0aa1ac425dd8a41e3857f7acc6ba',
#    'USDC_WETH_0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640',
#    'MKR_WETH_0xe8c6c9227491c0a8156a0106a0204d881bb7e531',
#    'MKR_WETH_0x3afdc5e6dfc0b0a507a8e023c9dce2cafc310316',
#    'MKR_WETH_0xc2adda861f89bbb333c90c492cb837741916a225',
#    'MKR_WETH_0xba13afecda9beb75de5c56bbaf696b880a5a50dd',
#    'MKR_WETH_0x886072a44bdd944495eff38ace8ce75c1eacdaf6'],
#   'DSD_WETH_0x7206ae46531093cf2dbbab4c74ac6135e6535a91': ['GP_WETH_0x7e3a3a525d9d265d11d1d1db3cad678746b47d09',
#    'TFT_WETH_0x43c4ea688e53aef3aab172b537b5df6d82f4c4dc',
#    'PUNKS_WETH_0xa80ccc104349d2ee29998c54d6e6488012f8afe0',
#    'DSD_WETH_0x7206ae46531093cf2dbbab4c74ac6135e6535a91',
#    'WETH_CRT_0xe8202cccda10a211cc9a5d6a0157fb47ba2ab157',
#    'KCC_WETH_0xec3f403b6b23462d8d657a6a24aef59d3cd622b9',
#    'tiger_WETH_0x207a0856d0cc2648260d05dc5cb3ba78bd5022f9',
#    'EGOD_WETH_0xfb57be17b95872fcea940ddfe98dcecdf2ac8377',
#    'JZo2o_WETH_0xcee2e90275af0aa1ac425dd8a41e3857f7acc6ba',
#    'USDC_WETH_0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640',
#    'MKR_WETH_0xe8c6c9227491c0a8156a0106a0204d881bb7e531',
#    'MKR_WETH_0x3afdc5e6dfc0b0a507a8e023c9dce2cafc310316',
#    'MKR_WETH_0xc2adda861f89bbb333c90c492cb837741916a225',
#    'MKR_WETH_0xba13afecda9beb75de5c56bbaf696b880a5a50dd',
#    'MKR_WETH_0x886072a44bdd944495eff38ace8ce75c1eacdaf6'],
#   'WETH_CRT_0xe8202cccda10a211cc9a5d6a0157fb47ba2ab157': ['GP_WETH_0x7e3a3a525d9d265d11d1d1db3cad678746b47d09',
#    'TFT_WETH_0x43c4ea688e53aef3aab172b537b5df6d82f4c4dc',
#    'PUNKS_WETH_0xa80ccc104349d2ee29998c54d6e6488012f8afe0',
#    'DSD_WETH_0x7206ae46531093cf2dbbab4c74ac6135e6535a91',
#    'WETH_CRT_0xe8202cccda10a211cc9a5d6a0157fb47ba2ab157',
#    'KCC_WETH_0xec3f403b6b23462d8d657a6a24aef59d3cd622b9',
#    'tiger_WETH_0x207a0856d0cc2648260d05dc5cb3ba78bd5022f9',
#    'EGOD_WETH_0xfb57be17b95872fcea940ddfe98dcecdf2ac8377',
#    'JZo2o_WETH_0xcee2e90275af0aa1ac425dd8a41e3857f7acc6ba',
#    'USDC_WETH_0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640',
#    'MKR_WETH_0xe8c6c9227491c0a8156a0106a0204d881bb7e531',
#    'MKR_WETH_0x3afdc5e6dfc0b0a507a8e023c9dce2cafc310316',
#    'MKR_WETH_0xc2adda861f89bbb333c90c492cb837741916a225',
#    'MKR_WETH_0xba13afecda9beb75de5c56bbaf696b880a5a50dd',
#    'MKR_WETH_0x886072a44bdd944495eff38ace8ce75c1eacdaf6'],
#   'ease.org_ez-cvxsteCRV_0x277667eb3e34f134adf870be9550e9f323d0dc24': ['ease.org_ez-cvxsteCRV_0x277667eb3e34f134adf870be9550e9f323d0dc24',
#    'ease.org_ez-yvCurve-IronBank_0x8c0411f2ad5470a66cb2e9c64536cfb8dcd54d51',
#    'ease.org_ez-SLP-WBTC-WETH_0x055284a4ca6532ecc219ac06b577d540c686669d'],
#   'rtx_USDT_0xb38e41aadd80eef03e1c86a7c106d6d3a25e3a75': ['rtx_USDT_0xb38e41aadd80eef03e1c86a7c106d6d3a25e3a75',
#    'ULST_USDT_0xb529b1d2f108de61415466b81e2cd2aa1c958ca2',
#    'MKR_USDT_0xb5f8d230523c4bdcd00603ee354921441fde39b4',
#    'MKR_USDT_0x0cbe2f86e2fd90040ebb557b99f83400bf8f3717'],
#   'KCC_WETH_0xec3f403b6b23462d8d657a6a24aef59d3cd622b9': ['GP_WETH_0x7e3a3a525d9d265d11d1d1db3cad678746b47d09',
#    'TFT_WETH_0x43c4ea688e53aef3aab172b537b5df6d82f4c4dc',
#    'PUNKS_WETH_0xa80ccc104349d2ee29998c54d6e6488012f8afe0',
#    'DSD_WETH_0x7206ae46531093cf2dbbab4c74ac6135e6535a91',
#    'WETH_CRT_0xe8202cccda10a211cc9a5d6a0157fb47ba2ab157',
#    'KCC_WETH_0xec3f403b6b23462d8d657a6a24aef59d3cd622b9',
#    'tiger_WETH_0x207a0856d0cc2648260d05dc5cb3ba78bd5022f9',
#    'EGOD_WETH_0xfb57be17b95872fcea940ddfe98dcecdf2ac8377',
#    'JZo2o_WETH_0xcee2e90275af0aa1ac425dd8a41e3857f7acc6ba',
#    'USDC_WETH_0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640',
#    'MKR_WETH_0xe8c6c9227491c0a8156a0106a0204d881bb7e531',
#    'MKR_WETH_0x3afdc5e6dfc0b0a507a8e023c9dce2cafc310316',
#    'MKR_WETH_0xc2adda861f89bbb333c90c492cb837741916a225',
#    'MKR_WETH_0xba13afecda9beb75de5c56bbaf696b880a5a50dd',
#    'MKR_WETH_0x886072a44bdd944495eff38ace8ce75c1eacdaf6'],
#   'ULST_USDT_0xb529b1d2f108de61415466b81e2cd2aa1c958ca2': ['rtx_USDT_0xb38e41aadd80eef03e1c86a7c106d6d3a25e3a75',
#    'ULST_USDT_0xb529b1d2f108de61415466b81e2cd2aa1c958ca2',
#    'MKR_USDT_0xb5f8d230523c4bdcd00603ee354921441fde39b4',
#    'MKR_USDT_0x0cbe2f86e2fd90040ebb557b99f83400bf8f3717'],
#   'tiger_WETH_0x207a0856d0cc2648260d05dc5cb3ba78bd5022f9': ['GP_WETH_0x7e3a3a525d9d265d11d1d1db3cad678746b47d09',
#    'TFT_WETH_0x43c4ea688e53aef3aab172b537b5df6d82f4c4dc',
#    'PUNKS_WETH_0xa80ccc104349d2ee29998c54d6e6488012f8afe0',
#    'DSD_WETH_0x7206ae46531093cf2dbbab4c74ac6135e6535a91',
#    'WETH_CRT_0xe8202cccda10a211cc9a5d6a0157fb47ba2ab157',
#    'KCC_WETH_0xec3f403b6b23462d8d657a6a24aef59d3cd622b9',
#    'tiger_WETH_0x207a0856d0cc2648260d05dc5cb3ba78bd5022f9',
#    'EGOD_WETH_0xfb57be17b95872fcea940ddfe98dcecdf2ac8377',
#    'JZo2o_WETH_0xcee2e90275af0aa1ac425dd8a41e3857f7acc6ba',
#    'USDC_WETH_0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640',
#    'MKR_WETH_0xe8c6c9227491c0a8156a0106a0204d881bb7e531',
#    'MKR_WETH_0x3afdc5e6dfc0b0a507a8e023c9dce2cafc310316',
#    'MKR_WETH_0xc2adda861f89bbb333c90c492cb837741916a225',
#    'MKR_WETH_0xba13afecda9beb75de5c56bbaf696b880a5a50dd',
#    'MKR_WETH_0x886072a44bdd944495eff38ace8ce75c1eacdaf6'],
#   'EGOD_WETH_0xfb57be17b95872fcea940ddfe98dcecdf2ac8377': ['GP_WETH_0x7e3a3a525d9d265d11d1d1db3cad678746b47d09',
#    'TFT_WETH_0x43c4ea688e53aef3aab172b537b5df6d82f4c4dc',
#    'PUNKS_WETH_0xa80ccc104349d2ee29998c54d6e6488012f8afe0',
#    'DSD_WETH_0x7206ae46531093cf2dbbab4c74ac6135e6535a91',
#    'WETH_CRT_0xe8202cccda10a211cc9a5d6a0157fb47ba2ab157',
#    'KCC_WETH_0xec3f403b6b23462d8d657a6a24aef59d3cd622b9',
#    'tiger_WETH_0x207a0856d0cc2648260d05dc5cb3ba78bd5022f9',
#    'EGOD_WETH_0xfb57be17b95872fcea940ddfe98dcecdf2ac8377',
#    'JZo2o_WETH_0xcee2e90275af0aa1ac425dd8a41e3857f7acc6ba',
#    'USDC_WETH_0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640',
#    'MKR_WETH_0xe8c6c9227491c0a8156a0106a0204d881bb7e531',
#    'MKR_WETH_0x3afdc5e6dfc0b0a507a8e023c9dce2cafc310316',
#    'MKR_WETH_0xc2adda861f89bbb333c90c492cb837741916a225',
#    'MKR_WETH_0xba13afecda9beb75de5c56bbaf696b880a5a50dd',
#    'MKR_WETH_0x886072a44bdd944495eff38ace8ce75c1eacdaf6'],
#   'ease.org_ez-yvCurve-IronBank_0x8c0411f2ad5470a66cb2e9c64536cfb8dcd54d51': ['ease.org_ez-cvxsteCRV_0x277667eb3e34f134adf870be9550e9f323d0dc24',
#    'ease.org_ez-yvCurve-IronBank_0x8c0411f2ad5470a66cb2e9c64536cfb8dcd54d51',
#    'ease.org_ez-SLP-WBTC-WETH_0x055284a4ca6532ecc219ac06b577d540c686669d'],
#   'ease.org_ez-SLP-WBTC-WETH_0x055284a4ca6532ecc219ac06b577d540c686669d': ['ease.org_ez-cvxsteCRV_0x277667eb3e34f134adf870be9550e9f323d0dc24',
#    'ease.org_ez-yvCurve-IronBank_0x8c0411f2ad5470a66cb2e9c64536cfb8dcd54d51',
#    'ease.org_ez-SLP-WBTC-WETH_0x055284a4ca6532ecc219ac06b577d540c686669d'],
#   'USDT_USDC_0x86b32fa55943c9af8c12961d8d2ad7040eeb2f2f': ['USDT_USDC_0x86b32fa55943c9af8c12961d8d2ad7040eeb2f2f',
#    'FRAX_USDC_0xdcef968d416a41cdac0ed8702fac8128a64241a2',
#    'USDC_WETH_0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640',
#    'MKR_USDC_0xc486ad2764d55c7dc033487d634195d6e4a6917e',
#    'MKR_USDC_0x936198fcac6d8cdec3815f24ba250041f593f6c3'],
#   'JZo2o_WETH_0xcee2e90275af0aa1ac425dd8a41e3857f7acc6ba': ['GP_WETH_0x7e3a3a525d9d265d11d1d1db3cad678746b47d09',
#    'TFT_WETH_0x43c4ea688e53aef3aab172b537b5df6d82f4c4dc',
#    'PUNKS_WETH_0xa80ccc104349d2ee29998c54d6e6488012f8afe0',
#    'DSD_WETH_0x7206ae46531093cf2dbbab4c74ac6135e6535a91',
#    'WETH_CRT_0xe8202cccda10a211cc9a5d6a0157fb47ba2ab157',
#    'KCC_WETH_0xec3f403b6b23462d8d657a6a24aef59d3cd622b9',
#    'tiger_WETH_0x207a0856d0cc2648260d05dc5cb3ba78bd5022f9',
#    'EGOD_WETH_0xfb57be17b95872fcea940ddfe98dcecdf2ac8377',
#    'JZo2o_WETH_0xcee2e90275af0aa1ac425dd8a41e3857f7acc6ba',
#    'USDC_WETH_0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640',
#    'MKR_WETH_0xe8c6c9227491c0a8156a0106a0204d881bb7e531',
#    'MKR_WETH_0x3afdc5e6dfc0b0a507a8e023c9dce2cafc310316',
#    'MKR_WETH_0xc2adda861f89bbb333c90c492cb837741916a225',
#    'MKR_WETH_0xba13afecda9beb75de5c56bbaf696b880a5a50dd',
#    'MKR_WETH_0x886072a44bdd944495eff38ace8ce75c1eacdaf6'],
#   'FRAX_USDC_0xdcef968d416a41cdac0ed8702fac8128a64241a2': ['USDT_USDC_0x86b32fa55943c9af8c12961d8d2ad7040eeb2f2f',
#    'FRAX_USDC_0xdcef968d416a41cdac0ed8702fac8128a64241a2',
#    'USDC_WETH_0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640',
#    'MKR_USDC_0xc486ad2764d55c7dc033487d634195d6e4a6917e',
#    'MKR_USDC_0x936198fcac6d8cdec3815f24ba250041f593f6c3'],
#   'USDC_WETH_0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640': ['GP_WETH_0x7e3a3a525d9d265d11d1d1db3cad678746b47d09',
#    'TFT_WETH_0x43c4ea688e53aef3aab172b537b5df6d82f4c4dc',
#    'PUNKS_WETH_0xa80ccc104349d2ee29998c54d6e6488012f8afe0',
#    'DSD_WETH_0x7206ae46531093cf2dbbab4c74ac6135e6535a91',
#    'WETH_CRT_0xe8202cccda10a211cc9a5d6a0157fb47ba2ab157',
#    'KCC_WETH_0xec3f403b6b23462d8d657a6a24aef59d3cd622b9',
#    'tiger_WETH_0x207a0856d0cc2648260d05dc5cb3ba78bd5022f9',
#    'EGOD_WETH_0xfb57be17b95872fcea940ddfe98dcecdf2ac8377',
#    'USDT_USDC_0x86b32fa55943c9af8c12961d8d2ad7040eeb2f2f',
#    'JZo2o_WETH_0xcee2e90275af0aa1ac425dd8a41e3857f7acc6ba',
#    'FRAX_USDC_0xdcef968d416a41cdac0ed8702fac8128a64241a2',
#    'USDC_WETH_0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640',
#    'MKR_WETH_0xe8c6c9227491c0a8156a0106a0204d881bb7e531',
#    'MKR_WETH_0x3afdc5e6dfc0b0a507a8e023c9dce2cafc310316',
#    'MKR_WETH_0xc2adda861f89bbb333c90c492cb837741916a225',
#    'MKR_WETH_0xba13afecda9beb75de5c56bbaf696b880a5a50dd',
#    'MKR_USDC_0xc486ad2764d55c7dc033487d634195d6e4a6917e',
#    'MKR_WETH_0x886072a44bdd944495eff38ace8ce75c1eacdaf6',
#    'MKR_USDC_0x936198fcac6d8cdec3815f24ba250041f593f6c3'],
#   'MKR_WETH_0xe8c6c9227491c0a8156a0106a0204d881bb7e531': ['GP_WETH_0x7e3a3a525d9d265d11d1d1db3cad678746b47d09',
#    'TFT_WETH_0x43c4ea688e53aef3aab172b537b5df6d82f4c4dc',
#    'PUNKS_WETH_0xa80ccc104349d2ee29998c54d6e6488012f8afe0',
#    'DSD_WETH_0x7206ae46531093cf2dbbab4c74ac6135e6535a91',
#    'WETH_CRT_0xe8202cccda10a211cc9a5d6a0157fb47ba2ab157',
#    'KCC_WETH_0xec3f403b6b23462d8d657a6a24aef59d3cd622b9',
#    'tiger_WETH_0x207a0856d0cc2648260d05dc5cb3ba78bd5022f9',
#    'EGOD_WETH_0xfb57be17b95872fcea940ddfe98dcecdf2ac8377',
#    'JZo2o_WETH_0xcee2e90275af0aa1ac425dd8a41e3857f7acc6ba',
#    'USDC_WETH_0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640',
#    'MKR_WETH_0xe8c6c9227491c0a8156a0106a0204d881bb7e531',
#    'MKR_WETH_0x3afdc5e6dfc0b0a507a8e023c9dce2cafc310316',
#    'MKR_WETH_0xc2adda861f89bbb333c90c492cb837741916a225',
#    'MKR_WETH_0xba13afecda9beb75de5c56bbaf696b880a5a50dd',
#    'RNG_MKR_0xa82656f9e5405af0d80539f7831c8ef3fe4c5bef',
#    'DAI_MKR_0x2a84e2bd2e961b1557d6e516ca647268b432cba4',
#    'MKR_USDC_0xc486ad2764d55c7dc033487d634195d6e4a6917e',
#    'MKR_USD_0xa16a3cbc92d77b720a851d33a91890c4fbfb0299',
#    'MKR_TRIBE_0xe83bad50c0b3f58ded74ecd67f001337e319075f',
#    'MKR_USDT_0xb5f8d230523c4bdcd00603ee354921441fde39b4',
#    'MKR_WETH_0x886072a44bdd944495eff38ace8ce75c1eacdaf6',
#    'MKR_USDT_0x0cbe2f86e2fd90040ebb557b99f83400bf8f3717',
#    'MKR_USDC_0x936198fcac6d8cdec3815f24ba250041f593f6c3'],
#   'MKR_WETH_0x3afdc5e6dfc0b0a507a8e023c9dce2cafc310316': ['GP_WETH_0x7e3a3a525d9d265d11d1d1db3cad678746b47d09',
#    'TFT_WETH_0x43c4ea688e53aef3aab172b537b5df6d82f4c4dc',
#    'PUNKS_WETH_0xa80ccc104349d2ee29998c54d6e6488012f8afe0',
#    'DSD_WETH_0x7206ae46531093cf2dbbab4c74ac6135e6535a91',
#    'WETH_CRT_0xe8202cccda10a211cc9a5d6a0157fb47ba2ab157',
#    'KCC_WETH_0xec3f403b6b23462d8d657a6a24aef59d3cd622b9',
#    'tiger_WETH_0x207a0856d0cc2648260d05dc5cb3ba78bd5022f9',
#    'EGOD_WETH_0xfb57be17b95872fcea940ddfe98dcecdf2ac8377',
#    'JZo2o_WETH_0xcee2e90275af0aa1ac425dd8a41e3857f7acc6ba',
#    'USDC_WETH_0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640',
#    'MKR_WETH_0xe8c6c9227491c0a8156a0106a0204d881bb7e531',
#    'MKR_WETH_0x3afdc5e6dfc0b0a507a8e023c9dce2cafc310316',
#    'MKR_WETH_0xc2adda861f89bbb333c90c492cb837741916a225',
#    'MKR_WETH_0xba13afecda9beb75de5c56bbaf696b880a5a50dd',
#    'RNG_MKR_0xa82656f9e5405af0d80539f7831c8ef3fe4c5bef',
#    'DAI_MKR_0x2a84e2bd2e961b1557d6e516ca647268b432cba4',
#    'MKR_USDC_0xc486ad2764d55c7dc033487d634195d6e4a6917e',
#    'MKR_USD_0xa16a3cbc92d77b720a851d33a91890c4fbfb0299',
#    'MKR_TRIBE_0xe83bad50c0b3f58ded74ecd67f001337e319075f',
#    'MKR_USDT_0xb5f8d230523c4bdcd00603ee354921441fde39b4',
#    'MKR_WETH_0x886072a44bdd944495eff38ace8ce75c1eacdaf6',
#    'MKR_USDT_0x0cbe2f86e2fd90040ebb557b99f83400bf8f3717',
#    'MKR_USDC_0x936198fcac6d8cdec3815f24ba250041f593f6c3'],
#   'MKR_WETH_0xc2adda861f89bbb333c90c492cb837741916a225': ['GP_WETH_0x7e3a3a525d9d265d11d1d1db3cad678746b47d09',
#    'TFT_WETH_0x43c4ea688e53aef3aab172b537b5df6d82f4c4dc',
#    'PUNKS_WETH_0xa80ccc104349d2ee29998c54d6e6488012f8afe0',
#    'DSD_WETH_0x7206ae46531093cf2dbbab4c74ac6135e6535a91',
#    'WETH_CRT_0xe8202cccda10a211cc9a5d6a0157fb47ba2ab157',
#    'KCC_WETH_0xec3f403b6b23462d8d657a6a24aef59d3cd622b9',
#    'tiger_WETH_0x207a0856d0cc2648260d05dc5cb3ba78bd5022f9',
#    'EGOD_WETH_0xfb57be17b95872fcea940ddfe98dcecdf2ac8377',
#    'JZo2o_WETH_0xcee2e90275af0aa1ac425dd8a41e3857f7acc6ba',
#    'USDC_WETH_0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640',
#    'MKR_WETH_0xe8c6c9227491c0a8156a0106a0204d881bb7e531',
#    'MKR_WETH_0x3afdc5e6dfc0b0a507a8e023c9dce2cafc310316',
#    'MKR_WETH_0xc2adda861f89bbb333c90c492cb837741916a225',
#    'MKR_WETH_0xba13afecda9beb75de5c56bbaf696b880a5a50dd',
#    'RNG_MKR_0xa82656f9e5405af0d80539f7831c8ef3fe4c5bef',
#    'DAI_MKR_0x2a84e2bd2e961b1557d6e516ca647268b432cba4',
#    'MKR_USDC_0xc486ad2764d55c7dc033487d634195d6e4a6917e',
#    'MKR_USD_0xa16a3cbc92d77b720a851d33a91890c4fbfb0299',
#    'MKR_TRIBE_0xe83bad50c0b3f58ded74ecd67f001337e319075f',
#    'MKR_USDT_0xb5f8d230523c4bdcd00603ee354921441fde39b4',
#    'MKR_WETH_0x886072a44bdd944495eff38ace8ce75c1eacdaf6',
#    'MKR_USDT_0x0cbe2f86e2fd90040ebb557b99f83400bf8f3717',
#    'MKR_USDC_0x936198fcac6d8cdec3815f24ba250041f593f6c3'],
#   'MKR_WETH_0xba13afecda9beb75de5c56bbaf696b880a5a50dd': ['GP_WETH_0x7e3a3a525d9d265d11d1d1db3cad678746b47d09',
#    'TFT_WETH_0x43c4ea688e53aef3aab172b537b5df6d82f4c4dc',
#    'PUNKS_WETH_0xa80ccc104349d2ee29998c54d6e6488012f8afe0',
#    'DSD_WETH_0x7206ae46531093cf2dbbab4c74ac6135e6535a91',
#    'WETH_CRT_0xe8202cccda10a211cc9a5d6a0157fb47ba2ab157',
#    'KCC_WETH_0xec3f403b6b23462d8d657a6a24aef59d3cd622b9',
#    'tiger_WETH_0x207a0856d0cc2648260d05dc5cb3ba78bd5022f9',
#    'EGOD_WETH_0xfb57be17b95872fcea940ddfe98dcecdf2ac8377',
#    'JZo2o_WETH_0xcee2e90275af0aa1ac425dd8a41e3857f7acc6ba',
#    'USDC_WETH_0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640',
#    'MKR_WETH_0xe8c6c9227491c0a8156a0106a0204d881bb7e531',
#    'MKR_WETH_0x3afdc5e6dfc0b0a507a8e023c9dce2cafc310316',
#    'MKR_WETH_0xc2adda861f89bbb333c90c492cb837741916a225',
#    'MKR_WETH_0xba13afecda9beb75de5c56bbaf696b880a5a50dd',
#    'RNG_MKR_0xa82656f9e5405af0d80539f7831c8ef3fe4c5bef',
#    'DAI_MKR_0x2a84e2bd2e961b1557d6e516ca647268b432cba4',
#    'MKR_USDC_0xc486ad2764d55c7dc033487d634195d6e4a6917e',
#    'MKR_USD_0xa16a3cbc92d77b720a851d33a91890c4fbfb0299',
#    'MKR_TRIBE_0xe83bad50c0b3f58ded74ecd67f001337e319075f',
#    'MKR_USDT_0xb5f8d230523c4bdcd00603ee354921441fde39b4',
#    'MKR_WETH_0x886072a44bdd944495eff38ace8ce75c1eacdaf6',
#    'MKR_USDT_0x0cbe2f86e2fd90040ebb557b99f83400bf8f3717',
#    'MKR_USDC_0x936198fcac6d8cdec3815f24ba250041f593f6c3'],
#   'RNG_MKR_0xa82656f9e5405af0d80539f7831c8ef3fe4c5bef': ['MKR_WETH_0xe8c6c9227491c0a8156a0106a0204d881bb7e531',
#    'MKR_WETH_0x3afdc5e6dfc0b0a507a8e023c9dce2cafc310316',
#    'MKR_WETH_0xc2adda861f89bbb333c90c492cb837741916a225',
#    'MKR_WETH_0xba13afecda9beb75de5c56bbaf696b880a5a50dd',
#    'RNG_MKR_0xa82656f9e5405af0d80539f7831c8ef3fe4c5bef',
#    'DAI_MKR_0x2a84e2bd2e961b1557d6e516ca647268b432cba4',
#    'MKR_USDC_0xc486ad2764d55c7dc033487d634195d6e4a6917e',
#    'MKR_USD_0xa16a3cbc92d77b720a851d33a91890c4fbfb0299',
#    'MKR_TRIBE_0xe83bad50c0b3f58ded74ecd67f001337e319075f',
#    'MKR_USDT_0xb5f8d230523c4bdcd00603ee354921441fde39b4',
#    'MKR_WETH_0x886072a44bdd944495eff38ace8ce75c1eacdaf6',
#    'MKR_USDT_0x0cbe2f86e2fd90040ebb557b99f83400bf8f3717',
#    'MKR_USDC_0x936198fcac6d8cdec3815f24ba250041f593f6c3'],
#   'DAI_MKR_0x2a84e2bd2e961b1557d6e516ca647268b432cba4': ['MKR_WETH_0xe8c6c9227491c0a8156a0106a0204d881bb7e531',
#    'MKR_WETH_0x3afdc5e6dfc0b0a507a8e023c9dce2cafc310316',
#    'MKR_WETH_0xc2adda861f89bbb333c90c492cb837741916a225',
#    'MKR_WETH_0xba13afecda9beb75de5c56bbaf696b880a5a50dd',
#    'RNG_MKR_0xa82656f9e5405af0d80539f7831c8ef3fe4c5bef',
#    'DAI_MKR_0x2a84e2bd2e961b1557d6e516ca647268b432cba4',
#    'MKR_USDC_0xc486ad2764d55c7dc033487d634195d6e4a6917e',
#    'MKR_USD_0xa16a3cbc92d77b720a851d33a91890c4fbfb0299',
#    'MKR_TRIBE_0xe83bad50c0b3f58ded74ecd67f001337e319075f',
#    'MKR_USDT_0xb5f8d230523c4bdcd00603ee354921441fde39b4',
#    'MKR_WETH_0x886072a44bdd944495eff38ace8ce75c1eacdaf6',
#    'MKR_USDT_0x0cbe2f86e2fd90040ebb557b99f83400bf8f3717',
#    'MKR_USDC_0x936198fcac6d8cdec3815f24ba250041f593f6c3'],
#   'MKR_USDC_0xc486ad2764d55c7dc033487d634195d6e4a6917e': ['USDT_USDC_0x86b32fa55943c9af8c12961d8d2ad7040eeb2f2f',
#    'FRAX_USDC_0xdcef968d416a41cdac0ed8702fac8128a64241a2',
#    'USDC_WETH_0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640',
#    'MKR_WETH_0xe8c6c9227491c0a8156a0106a0204d881bb7e531',
#    'MKR_WETH_0x3afdc5e6dfc0b0a507a8e023c9dce2cafc310316',
#    'MKR_WETH_0xc2adda861f89bbb333c90c492cb837741916a225',
#    'MKR_WETH_0xba13afecda9beb75de5c56bbaf696b880a5a50dd',
#    'RNG_MKR_0xa82656f9e5405af0d80539f7831c8ef3fe4c5bef',
#    'DAI_MKR_0x2a84e2bd2e961b1557d6e516ca647268b432cba4',
#    'MKR_USDC_0xc486ad2764d55c7dc033487d634195d6e4a6917e',
#    'MKR_USD_0xa16a3cbc92d77b720a851d33a91890c4fbfb0299',
#    'MKR_TRIBE_0xe83bad50c0b3f58ded74ecd67f001337e319075f',
#    'MKR_USDT_0xb5f8d230523c4bdcd00603ee354921441fde39b4',
#    'MKR_WETH_0x886072a44bdd944495eff38ace8ce75c1eacdaf6',
#    'MKR_USDT_0x0cbe2f86e2fd90040ebb557b99f83400bf8f3717',
#    'MKR_USDC_0x936198fcac6d8cdec3815f24ba250041f593f6c3'],
#   'MKR_USD_0xa16a3cbc92d77b720a851d33a91890c4fbfb0299': ['MKR_WETH_0xe8c6c9227491c0a8156a0106a0204d881bb7e531',
#    'MKR_WETH_0x3afdc5e6dfc0b0a507a8e023c9dce2cafc310316',
#    'MKR_WETH_0xc2adda861f89bbb333c90c492cb837741916a225',
#    'MKR_WETH_0xba13afecda9beb75de5c56bbaf696b880a5a50dd',
#    'RNG_MKR_0xa82656f9e5405af0d80539f7831c8ef3fe4c5bef',
#    'DAI_MKR_0x2a84e2bd2e961b1557d6e516ca647268b432cba4',
#    'MKR_USDC_0xc486ad2764d55c7dc033487d634195d6e4a6917e',
#    'MKR_USD_0xa16a3cbc92d77b720a851d33a91890c4fbfb0299',
#    'MKR_TRIBE_0xe83bad50c0b3f58ded74ecd67f001337e319075f',
#    'MKR_USDT_0xb5f8d230523c4bdcd00603ee354921441fde39b4',
#    'MKR_WETH_0x886072a44bdd944495eff38ace8ce75c1eacdaf6',
#    'MKR_USDT_0x0cbe2f86e2fd90040ebb557b99f83400bf8f3717',
#    'MKR_USDC_0x936198fcac6d8cdec3815f24ba250041f593f6c3'],
#   'MKR_TRIBE_0xe83bad50c0b3f58ded74ecd67f001337e319075f': ['MKR_WETH_0xe8c6c9227491c0a8156a0106a0204d881bb7e531',
#    'MKR_WETH_0x3afdc5e6dfc0b0a507a8e023c9dce2cafc310316',
#    'MKR_WETH_0xc2adda861f89bbb333c90c492cb837741916a225',
#    'MKR_WETH_0xba13afecda9beb75de5c56bbaf696b880a5a50dd',
#    'RNG_MKR_0xa82656f9e5405af0d80539f7831c8ef3fe4c5bef',
#    'DAI_MKR_0x2a84e2bd2e961b1557d6e516ca647268b432cba4',
#    'MKR_USDC_0xc486ad2764d55c7dc033487d634195d6e4a6917e',
#    'MKR_USD_0xa16a3cbc92d77b720a851d33a91890c4fbfb0299',
#    'MKR_TRIBE_0xe83bad50c0b3f58ded74ecd67f001337e319075f',
#    'MKR_USDT_0xb5f8d230523c4bdcd00603ee354921441fde39b4',
#    'MKR_WETH_0x886072a44bdd944495eff38ace8ce75c1eacdaf6',
#    'MKR_USDT_0x0cbe2f86e2fd90040ebb557b99f83400bf8f3717',
#    'MKR_USDC_0x936198fcac6d8cdec3815f24ba250041f593f6c3'],
#   'MKR_USDT_0xb5f8d230523c4bdcd00603ee354921441fde39b4': ['rtx_USDT_0xb38e41aadd80eef03e1c86a7c106d6d3a25e3a75',
#    'ULST_USDT_0xb529b1d2f108de61415466b81e2cd2aa1c958ca2',
#    'MKR_WETH_0xe8c6c9227491c0a8156a0106a0204d881bb7e531',
#    'MKR_WETH_0x3afdc5e6dfc0b0a507a8e023c9dce2cafc310316',
#    'MKR_WETH_0xc2adda861f89bbb333c90c492cb837741916a225',
#    'MKR_WETH_0xba13afecda9beb75de5c56bbaf696b880a5a50dd',
#    'RNG_MKR_0xa82656f9e5405af0d80539f7831c8ef3fe4c5bef',
#    'DAI_MKR_0x2a84e2bd2e961b1557d6e516ca647268b432cba4',
#    'MKR_USDC_0xc486ad2764d55c7dc033487d634195d6e4a6917e',
#    'MKR_USD_0xa16a3cbc92d77b720a851d33a91890c4fbfb0299',
#    'MKR_TRIBE_0xe83bad50c0b3f58ded74ecd67f001337e319075f',
#    'MKR_USDT_0xb5f8d230523c4bdcd00603ee354921441fde39b4',
#    'MKR_WETH_0x886072a44bdd944495eff38ace8ce75c1eacdaf6',
#    'MKR_USDT_0x0cbe2f86e2fd90040ebb557b99f83400bf8f3717',
#    'MKR_USDC_0x936198fcac6d8cdec3815f24ba250041f593f6c3'],
#   'MKR_WETH_0x886072a44bdd944495eff38ace8ce75c1eacdaf6': ['GP_WETH_0x7e3a3a525d9d265d11d1d1db3cad678746b47d09',
#    'TFT_WETH_0x43c4ea688e53aef3aab172b537b5df6d82f4c4dc',
#    'PUNKS_WETH_0xa80ccc104349d2ee29998c54d6e6488012f8afe0',
#    'DSD_WETH_0x7206ae46531093cf2dbbab4c74ac6135e6535a91',
#    'WETH_CRT_0xe8202cccda10a211cc9a5d6a0157fb47ba2ab157',
#    'KCC_WETH_0xec3f403b6b23462d8d657a6a24aef59d3cd622b9',
#    'tiger_WETH_0x207a0856d0cc2648260d05dc5cb3ba78bd5022f9',
#    'EGOD_WETH_0xfb57be17b95872fcea940ddfe98dcecdf2ac8377',
#    'JZo2o_WETH_0xcee2e90275af0aa1ac425dd8a41e3857f7acc6ba',
#    'USDC_WETH_0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640',
#    'MKR_WETH_0xe8c6c9227491c0a8156a0106a0204d881bb7e531',
#    'MKR_WETH_0x3afdc5e6dfc0b0a507a8e023c9dce2cafc310316',
#    'MKR_WETH_0xc2adda861f89bbb333c90c492cb837741916a225',
#    'MKR_WETH_0xba13afecda9beb75de5c56bbaf696b880a5a50dd',
#    'RNG_MKR_0xa82656f9e5405af0d80539f7831c8ef3fe4c5bef',
#    'DAI_MKR_0x2a84e2bd2e961b1557d6e516ca647268b432cba4',
#    'MKR_USDC_0xc486ad2764d55c7dc033487d634195d6e4a6917e',
#    'MKR_USD_0xa16a3cbc92d77b720a851d33a91890c4fbfb0299',
#    'MKR_TRIBE_0xe83bad50c0b3f58ded74ecd67f001337e319075f',
#    'MKR_USDT_0xb5f8d230523c4bdcd00603ee354921441fde39b4',
#    'MKR_WETH_0x886072a44bdd944495eff38ace8ce75c1eacdaf6',
#    'MKR_USDT_0x0cbe2f86e2fd90040ebb557b99f83400bf8f3717',
#    'MKR_USDC_0x936198fcac6d8cdec3815f24ba250041f593f6c3'],
#   'MKR_USDT_0x0cbe2f86e2fd90040ebb557b99f83400bf8f3717': ['rtx_USDT_0xb38e41aadd80eef03e1c86a7c106d6d3a25e3a75',
#    'ULST_USDT_0xb529b1d2f108de61415466b81e2cd2aa1c958ca2',
#    'MKR_WETH_0xe8c6c9227491c0a8156a0106a0204d881bb7e531',
#    'MKR_WETH_0x3afdc5e6dfc0b0a507a8e023c9dce2cafc310316',
#    'MKR_WETH_0xc2adda861f89bbb333c90c492cb837741916a225',
#    'MKR_WETH_0xba13afecda9beb75de5c56bbaf696b880a5a50dd',
#    'RNG_MKR_0xa82656f9e5405af0d80539f7831c8ef3fe4c5bef',
#    'DAI_MKR_0x2a84e2bd2e961b1557d6e516ca647268b432cba4',
#    'MKR_USDC_0xc486ad2764d55c7dc033487d634195d6e4a6917e',
#    'MKR_USD_0xa16a3cbc92d77b720a851d33a91890c4fbfb0299',
#    'MKR_TRIBE_0xe83bad50c0b3f58ded74ecd67f001337e319075f',
#    'MKR_USDT_0xb5f8d230523c4bdcd00603ee354921441fde39b4',
#    'MKR_WETH_0x886072a44bdd944495eff38ace8ce75c1eacdaf6',
#    'MKR_USDT_0x0cbe2f86e2fd90040ebb557b99f83400bf8f3717',
#    'MKR_USDC_0x936198fcac6d8cdec3815f24ba250041f593f6c3'],
#   'MKR_USDC_0x936198fcac6d8cdec3815f24ba250041f593f6c3': ['USDT_USDC_0x86b32fa55943c9af8c12961d8d2ad7040eeb2f2f',
#    'FRAX_USDC_0xdcef968d416a41cdac0ed8702fac8128a64241a2',
#    'USDC_WETH_0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640',
#    'MKR_WETH_0xe8c6c9227491c0a8156a0106a0204d881bb7e531',
#    'MKR_WETH_0x3afdc5e6dfc0b0a507a8e023c9dce2cafc310316',
#    'MKR_WETH_0xc2adda861f89bbb333c90c492cb837741916a225',
#    'MKR_WETH_0xba13afecda9beb75de5c56bbaf696b880a5a50dd',
#    'RNG_MKR_0xa82656f9e5405af0d80539f7831c8ef3fe4c5bef',
#    'DAI_MKR_0x2a84e2bd2e961b1557d6e516ca647268b432cba4',
#    'MKR_USDC_0xc486ad2764d55c7dc033487d634195d6e4a6917e',
#    'MKR_USD_0xa16a3cbc92d77b720a851d33a91890c4fbfb0299',
#    'MKR_TRIBE_0xe83bad50c0b3f58ded74ecd67f001337e319075f',
#    'MKR_USDT_0xb5f8d230523c4bdcd00603ee354921441fde39b4',
#    'MKR_WETH_0x886072a44bdd944495eff38ace8ce75c1eacdaf6',
#    'MKR_USDT_0x0cbe2f86e2fd90040ebb557b99f83400bf8f3717',
#    'MKR_USDC_0x936198fcac6d8cdec3815f24ba250041f593f6c3']},
#  'path_graph': {'MKR_USDC_0xc486ad2764d55c7dc033487d634195d6e4a6917e': ['MKR_WETH_0xe8c6c9227491c0a8156a0106a0204d881bb7e531',
#    'MKR_WETH_0x3afdc5e6dfc0b0a507a8e023c9dce2cafc310316',
#    'MKR_WETH_0xc2adda861f89bbb333c90c492cb837741916a225',
#    'MKR_WETH_0xba13afecda9beb75de5c56bbaf696b880a5a50dd',
#    'RNG_MKR_0xa82656f9e5405af0d80539f7831c8ef3fe4c5bef',
#    'DAI_MKR_0x2a84e2bd2e961b1557d6e516ca647268b432cba4',
#    'USDT_USDC_0x86b32fa55943c9af8c12961d8d2ad7040eeb2f2f',
#    'FRAX_USDC_0xdcef968d416a41cdac0ed8702fac8128a64241a2',
#    'USDC_WETH_0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640',
#    'MKR_USDC_0x936198fcac6d8cdec3815f24ba250041f593f6c3',
#    'MKR_USD_0xa16a3cbc92d77b720a851d33a91890c4fbfb0299',
#    'MKR_TRIBE_0xe83bad50c0b3f58ded74ecd67f001337e319075f',
#    'MKR_USDT_0xb5f8d230523c4bdcd00603ee354921441fde39b4',
#    'MKR_WETH_0x886072a44bdd944495eff38ace8ce75c1eacdaf6',
#    'MKR_USDT_0x0cbe2f86e2fd90040ebb557b99f83400bf8f3717'],
#   'MKR_USDC_0x936198fcac6d8cdec3815f24ba250041f593f6c3': ['MKR_WETH_0xe8c6c9227491c0a8156a0106a0204d881bb7e531',
#    'MKR_WETH_0x3afdc5e6dfc0b0a507a8e023c9dce2cafc310316',
#    'MKR_WETH_0xc2adda861f89bbb333c90c492cb837741916a225',
#    'MKR_WETH_0xba13afecda9beb75de5c56bbaf696b880a5a50dd',
#    'RNG_MKR_0xa82656f9e5405af0d80539f7831c8ef3fe4c5bef',
#    'DAI_MKR_0x2a84e2bd2e961b1557d6e516ca647268b432cba4',
#    'MKR_USDC_0xc486ad2764d55c7dc033487d634195d6e4a6917e',
#    'MKR_USD_0xa16a3cbc92d77b720a851d33a91890c4fbfb0299',
#    'MKR_TRIBE_0xe83bad50c0b3f58ded74ecd67f001337e319075f',
#    'MKR_USDT_0xb5f8d230523c4bdcd00603ee354921441fde39b4',
#    'MKR_WETH_0x886072a44bdd944495eff38ace8ce75c1eacdaf6',
#    'MKR_USDT_0x0cbe2f86e2fd90040ebb557b99f83400bf8f3717',
#    'USDT_USDC_0x86b32fa55943c9af8c12961d8d2ad7040eeb2f2f',
#    'FRAX_USDC_0xdcef968d416a41cdac0ed8702fac8128a64241a2',
#    'USDC_WETH_0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640'],
#   'MKR_WETH_0xe8c6c9227491c0a8156a0106a0204d881bb7e531': ['USDC_WETH_0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640',
#    'MKR_USDC_0xc486ad2764d55c7dc033487d634195d6e4a6917e',
#    'MKR_USDC_0x936198fcac6d8cdec3815f24ba250041f593f6c3',
#    'RNG_MKR_0xa82656f9e5405af0d80539f7831c8ef3fe4c5bef',
#    'DAI_MKR_0x2a84e2bd2e961b1557d6e516ca647268b432cba4',
#    'MKR_USD_0xa16a3cbc92d77b720a851d33a91890c4fbfb0299',
#    'MKR_TRIBE_0xe83bad50c0b3f58ded74ecd67f001337e319075f',
#    'MKR_USDT_0xb5f8d230523c4bdcd00603ee354921441fde39b4',
#    'MKR_USDT_0x0cbe2f86e2fd90040ebb557b99f83400bf8f3717'],
#   'USDC_WETH_0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640': ['MKR_WETH_0xe8c6c9227491c0a8156a0106a0204d881bb7e531',
#    'MKR_WETH_0x3afdc5e6dfc0b0a507a8e023c9dce2cafc310316',
#    'MKR_WETH_0xc2adda861f89bbb333c90c492cb837741916a225',
#    'MKR_WETH_0xba13afecda9beb75de5c56bbaf696b880a5a50dd',
#    'MKR_USDC_0xc486ad2764d55c7dc033487d634195d6e4a6917e',
#    'MKR_WETH_0x886072a44bdd944495eff38ace8ce75c1eacdaf6',
#    'MKR_USDC_0x936198fcac6d8cdec3815f24ba250041f593f6c3',
#    'USDT_USDC_0x86b32fa55943c9af8c12961d8d2ad7040eeb2f2f',
#    'FRAX_USDC_0xdcef968d416a41cdac0ed8702fac8128a64241a2'],
#   'MKR_WETH_0x3afdc5e6dfc0b0a507a8e023c9dce2cafc310316': ['USDC_WETH_0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640',
#    'MKR_USDC_0xc486ad2764d55c7dc033487d634195d6e4a6917e',
#    'MKR_USDC_0x936198fcac6d8cdec3815f24ba250041f593f6c3'],
#   'MKR_WETH_0xc2adda861f89bbb333c90c492cb837741916a225': ['USDC_WETH_0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640',
#    'MKR_USDC_0xc486ad2764d55c7dc033487d634195d6e4a6917e',
#    'MKR_USDC_0x936198fcac6d8cdec3815f24ba250041f593f6c3'],
#   'MKR_WETH_0xba13afecda9beb75de5c56bbaf696b880a5a50dd': ['USDC_WETH_0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640',
#    'MKR_USDC_0xc486ad2764d55c7dc033487d634195d6e4a6917e',
#    'MKR_USDC_0x936198fcac6d8cdec3815f24ba250041f593f6c3'],
#   'RNG_MKR_0xa82656f9e5405af0d80539f7831c8ef3fe4c5bef': ['MKR_USDC_0xc486ad2764d55c7dc033487d634195d6e4a6917e',
#    'MKR_USDC_0x936198fcac6d8cdec3815f24ba250041f593f6c3',
#    'MKR_WETH_0xe8c6c9227491c0a8156a0106a0204d881bb7e531'],
#   'DAI_MKR_0x2a84e2bd2e961b1557d6e516ca647268b432cba4': ['MKR_USDC_0xc486ad2764d55c7dc033487d634195d6e4a6917e',
#    'MKR_USDC_0x936198fcac6d8cdec3815f24ba250041f593f6c3',
#    'MKR_WETH_0xe8c6c9227491c0a8156a0106a0204d881bb7e531'],
#   'USDT_USDC_0x86b32fa55943c9af8c12961d8d2ad7040eeb2f2f': ['MKR_USDC_0xc486ad2764d55c7dc033487d634195d6e4a6917e',
#    'MKR_USDC_0x936198fcac6d8cdec3815f24ba250041f593f6c3',
#    'USDC_WETH_0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640'],
#   'FRAX_USDC_0xdcef968d416a41cdac0ed8702fac8128a64241a2': ['MKR_USDC_0xc486ad2764d55c7dc033487d634195d6e4a6917e',
#    'MKR_USDC_0x936198fcac6d8cdec3815f24ba250041f593f6c3',
#    'USDC_WETH_0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640'],
#   'MKR_USD_0xa16a3cbc92d77b720a851d33a91890c4fbfb0299': ['MKR_USDC_0xc486ad2764d55c7dc033487d634195d6e4a6917e',
#    'MKR_USDC_0x936198fcac6d8cdec3815f24ba250041f593f6c3',
#    'MKR_WETH_0xe8c6c9227491c0a8156a0106a0204d881bb7e531'],
#   'MKR_TRIBE_0xe83bad50c0b3f58ded74ecd67f001337e319075f': ['MKR_USDC_0xc486ad2764d55c7dc033487d634195d6e4a6917e',
#    'MKR_USDC_0x936198fcac6d8cdec3815f24ba250041f593f6c3',
#    'MKR_WETH_0xe8c6c9227491c0a8156a0106a0204d881bb7e531'],
#   'MKR_USDT_0xb5f8d230523c4bdcd00603ee354921441fde39b4': ['MKR_USDC_0xc486ad2764d55c7dc033487d634195d6e4a6917e',
#    'MKR_USDC_0x936198fcac6d8cdec3815f24ba250041f593f6c3',
#    'MKR_WETH_0xe8c6c9227491c0a8156a0106a0204d881bb7e531'],
#   'MKR_WETH_0x886072a44bdd944495eff38ace8ce75c1eacdaf6': ['USDC_WETH_0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640',
#    'MKR_USDC_0xc486ad2764d55c7dc033487d634195d6e4a6917e',
#    'MKR_USDC_0x936198fcac6d8cdec3815f24ba250041f593f6c3'],
#   'MKR_USDT_0x0cbe2f86e2fd90040ebb557b99f83400bf8f3717': ['MKR_USDC_0xc486ad2764d55c7dc033487d634195d6e4a6917e',
#    'MKR_USDC_0x936198fcac6d8cdec3815f24ba250041f593f6c3',
#    'MKR_WETH_0xe8c6c9227491c0a8156a0106a0204d881bb7e531']},
#  'routes': [('route_8',
#    {'swap_0': {'pool': 'MKR_WETH_0xe8c6c9227491c0a8156a0106a0204d881bb7e531',
#      'exchange': 'Uniswap_V3',
#      'dangerous': False,
#      'input_token': 'MKR',
#      'input_amount': 100,
#      'input_amount_usd': 254650.06950639523,
#      'output_token': 'WETH',
#      'output_amount': 33.76670726268958,
#      'output_amount_usd': 248575.01003307817,
#      'price_impact': 2.3856500353966914,
#      'price': 2.9614969331195256,
#      'price_usd': 55516725.062558204,
#      'gas_fee': 0.001008558644457,
#      'description': 'Sell 100 MKR for WETH in Uniswap V3 0xe8c6c9227491c0a8156a0106a0204d881bb7e531\n    \nExpected return: 33.76670726268958 WETH\n    \nPrice impact: 2.3856500353966914%\n    '},
#     'swap_1': {'pool': 'USDC_WETH_0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640',
#      'exchange': 'Uniswap_V3',
#      'dangerous': False,
#      'input_token': 'WETH',
#      'input_amount': 33.76670726268958,
#      'input_amount_usd': 28490.449600939042,
#      'output_token': 'USDC',
#      'output_amount': 60876.154873132706,
#      'output_amount_usd': 28488.565305980563,
#      'price_impact': 0.006613777546071731,
#      'price': 0.0005546787134151322,
#      'price_usd': 0.21901580428950115,
#      'gas_fee': 0.001008558644457,
#      'description': 'Sell 33.76670726268958 WETH for USDC in Uniswap V3 0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640\n    \nExpected return: 60876.154873132706 USDC\n    \nPrice impact: 0.006613777546071731%\n    '},
#     'swap_2': {'pool': 'USDT_USDC_0x86b32fa55943c9af8c12961d8d2ad7040eeb2f2f',
#      'exchange': 'DODO',
#      'dangerous': False,
#      'input_token': 'USDC',
#      'input_amount': 60876.154873132706,
#      'input_amount_usd': 60871.42009064679,
#      'output_token': 'USDT',
#      'output_amount': 60870.03019,
#      'output_amount_usd': 60875.59445152921,
#      'price_impact': 6.341866246595274e-05,
#      'price': 1.000100619025711,
#      'price_usd': 1.0001142481646244,
#      'gas_fee': 0.001008558644457,
#      'description': 'Sell 60876.154873132706 USDC for USDT in DODO 0x86b32fa55943c9af8c12961d8d2ad7040eeb2f2f\nExpected return: 60870.03019 USDT\nPrice impact: 6.341866246595274e-05%'},
#     'amount_in': 100,
#     'amount_in_usd': 736154.1298631163,
#     'amount_out': 60870.03019,
#     'amount_out_usd': 60875.59445152921,
#     'price': 0.0016428445934371897,
#     'price_usd': 1.0000914121696973,
#     'gas_fee': 0.003025675933371,
#     'path': ['MKR_WETH_0xe8c6c9227491c0a8156a0106a0204d881bb7e531',
#      'USDC_WETH_0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640',
#      'USDT_USDC_0x86b32fa55943c9af8c12961d8d2ad7040eeb2f2f'],
#     'price_impact': 2.392327231605229}),
#   ('route_9',
#    {'swap_0': {'pool': 'MKR_WETH_0xe8c6c9227491c0a8156a0106a0204d881bb7e531',
#      'exchange': 'Uniswap_V3',
#      'dangerous': False,
#      'input_token': 'MKR',
#      'input_amount': 100,
#      'input_amount_usd': 254650.06950639523,
#      'output_token': 'WETH',
#      'output_amount': 33.76670726268958,
#      'output_amount_usd': 248575.01003307817,
#      'price_impact': 2.3856500353966914,
#      'price': 2.9614969331195256,
#      'price_usd': 55516725.062558204,
#      'gas_fee': 0.001008558644457,
#      'description': 'Sell 100 MKR for WETH in Uniswap V3 0xe8c6c9227491c0a8156a0106a0204d881bb7e531\n    \nExpected return: 33.76670726268958 WETH\n    \nPrice impact: 2.3856500353966914%\n    '},
#     'swap_1': {'pool': 'USDC_WETH_0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640',
#      'exchange': 'Uniswap_V3',
#      'dangerous': False,
#      'input_token': 'WETH',
#      'input_amount': 33.76670726268958,
#      'input_amount_usd': 28490.449600939042,
#      'output_token': 'USDC',
#      'output_amount': 60876.154873132706,
#      'output_amount_usd': 28488.565305980563,
#      'price_impact': 0.006613777546071731,
#      'price': 0.0005546787134151322,
#      'price_usd': 0.21901580428950115,
#      'gas_fee': 0.001008558644457,
#      'description': 'Sell 33.76670726268958 WETH for USDC in Uniswap V3 0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640\n    \nExpected return: 60876.154873132706 USDC\n    \nPrice impact: 0.006613777546071731%\n    '},
#     'swap_2': {'pool': 'FRAX_USDC_0xdcef968d416a41cdac0ed8702fac8128a64241a2',
#      'exchange': 'Curve',
#      'dangerous': False,
#      'input_token': 'USDC',
#      'input_amount': 60876.154873132706,
#      'input_amount_usd': 60863.37088060934,
#      'output_token': 'FRAX',
#      'output_amount': 60914.022878507574,
#      'output_amount_usd': 60863.37088060934,
#      'price_impact': 0.0,
#      'price': 0.9993783368166244,
#      'price_usd': 0.9983376261783072,
#      'gas_fee': 0.001008558644457,
#      'description': 'Sell 60876.154873132706 USDC for FRAX in Curve 0xdcef968d416a41cdac0ed8702fac8128a64241a2\n    \nExpected return: 60914.022878507574 FRAX\n    \nPrice impact: 0.0%\n    '},
#     'amount_in': 100,
#     'amount_in_usd': 736154.1298631163,
#     'amount_out': 60914.022878507574,
#     'amount_out_usd': 60863.37088060934,
#     'price': 0.0016416581153973204,
#     'price_usd': 0.9991684673658928,
#     'gas_fee': 0.003025675933371,
#     'path': ['MKR_WETH_0xe8c6c9227491c0a8156a0106a0204d881bb7e531',
#      'USDC_WETH_0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640',
#      'FRAX_USDC_0xdcef968d416a41cdac0ed8702fac8128a64241a2'],
#     'price_impact': 2.392263812942763}),
#   ('route_12',
#    {'swap_0': {'pool': 'MKR_WETH_0xc2adda861f89bbb333c90c492cb837741916a225',
#      'exchange': 'Uniswap_V2',
#      'dangerous': False,
#      'input_token': 'MKR',
#      'input_amount': 100,
#      'input_amount_usd': 124912.27311461946,
#      'output_token': 'WETH',
#      'output_amount': 31.211468249450604,
#      'output_amount_usd': 113131.55601745826,
#      'price_impact': 9.431192630968477,
#      'price': 3.2039505223135487,
#      'price_usd': 14506427.559431907,
#      'gas_fee': 0.001008558644457,
#      'description': 'Sell 100 MKR for WETH in Uniswap V2 0xc2adda861f89bbb333c90c492cb837741916a225\n    \nExpected return: 31.211468249450604 WETH\n    \nPrice impact: 9.431192630968477%\n    '},
#     'swap_1': {'pool': 'USDC_WETH_0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640',
#      'exchange': 'Uniswap_V3',
#      'dangerous': False,
#      'input_token': 'WETH',
#      'input_amount': 31.211468249450604,
#      'input_amount_usd': 26334.48254857921,
#      'output_token': 'USDC',
#      'output_amount': 56269.73544251919,
#      'output_amount_usd': 26332.872636999447,
#      'price_impact': 0.006113321485590184,
#      'price': 0.0005546759373221832,
#      'price_usd': 0.21901470814462431,
#      'gas_fee': 0.001008558644457,
#      'description': 'Sell 31.211468249450604 WETH for USDC in Uniswap V3 0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640\n    \nExpected return: 56269.73544251919 USDC\n    \nPrice impact: 0.006113321485590184%\n    '},
#     'swap_2': {'pool': 'USDT_USDC_0x86b32fa55943c9af8c12961d8d2ad7040eeb2f2f',
#      'exchange': 'DODO',
#      'dangerous': False,
#      'input_token': 'USDC',
#      'input_amount': 56269.73544251919,
#      'input_amount_usd': 56265.35893486335,
#      'output_token': 'USDT',
#      'output_amount': 56264.076797,
#      'output_amount_usd': 56269.22001833603,
#      'price_impact': 5.881393315698702e-05,
#      'price': 1.0001005729737573,
#      'price_usd': 1.0001142021120433,
#      'gas_fee': 0.001008558644457,
#      'description': 'Sell 56269.73544251919 USDC for USDT in DODO 0x86b32fa55943c9af8c12961d8d2ad7040eeb2f2f\nExpected return: 56264.076797 USDT\nPrice impact: 5.881393315698702e-05%'},
#     'amount_in': 100,
#     'amount_in_usd': 362467.90799227986,
#     'amount_out': 56264.076797,
#     'amount_out_usd': 56269.22001833603,
#     'price': 0.001777332992786829,
#     'price_usd': 1.0000914121696973,
#     'gas_fee': 0.003025675933371,
#     'path': ['MKR_WETH_0xc2adda861f89bbb333c90c492cb837741916a225',
#      'USDC_WETH_0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640',
#      'USDT_USDC_0x86b32fa55943c9af8c12961d8d2ad7040eeb2f2f'],
#     'price_impact': 9.437364766387224}),
#   ('route_13',
#    {'swap_0': {'pool': 'MKR_WETH_0xc2adda861f89bbb333c90c492cb837741916a225',
#      'exchange': 'Uniswap_V2',
#      'dangerous': False,
#      'input_token': 'MKR',
#      'input_amount': 100,
#      'input_amount_usd': 124912.27311461946,
#      'output_token': 'WETH',
#      'output_amount': 31.211468249450604,
#      'output_amount_usd': 113131.55601745826,
#      'price_impact': 9.431192630968477,
#      'price': 3.2039505223135487,
#      'price_usd': 14506427.559431907,
#      'gas_fee': 0.001008558644457,
#      'description': 'Sell 100 MKR for WETH in Uniswap V2 0xc2adda861f89bbb333c90c492cb837741916a225\n    \nExpected return: 31.211468249450604 WETH\n    \nPrice impact: 9.431192630968477%\n    '},
#     'swap_1': {'pool': 'USDC_WETH_0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640',
#      'exchange': 'Uniswap_V3',
#      'dangerous': False,
#      'input_token': 'WETH',
#      'input_amount': 31.211468249450604,
#      'input_amount_usd': 26334.48254857921,
#      'output_token': 'USDC',
#      'output_amount': 56269.73544251919,
#      'output_amount_usd': 26332.872636999447,
#      'price_impact': 0.006113321485590184,
#      'price': 0.0005546759373221832,
#      'price_usd': 0.21901470814462431,
#      'gas_fee': 0.001008558644457,
#      'description': 'Sell 31.211468249450604 WETH for USDC in Uniswap V3 0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640\n    \nExpected return: 56269.73544251919 USDC\n    \nPrice impact: 0.006113321485590184%\n    '},
#     'swap_2': {'pool': 'FRAX_USDC_0xdcef968d416a41cdac0ed8702fac8128a64241a2',
#      'exchange': 'Curve',
#      'dangerous': False,
#      'input_token': 'USDC',
#      'input_amount': 56269.73544251919,
#      'input_amount_usd': 56257.91879807626,
#      'output_token': 'FRAX',
#      'output_amount': 56304.73802519906,
#      'output_amount_usd': 56257.91879807625,
#      'price_impact': 0.0,
#      'price': 0.9993783368166244,
#      'price_usd': 0.9983376261783073,
#      'gas_fee': 0.001008558644457,
#      'description': 'Sell 56269.73544251919 USDC for FRAX in Curve 0xdcef968d416a41cdac0ed8702fac8128a64241a2\n    \nExpected return: 56304.73802519906 FRAX\n    \nPrice impact: 0.0%\n    '},
#     'amount_in': 100,
#     'amount_in_usd': 362467.90799227986,
#     'amount_out': 56304.73802519906,
#     'amount_out_usd': 56257.91879807625,
#     'price': 0.0017760494677241056,
#     'price_usd': 0.9991684673658928,
#     'gas_fee': 0.003025675933371,
#     'path': ['MKR_WETH_0xc2adda861f89bbb333c90c492cb837741916a225',
#      'USDC_WETH_0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640',
#      'FRAX_USDC_0xdcef968d416a41cdac0ed8702fac8128a64241a2'],
#     'price_impact': 9.437305952454068}),
#   ('route_0',
#    {'swap_0': {'pool': 'MKR_USDC_0xc486ad2764d55c7dc033487d634195d6e4a6917e',
#      'exchange': 'Uniswap_V3',
#      'dangerous': False,
#      'input_token': 'MKR',
#      'input_amount': 100,
#      'input_amount_usd': 558187.1363728422,
#      'output_token': 'USDC',
#      'output_amount': 6266.289260541243,
#      'output_amount_usd': 55877.37296753924,
#      'price_impact': 89.9894910995914,
#      'price': 0.01595840789375922,
#      'price_usd': 794.3189551366643,
#      'gas_fee': 0.001008558644457,
#      'description': 'Sell 100 MKR for USDC in Uniswap V3 0xc486ad2764d55c7dc033487d634195d6e4a6917e\n    \nExpected return: 6266.289260541243 USDC\n    \nPrice impact: 89.9894910995914%\n    '},
#     'amount_in': 100,
#     'amount_in_usd': 558187.1363728422,
#     'amount_out': 6266.289260541243,
#     'amount_out_usd': 55877.37296753924,
#     'price': 0.01595840789375922,
#     'price_usd': 8.917139098477064,
#     'gas_fee': 0.001008558644457,
#     'path': ['MKR_USDC_0xc486ad2764d55c7dc033487d634195d6e4a6917e'],
#     'price_impact': 89.9894910995914}),
#   ('route_14',
#    {'swap_0': {'pool': 'MKR_WETH_0xba13afecda9beb75de5c56bbaf696b880a5a50dd',
#      'exchange': 'Sushiswap_V2',
#      'dangerous': False,
#      'input_token': 'MKR',
#      'input_amount': 100,
#      'input_amount_usd': 1.2549986654281113e-13,
#      'output_token': 'WETH',
#      'output_amount': 25.631270682474067,
#      'output_amount_usd': 9.270470955933966e-14,
#      'price_impact': 26.13162697849104,
#      'price': 3.901484293885482,
#      'price_usd': 1.7709438332674908e-29,
#      'gas_fee': 0.001008558644457,
#      'description': 'Sell 100 MKR for WETH in Sushiswap V2 0xba13afecda9beb75de5c56bbaf696b880a5a50dd\n    \nExpected return: 25.631270682474067 WETH\n    \nPrice impact: 26.13162697849104%\n    '},
#     'swap_1': {'pool': 'USDC_WETH_0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640',
#      'exchange': 'Uniswap_V3',
#      'dangerous': False,
#      'input_token': 'WETH',
#      'input_amount': 25.631270682474067,
#      'input_amount_usd': 21626.22549797556,
#      'output_token': 'USDC',
#      'output_amount': 46209.95631110668,
#      'output_amount_usd': 21625.13977597623,
#      'price_impact': 0.005020395257748778,
#      'price': 0.000554669874819023,
#      'price_usd': 0.21901231435525848,
#      'gas_fee': 0.001008558644457,
#      'description': 'Sell 25.631270682474067 WETH for USDC in Uniswap V3 0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640\n    \nExpected return: 46209.95631110668 USDC\n    \nPrice impact: 0.005020395257748778%\n    '},
#     'swap_2': {'pool': 'USDT_USDC_0x86b32fa55943c9af8c12961d8d2ad7040eeb2f2f',
#      'exchange': 'DODO',
#      'dangerous': False,
#      'input_token': 'USDC',
#      'input_amount': 46209.95631110668,
#      'input_amount_usd': 46206.362225831865,
#      'output_token': 'USDT',
#      'output_amount': 46205.313956,
#      'output_amount_usd': 46209.537684000265,
#      'price_impact': 4.8749611725185105e-05,
#      'price': 1.0001004723203721,
#      'price_usd': 1.0001141014572863,
#      'gas_fee': 0.001008558644457,
#      'description': 'Sell 46209.95631110668 USDC for USDT in DODO 0x86b32fa55943c9af8c12961d8d2ad7040eeb2f2f\nExpected return: 46205.313956 USDT\nPrice impact: 4.8749611725185105e-05%'},
#     'amount_in': 100,
#     'amount_in_usd': 3.61685968314979e-13,
#     'amount_out': 46205.313956,
#     'amount_out_usd': 46209.537684000265,
#     'price': 0.0021642532305965315,
#     'price_usd': 1.0000914121696973,
#     'gas_fee': 0.003025675933371,
#     'path': ['MKR_WETH_0xba13afecda9beb75de5c56bbaf696b880a5a50dd',
#      'USDC_WETH_0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640',
#      'USDT_USDC_0x86b32fa55943c9af8c12961d8d2ad7040eeb2f2f'],
#     'price_impact': 26.136696123360515}),
#   ('route_15',
#    {'swap_0': {'pool': 'MKR_WETH_0xba13afecda9beb75de5c56bbaf696b880a5a50dd',
#      'exchange': 'Sushiswap_V2',
#      'dangerous': False,
#      'input_token': 'MKR',
#      'input_amount': 100,
#      'input_amount_usd': 1.2549986654281113e-13,
#      'output_token': 'WETH',
#      'output_amount': 25.631270682474067,
#      'output_amount_usd': 9.270470955933966e-14,
#      'price_impact': 26.13162697849104,
#      'price': 3.901484293885482,
#      'price_usd': 1.7709438332674908e-29,
#      'gas_fee': 0.001008558644457,
#      'description': 'Sell 100 MKR for WETH in Sushiswap V2 0xba13afecda9beb75de5c56bbaf696b880a5a50dd\n    \nExpected return: 25.631270682474067 WETH\n    \nPrice impact: 26.13162697849104%\n    '},
#     'swap_1': {'pool': 'USDC_WETH_0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640',
#      'exchange': 'Uniswap_V3',
#      'dangerous': False,
#      'input_token': 'WETH',
#      'input_amount': 25.631270682474067,
#      'input_amount_usd': 21626.22549797556,
#      'output_token': 'USDC',
#      'output_amount': 46209.95631110668,
#      'output_amount_usd': 21625.13977597623,
#      'price_impact': 0.005020395257748778,
#      'price': 0.000554669874819023,
#      'price_usd': 0.21901231435525848,
#      'gas_fee': 0.001008558644457,
#      'description': 'Sell 25.631270682474067 WETH for USDC in Uniswap V3 0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640\n    \nExpected return: 46209.95631110668 USDC\n    \nPrice impact: 0.005020395257748778%\n    '},
#     'swap_2': {'pool': 'FRAX_USDC_0xdcef968d416a41cdac0ed8702fac8128a64241a2',
#      'exchange': 'Curve',
#      'dangerous': False,
#      'input_token': 'USDC',
#      'input_amount': 46209.95631110668,
#      'input_amount_usd': 46200.25222028135,
#      'output_token': 'FRAX',
#      'output_amount': 46238.70120929561,
#      'output_amount_usd': 46200.25222028135,
#      'price_impact': 0.0,
#      'price': 0.9993783368166244,
#      'price_usd': 0.9983376261783073,
#      'gas_fee': 0.001008558644457,
#      'description': 'Sell 46209.95631110668 USDC for FRAX in Curve 0xdcef968d416a41cdac0ed8702fac8128a64241a2\n    \nExpected return: 46238.70120929561 FRAX\n    \nPrice impact: 0.0%\n    '},
#     'amount_in': 100,
#     'amount_in_usd': 3.61685968314979e-13,
#     'amount_out': 46238.70120929561,
#     'amount_out_usd': 46200.25222028135,
#     'price': 0.0021626905035104335,
#     'price_usd': 0.9991684673658928,
#     'gas_fee': 0.003025675933371,
#     'path': ['MKR_WETH_0xba13afecda9beb75de5c56bbaf696b880a5a50dd',
#      'USDC_WETH_0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640',
#      'FRAX_USDC_0xdcef968d416a41cdac0ed8702fac8128a64241a2'],
#     'price_impact': 26.13664737374879}),
#   ('route_1',
#    {'swap_0': {'pool': 'MKR_WETH_0xe8c6c9227491c0a8156a0106a0204d881bb7e531',
#      'exchange': 'Uniswap_V3',
#      'dangerous': False,
#      'input_token': 'MKR',
#      'input_amount': 100,
#      'input_amount_usd': 254650.06950639523,
#      'output_token': 'WETH',
#      'output_amount': 33.76670726268958,
#      'output_amount_usd': 248575.01003307817,
#      'price_impact': 2.3856500353966914,
#      'price': 2.9614969331195256,
#      'price_usd': 55516725.062558204,
#      'gas_fee': 0.001008558644457,
#      'description': 'Sell 100 MKR for WETH in Uniswap V3 0xe8c6c9227491c0a8156a0106a0204d881bb7e531\n    \nExpected return: 33.76670726268958 WETH\n    \nPrice impact: 2.3856500353966914%\n    '},
#     'swap_1': {'pool': 'USDC_WETH_0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640',
#      'exchange': 'Uniswap_V3',
#      'dangerous': False,
#      'input_token': 'WETH',
#      'input_amount': 33.76670726268958,
#      'input_amount_usd': 28490.449600939042,
#      'output_token': 'USDC',
#      'output_amount': 60876.154873132706,
#      'output_amount_usd': 28488.565305980563,
#      'price_impact': 0.006613777546071731,
#      'price': 0.0005546787134151322,
#      'price_usd': 0.21901580428950115,
#      'gas_fee': 0.001008558644457,
#      'description': 'Sell 33.76670726268958 WETH for USDC in Uniswap V3 0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640\n    \nExpected return: 60876.154873132706 USDC\n    \nPrice impact: 0.006613777546071731%\n    '},
#     'amount_in': 100,
#     'amount_in_usd': 736154.1298631163,
#     'amount_out': 60876.154873132706,
#     'amount_out_usd': 28488.565305980563,
#     'price': 0.0016426793086455982,
#     'price_usd': 0.46797576761133125,
#     'gas_fee': 0.002017117288914,
#     'path': ['MKR_WETH_0xe8c6c9227491c0a8156a0106a0204d881bb7e531',
#      'USDC_WETH_0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640'],
#     'price_impact': 2.392263812942763}),
#   ('route_3',
#    {'swap_0': {'pool': 'MKR_WETH_0xc2adda861f89bbb333c90c492cb837741916a225',
#      'exchange': 'Uniswap_V2',
#      'dangerous': False,
#      'input_token': 'MKR',
#      'input_amount': 100,
#      'input_amount_usd': 124912.27311461946,
#      'output_token': 'WETH',
#      'output_amount': 31.211468249450604,
#      'output_amount_usd': 113131.55601745826,
#      'price_impact': 9.431192630968477,
#      'price': 3.2039505223135487,
#      'price_usd': 14506427.559431907,
#      'gas_fee': 0.001008558644457,
#      'description': 'Sell 100 MKR for WETH in Uniswap V2 0xc2adda861f89bbb333c90c492cb837741916a225\n    \nExpected return: 31.211468249450604 WETH\n    \nPrice impact: 9.431192630968477%\n    '},
#     'swap_1': {'pool': 'USDC_WETH_0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640',
#      'exchange': 'Uniswap_V3',
#      'dangerous': False,
#      'input_token': 'WETH',
#      'input_amount': 31.211468249450604,
#      'input_amount_usd': 26334.48254857921,
#      'output_token': 'USDC',
#      'output_amount': 56269.73544251919,
#      'output_amount_usd': 26332.872636999447,
#      'price_impact': 0.006113321485590184,
#      'price': 0.0005546759373221832,
#      'price_usd': 0.21901470814462431,
#      'gas_fee': 0.001008558644457,
#      'description': 'Sell 31.211468249450604 WETH for USDC in Uniswap V3 0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640\n    \nExpected return: 56269.73544251919 USDC\n    \nPrice impact: 0.006113321485590184%\n    '},
#     'amount_in': 100,
#     'amount_in_usd': 362467.90799227986,
#     'amount_out': 56269.73544251919,
#     'amount_out_usd': 26332.872636999447,
#     'price': 0.001777154259098166,
#     'price_usd': 0.46797576761133125,
#     'gas_fee': 0.002017117288914,
#     'path': ['MKR_WETH_0xc2adda861f89bbb333c90c492cb837741916a225',
#      'USDC_WETH_0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640'],
#     'price_impact': 9.437305952454068}),
#   ('route_4',
#    {'swap_0': {'pool': 'MKR_WETH_0xba13afecda9beb75de5c56bbaf696b880a5a50dd',
#      'exchange': 'Sushiswap_V2',
#      'dangerous': False,
#      'input_token': 'MKR',
#      'input_amount': 100,
#      'input_amount_usd': 1.2549986654281113e-13,
#      'output_token': 'WETH',
#      'output_amount': 25.631270682474067,
#      'output_amount_usd': 9.270470955933966e-14,
#      'price_impact': 26.13162697849104,
#      'price': 3.901484293885482,
#      'price_usd': 1.7709438332674908e-29,
#      'gas_fee': 0.001008558644457,
#      'description': 'Sell 100 MKR for WETH in Sushiswap V2 0xba13afecda9beb75de5c56bbaf696b880a5a50dd\n    \nExpected return: 25.631270682474067 WETH\n    \nPrice impact: 26.13162697849104%\n    '},
#     'swap_1': {'pool': 'USDC_WETH_0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640',
#      'exchange': 'Uniswap_V3',
#      'dangerous': False,
#      'input_token': 'WETH',
#      'input_amount': 25.631270682474067,
#      'input_amount_usd': 21626.22549797556,
#      'output_token': 'USDC',
#      'output_amount': 46209.95631110668,
#      'output_amount_usd': 21625.13977597623,
#      'price_impact': 0.005020395257748778,
#      'price': 0.000554669874819023,
#      'price_usd': 0.21901231435525848,
#      'gas_fee': 0.001008558644457,
#      'description': 'Sell 25.631270682474067 WETH for USDC in Uniswap V3 0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640\n    \nExpected return: 46209.95631110668 USDC\n    \nPrice impact: 0.005020395257748778%\n    '},
#     'amount_in': 100,
#     'amount_in_usd': 3.61685968314979e-13,
#     'amount_out': 46209.95631110668,
#     'amount_out_usd': 21625.13977597623,
#     'price': 0.002164035804897845,
#     'price_usd': 0.46797576761133125,
#     'gas_fee': 0.002017117288914,
#     'path': ['MKR_WETH_0xba13afecda9beb75de5c56bbaf696b880a5a50dd',
#      'USDC_WETH_0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640'],
#     'price_impact': 26.13664737374879})]}

# %%
split = route_orders("MKR", "0x9f8f72aa9304c8b593d555f12ef6589cc3a579a2", 100, "USDC", "0xA0b86991c6218b36c1d19D4a2e9Eb0cE3606eB48", ('Uniswap_V2', 'Uniswap_V3', 'Sushiswap_V2', 'Curve', 'DODO', 'PancakeSwap_V3'), split=True, routing_strategy='best_match')
# Out:
# {'actual_return': 60876.154873132706, 'price_impact': 0.006613777546071731, 'buy_symbol': 'USDC', 'description': 'Sell 33.76670726268958 WETH for USDC in Uniswap V3 0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640\n    \nExpected return: 60876.154873132706 USDC\n    \nPrice impact: 0.006613777546071731%\n    '}
# values type:<class 'dict'>
# Sell token not accepted by pool: 0xc486ad2764d55c7dc033487d634195d6e4a6917e
# 0xc486ad2764d55c7dc033487d634195d6e4a6917e
# values type:<class 'str'>
# string indices must be integers
# Sell token not accepted by pool: 0x936198fcac6d8cdec3815f24ba250041f593f6c3
# 0x936198fcac6d8cdec3815f24ba250041f593f6c3
# values type:<class 'str'>
# string indices must be integers
# {'actual_return': 6915.227019309998, 'price_impact': 0.0007512925106589741, 'buy_symbol': 'USDC', 'description': 'Sell 3.835504355303116 WETH for USDC in Uniswap V3 0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640\n    \nExpected return: 6915.227019309998 USDC\n    \nPrice impact: 0.0007512925106589741%\n    '}
# values type:<class 'dict'>
# Sell token not accepted by pool: 0xc486ad2764d55c7dc033487d634195d6e4a6917e
# 0xc486ad2764d55c7dc033487d634195d6e4a6917e
# values type:<class 'str'>
# string indices must be integers
# Sell token not accepted by pool: 0x936198fcac6d8cdec3815f24ba250041f593f6c3
# 0x936198fcac6d8cdec3815f24ba250041f593f6c3
# values type:<class 'str'>
# string indices must be integers
# {'actual_return': 56269.73544251919, 'price_impact': 0.006113321485590184, 'buy_symbol': 'USDC', 'description': 'Sell 31.211468249450604 WETH for USDC in Uniswap V3 0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640\n    \nExpected return: 56269.73544251919 USDC\n    \nPrice impact: 0.006113321485590184%\n    '}
# values type:<class 'dict'>
# Sell token not accepted by pool: 0xc486ad2764d55c7dc033487d634195d6e4a6917e
# 0xc486ad2764d55c7dc033487d634195d6e4a6917e
# values type:<class 'str'>
# string indices must be integers
# Sell token not accepted by pool: 0x936198fcac6d8cdec3815f24ba250041f593f6c3
# 0x936198fcac6d8cdec3815f24ba250041f593f6c3
# values type:<class 'str'>
# string indices must be integers
# {'actual_return': 46209.95631110668, 'price_impact': 0.005020395257748778, 'buy_symbol': 'USDC', 'description': 'Sell 25.631270682474067 WETH for USDC in Uniswap V3 0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640\n    \nExpected return: 46209.95631110668 USDC\n    \nPrice impact: 0.005020395257748778%\n    '}
# values type:<class 'dict'>
# Sell token not accepted by pool: 0xc486ad2764d55c7dc033487d634195d6e4a6917e
# 0xc486ad2764d55c7dc033487d634195d6e4a6917e
# values type:<class 'str'>
# string indices must be integers
# Sell token not accepted by pool: 0x936198fcac6d8cdec3815f24ba250041f593f6c3
# 0x936198fcac6d8cdec3815f24ba250041f593f6c3
# values type:<class 'str'>
# string indices must be integers
# Sell token not accepted by pool: 0xc486ad2764d55c7dc033487d634195d6e4a6917e
# 0xc486ad2764d55c7dc033487d634195d6e4a6917e
# values type:<class 'str'>
# string indices must be integers
# Sell token not accepted by pool: 0x936198fcac6d8cdec3815f24ba250041f593f6c3
# 0x936198fcac6d8cdec3815f24ba250041f593f6c3
# values type:<class 'str'>
# string indices must be integers
# Sell token not accepted by pool: 0xc486ad2764d55c7dc033487d634195d6e4a6917e
# 0xc486ad2764d55c7dc033487d634195d6e4a6917e
# values type:<class 'str'>
# string indices must be integers
# Sell token not accepted by pool: 0x936198fcac6d8cdec3815f24ba250041f593f6c3
# 0x936198fcac6d8cdec3815f24ba250041f593f6c3
# values type:<class 'str'>
# string indices must be integers
# Calculating price impact for DODO pool: 0x86b32fa55943c9af8c12961d8d2ad7040eeb2f2f
#
# {'actual_return': 6265.662239, 'price_impact': 8.788460026387668e-06, 'buy_symbol': 'USDT', 'description': 'Sell 6266.289260541243 USDC for USDT in DODO 0x86b32fa55943c9af8c12961d8d2ad7040eeb2f2f\nExpected return: 6265.662239 USDT\nPrice impact: 8.788460026387668e-06%'}
# values type:<class 'dict'>
# {'actual_return': 6270.187205079514, 'price_impact': 0.0, 'buy_symbol': 'FRAX', 'description': 'Sell 6266.289260541243 USDC for FRAX in Curve 0xdcef968d416a41cdac0ed8702fac8128a64241a2\n    \nExpected return: 6270.187205079514 FRAX\n    \nPrice impact: 0.0%\n    '}
# values type:<class 'dict'>
# {'actual_return': 3.475523723696824, 'price_impact': 0.0006807863146107707, 'buy_symbol': 'WETH', 'description': 'Sell 6266.289260541243 USDC for WETH in Uniswap V3 0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640\n    \nExpected return: 3.475523723696824 WETH\n    \nPrice impact: 0.0006807863146107707%\n    '}
# values type:<class 'dict'>
# {'actual_return': 0.0, 'price_impact': 100.0, 'buy_symbol': 'MKR', 'description': 'Sell 6266.289260541243 USDC for MKR in Uniswap V3 0x936198fcac6d8cdec3815f24ba250041f593f6c3\n    \nExpected return: 0.0 MKR\n    \nPrice impact: 100.0%\n    '}
# values type:<class 'dict'>
# Sell token not accepted by pool: 0xc486ad2764d55c7dc033487d634195d6e4a6917e
# 0xc486ad2764d55c7dc033487d634195d6e4a6917e
# values type:<class 'str'>
# string indices must be integers
# Sell token not accepted by pool: 0x936198fcac6d8cdec3815f24ba250041f593f6c3
# 0x936198fcac6d8cdec3815f24ba250041f593f6c3
# values type:<class 'str'>
# string indices must be integers
# Sell token not accepted by pool: 0xc486ad2764d55c7dc033487d634195d6e4a6917e
# 0xc486ad2764d55c7dc033487d634195d6e4a6917e
# values type:<class 'str'>
# string indices must be integers
# Sell token not accepted by pool: 0x936198fcac6d8cdec3815f24ba250041f593f6c3
# 0x936198fcac6d8cdec3815f24ba250041f593f6c3
# values type:<class 'str'>
# string indices must be integers
# Sell token not accepted by pool: 0xc486ad2764d55c7dc033487d634195d6e4a6917e
# 0xc486ad2764d55c7dc033487d634195d6e4a6917e
# values type:<class 'str'>
# string indices must be integers
# Sell token not accepted by pool: 0x936198fcac6d8cdec3815f24ba250041f593f6c3
# 0x936198fcac6d8cdec3815f24ba250041f593f6c3
# values type:<class 'str'>
# string indices must be integers
# float division by zero
# Sell token not accepted by pool: 0xc486ad2764d55c7dc033487d634195d6e4a6917e
# 0xc486ad2764d55c7dc033487d634195d6e4a6917e
# values type:<class 'str'>
# string indices must be integers
# Sell token not accepted by pool: 0x936198fcac6d8cdec3815f24ba250041f593f6c3
# 0x936198fcac6d8cdec3815f24ba250041f593f6c3
# values type:<class 'str'>
# string indices must be integers
# Sell token not accepted by pool: 0xc486ad2764d55c7dc033487d634195d6e4a6917e
# 0xc486ad2764d55c7dc033487d634195d6e4a6917e
# values type:<class 'str'>
# string indices must be integers
# Sell token not accepted by pool: 0x936198fcac6d8cdec3815f24ba250041f593f6c3
# 0x936198fcac6d8cdec3815f24ba250041f593f6c3
# values type:<class 'str'>
# string indices must be integers
# Calculating price impact for DODO pool: 0x86b32fa55943c9af8c12961d8d2ad7040eeb2f2f
# ValueError float division by zero: 0x86b32fa55943c9af8c12961d8d2ad7040eeb2f2f
#
# {'actual_return': 0, 'price_impact': inf, 'buy_symbol': 'USDT', 'description': 'pool 0x86b32fa55943c9af8c12961d8d2ad7040eeb2f2f is not active'}
# values type:<class 'dict'>
# float division by zero
# float division by zero
# float division by zero
# {'actual_return': 60876.154873132706, 'price_impact': 0.006613777546071731, 'buy_symbol': 'USDC', 'description': 'Sell 33.76670726268958 WETH for USDC in Uniswap V3 0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640\n    \nExpected return: 60876.154873132706 USDC\n    \nPrice impact: 0.006613777546071731%\n    '}
# values type:<class 'dict'>
# Calculating price impact for DODO pool: 0x86b32fa55943c9af8c12961d8d2ad7040eeb2f2f
#
# {'actual_return': 60870.03019, 'price_impact': 6.341866246595274e-05, 'buy_symbol': 'USDT', 'description': 'Sell 60876.154873132706 USDC for USDT in DODO 0x86b32fa55943c9af8c12961d8d2ad7040eeb2f2f\nExpected return: 60870.03019 USDT\nPrice impact: 6.341866246595274e-05%'}
# values type:<class 'dict'>
# {'actual_return': 60876.154873132706, 'price_impact': 0.006613777546071731, 'buy_symbol': 'USDC', 'description': 'Sell 33.76670726268958 WETH for USDC in Uniswap V3 0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640\n    \nExpected return: 60876.154873132706 USDC\n    \nPrice impact: 0.006613777546071731%\n    '}
# values type:<class 'dict'>
# {'actual_return': 60914.022878507574, 'price_impact': 0.0, 'buy_symbol': 'FRAX', 'description': 'Sell 60876.154873132706 USDC for FRAX in Curve 0xdcef968d416a41cdac0ed8702fac8128a64241a2\n    \nExpected return: 60914.022878507574 FRAX\n    \nPrice impact: 0.0%\n    '}
# values type:<class 'dict'>
# {'actual_return': 6915.227019309998, 'price_impact': 0.0007512925106589741, 'buy_symbol': 'USDC', 'description': 'Sell 3.835504355303116 WETH for USDC in Uniswap V3 0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640\n    \nExpected return: 6915.227019309998 USDC\n    \nPrice impact: 0.0007512925106589741%\n    '}
# values type:<class 'dict'>
# Calculating price impact for DODO pool: 0x86b32fa55943c9af8c12961d8d2ad7040eeb2f2f
#
# {'actual_return': 6914.535018, 'price_impact': 9.444087534227208e-06, 'buy_symbol': 'USDT', 'description': 'Sell 6915.227019309998 USDC for USDT in DODO 0x86b32fa55943c9af8c12961d8d2ad7040eeb2f2f\nExpected return: 6914.535018 USDT\nPrice impact: 9.444087534227208e-06%'}
# values type:<class 'dict'>
# {'actual_return': 6915.227019309998, 'price_impact': 0.0007512925106589741, 'buy_symbol': 'USDC', 'description': 'Sell 3.835504355303116 WETH for USDC in Uniswap V3 0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640\n    \nExpected return: 6915.227019309998 USDC\n    \nPrice impact: 0.0007512925106589741%\n    '}
# values type:<class 'dict'>
# {'actual_return': 6919.528635509007, 'price_impact': 0.0, 'buy_symbol': 'FRAX', 'description': 'Sell 6915.227019309998 USDC for FRAX in Curve 0xdcef968d416a41cdac0ed8702fac8128a64241a2\n    \nExpected return: 6919.528635509007 FRAX\n    \nPrice impact: 0.0%\n    '}
# values type:<class 'dict'>
# {'actual_return': 56269.73544251919, 'price_impact': 0.006113321485590184, 'buy_symbol': 'USDC', 'description': 'Sell 31.211468249450604 WETH for USDC in Uniswap V3 0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640\n    \nExpected return: 56269.73544251919 USDC\n    \nPrice impact: 0.006113321485590184%\n    '}
# values type:<class 'dict'>
# Calculating price impact for DODO pool: 0x86b32fa55943c9af8c12961d8d2ad7040eeb2f2f
#
# {'actual_return': 56264.076797, 'price_impact': 5.881393315698702e-05, 'buy_symbol': 'USDT', 'description': 'Sell 56269.73544251919 USDC for USDT in DODO 0x86b32fa55943c9af8c12961d8d2ad7040eeb2f2f\nExpected return: 56264.076797 USDT\nPrice impact: 5.881393315698702e-05%'}
# values type:<class 'dict'>
# {'actual_return': 56269.73544251919, 'price_impact': 0.006113321485590184, 'buy_symbol': 'USDC', 'description': 'Sell 31.211468249450604 WETH for USDC in Uniswap V3 0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640\n    \nExpected return: 56269.73544251919 USDC\n    \nPrice impact: 0.006113321485590184%\n    '}
# values type:<class 'dict'>
# {'actual_return': 56304.73802519906, 'price_impact': 0.0, 'buy_symbol': 'FRAX', 'description': 'Sell 56269.73544251919 USDC for FRAX in Curve 0xdcef968d416a41cdac0ed8702fac8128a64241a2\n    \nExpected return: 56304.73802519906 FRAX\n    \nPrice impact: 0.0%\n    '}
# values type:<class 'dict'>
# {'actual_return': 46209.95631110668, 'price_impact': 0.005020395257748778, 'buy_symbol': 'USDC', 'description': 'Sell 25.631270682474067 WETH for USDC in Uniswap V3 0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640\n    \nExpected return: 46209.95631110668 USDC\n    \nPrice impact: 0.005020395257748778%\n    '}
# values type:<class 'dict'>
# Calculating price impact for DODO pool: 0x86b32fa55943c9af8c12961d8d2ad7040eeb2f2f
#
# {'actual_return': 46205.313956, 'price_impact': 4.8749611725185105e-05, 'buy_symbol': 'USDT', 'description': 'Sell 46209.95631110668 USDC for USDT in DODO 0x86b32fa55943c9af8c12961d8d2ad7040eeb2f2f\nExpected return: 46205.313956 USDT\nPrice impact: 4.8749611725185105e-05%'}
# values type:<class 'dict'>
# {'actual_return': 46209.95631110668, 'price_impact': 0.005020395257748778, 'buy_symbol': 'USDC', 'description': 'Sell 25.631270682474067 WETH for USDC in Uniswap V3 0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640\n    \nExpected return: 46209.95631110668 USDC\n    \nPrice impact: 0.005020395257748778%\n    '}
# values type:<class 'dict'>
# {'actual_return': 46238.70120929561, 'price_impact': 0.0, 'buy_symbol': 'FRAX', 'description': 'Sell 46209.95631110668 USDC for FRAX in Curve 0xdcef968d416a41cdac0ed8702fac8128a64241a2\n    \nExpected return: 46238.70120929561 FRAX\n    \nPrice impact: 0.0%\n    '}
# values type:<class 'dict'>
# Sell token not accepted by pool: 0xc486ad2764d55c7dc033487d634195d6e4a6917e
# 0xc486ad2764d55c7dc033487d634195d6e4a6917e
# values type:<class 'str'>
# string indices must be integers
# Sell token not accepted by pool: 0xc486ad2764d55c7dc033487d634195d6e4a6917e
# 0xc486ad2764d55c7dc033487d634195d6e4a6917e
# values type:<class 'str'>
# string indices must be integers
# Sell token not accepted by pool: 0xe8c6c9227491c0a8156a0106a0204d881bb7e531
# 0xe8c6c9227491c0a8156a0106a0204d881bb7e531
# values type:<class 'str'>
# string indices must be integers
# Sell token not accepted by pool: 0xc486ad2764d55c7dc033487d634195d6e4a6917e
# 0xc486ad2764d55c7dc033487d634195d6e4a6917e
# values type:<class 'str'>
# string indices must be integers
# Sell token not accepted by pool: 0xc486ad2764d55c7dc033487d634195d6e4a6917e
# 0xc486ad2764d55c7dc033487d634195d6e4a6917e
# values type:<class 'str'>
# string indices must be integers
# Sell token not accepted by pool: 0xe8c6c9227491c0a8156a0106a0204d881bb7e531
# 0xe8c6c9227491c0a8156a0106a0204d881bb7e531
# values type:<class 'str'>
# string indices must be integers
# Sell token not accepted by pool: 0xc486ad2764d55c7dc033487d634195d6e4a6917e
# 0xc486ad2764d55c7dc033487d634195d6e4a6917e
# values type:<class 'str'>
# string indices must be integers
# Sell token not accepted by pool: 0xc486ad2764d55c7dc033487d634195d6e4a6917e
# 0xc486ad2764d55c7dc033487d634195d6e4a6917e
# values type:<class 'str'>
# string indices must be integers
# Sell token not accepted by pool: 0xe8c6c9227491c0a8156a0106a0204d881bb7e531
# 0xe8c6c9227491c0a8156a0106a0204d881bb7e531
# values type:<class 'str'>
# string indices must be integers
# Sell token not accepted by pool: 0xc486ad2764d55c7dc033487d634195d6e4a6917e
# 0xc486ad2764d55c7dc033487d634195d6e4a6917e
# values type:<class 'str'>
# string indices must be integers
# Sell token not accepted by pool: 0xc486ad2764d55c7dc033487d634195d6e4a6917e
# 0xc486ad2764d55c7dc033487d634195d6e4a6917e
# values type:<class 'str'>
# string indices must be integers
# Sell token not accepted by pool: 0xe8c6c9227491c0a8156a0106a0204d881bb7e531
# 0xe8c6c9227491c0a8156a0106a0204d881bb7e531
# values type:<class 'str'>
# string indices must be integers
# Sell token not accepted by pool: 0xc486ad2764d55c7dc033487d634195d6e4a6917e
# 0xc486ad2764d55c7dc033487d634195d6e4a6917e
# values type:<class 'str'>
# string indices must be integers
# Sell token not accepted by pool: 0xc486ad2764d55c7dc033487d634195d6e4a6917e
# 0xc486ad2764d55c7dc033487d634195d6e4a6917e
# values type:<class 'str'>
# string indices must be integers
# Sell token not accepted by pool: 0xe8c6c9227491c0a8156a0106a0204d881bb7e531
# 0xe8c6c9227491c0a8156a0106a0204d881bb7e531
# values type:<class 'str'>
# string indices must be integers
# float division by zero
# float division by zero
# Sell token not accepted by pool: 0xc486ad2764d55c7dc033487d634195d6e4a6917e
# 0xc486ad2764d55c7dc033487d634195d6e4a6917e
# values type:<class 'str'>
# string indices must be integers
# Sell token not accepted by pool: 0xc486ad2764d55c7dc033487d634195d6e4a6917e
# 0xc486ad2764d55c7dc033487d634195d6e4a6917e
# values type:<class 'str'>
# string indices must be integers
# Sell token not accepted by pool: 0xe8c6c9227491c0a8156a0106a0204d881bb7e531
# 0xe8c6c9227491c0a8156a0106a0204d881bb7e531
# values type:<class 'str'>
# string indices must be integers
#
# {'swap_0': {'pool': 'MKR_WETH_0xe8c6c9227491c0a8156a0106a0204d881bb7e531', 'exchange': 'Uniswap_V3', 'dangerous': False, 'input_token': 'MKR', 'input_amount': 100, 'input_amount_usd': 254650.06950639523, 'output_token': 'WETH', 'output_amount': 33.76670726268958, 'output_amount_usd': 248575.01003307817, 'price_impact': 2.3856500353966914, 'price': 2.9614969331195256, 'price_usd': 55516725.062558204, 'gas_fee': 0.000836437835961, 'description': 'Sell 100 MKR for WETH in Uniswap V3 0xe8c6c9227491c0a8156a0106a0204d881bb7e531\n    \nExpected return: 33.76670726268958 WETH\n    \nPrice impact: 2.3856500353966914%\n    '}, 'swap_1': {'pool': 'USDC_WETH_0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640', 'exchange': 'Uniswap_V3', 'dangerous': False, 'input_token': 'WETH', 'input_amount': 33.76670726268958, 'input_amount_usd': 28490.449600939042, 'output_token': 'USDC', 'output_amount': 60876.154873132706, 'output_amount_usd': 28488.565305980563, 'price_impact': 0.006613777546071731, 'price': 0.0005546787134151322, 'price_usd': 0.21901580428950115, 'gas_fee': 0.000836437835961, 'description': 'Sell 33.76670726268958 WETH for USDC in Uniswap V3 0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640\n    \nExpected return: 60876.154873132706 USDC\n    \nPrice impact: 0.006613777546071731%\n    '}, 'swap_2': {'pool': 'USDT_USDC_0x86b32fa55943c9af8c12961d8d2ad7040eeb2f2f', 'exchange': 'DODO', 'dangerous': False, 'input_token': 'USDC', 'input_amount': 60876.154873132706, 'input_amount_usd': 60871.42009064679, 'output_token': 'USDT', 'output_amount': 60870.03019, 'output_amount_usd': 60875.59445152921, 'price_impact': 6.341866246595274e-05, 'price': 1.000100619025711, 'price_usd': 1.0001142481646244, 'gas_fee': 0.000836437835961, 'description': 'Sell 60876.154873132706 USDC for USDT in DODO 0x86b32fa55943c9af8c12961d8d2ad7040eeb2f2f\nExpected return: 60870.03019 USDT\nPrice impact: 6.341866246595274e-05%'}, 'amount_in': 100, 'amount_in_usd': 736154.1298631163, 'amount_out': 60870.03019, 'amount_out_usd': 60875.59445152921, 'price': 0.0016428445934371897, 'price_usd': 1.0000914121696973, 'gas_fee': 0.002509313507883, 'path': ['MKR_WETH_0xe8c6c9227491c0a8156a0106a0204d881bb7e531', 'USDC_WETH_0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640', 'USDT_USDC_0x86b32fa55943c9af8c12961d8d2ad7040eeb2f2f'], 'price_impact': 2.392327231605229}
#
# 1
# {'swap_0': {'pool': 'MKR_WETH_0xe8c6c9227491c0a8156a0106a0204d881bb7e531', 'exchange': 'Uniswap_V3', 'dangerous': False, 'input_token': 'MKR', 'input_amount': 100, 'input_amount_usd': 254650.06950639523, 'output_token': 'WETH', 'output_amount': 33.76670726268958, 'output_amount_usd': 248575.01003307817, 'price_impact': 2.3856500353966914, 'price': 2.9614969331195256, 'price_usd': 55516725.062558204, 'gas_fee': 0.000836437835961, 'description': 'Sell 100 MKR for WETH in Uniswap V3 0xe8c6c9227491c0a8156a0106a0204d881bb7e531\n    \nExpected return: 33.76670726268958 WETH\n    \nPrice impact: 2.3856500353966914%\n    '}, 'swap_1': {'pool': 'USDC_WETH_0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640', 'exchange': 'Uniswap_V3', 'dangerous': False, 'input_token': 'WETH', 'input_amount': 33.76670726268958, 'input_amount_usd': 28490.449600939042, 'output_token': 'USDC', 'output_amount': 60876.154873132706, 'output_amount_usd': 28488.565305980563, 'price_impact': 0.006613777546071731, 'price': 0.0005546787134151322, 'price_usd': 0.21901580428950115, 'gas_fee': 0.000836437835961, 'description': 'Sell 33.76670726268958 WETH for USDC in Uniswap V3 0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640\n    \nExpected return: 60876.154873132706 USDC\n    \nPrice impact: 0.006613777546071731%\n    '}, 'swap_2': {'pool': 'USDT_USDC_0x86b32fa55943c9af8c12961d8d2ad7040eeb2f2f', 'exchange': 'DODO', 'dangerous': False, 'input_token': 'USDC', 'input_amount': 60876.154873132706, 'input_amount_usd': 60871.42009064679, 'output_token': 'USDT', 'output_amount': 60870.03019, 'output_amount_usd': 60875.59445152921, 'price_impact': 6.341866246595274e-05, 'price': 1.000100619025711, 'price_usd': 1.0001142481646244, 'gas_fee': 0.000836437835961, 'description': 'Sell 60876.154873132706 USDC for USDT in DODO 0x86b32fa55943c9af8c12961d8d2ad7040eeb2f2f\nExpected return: 60870.03019 USDT\nPrice impact: 6.341866246595274e-05%'}, 'amount_in': 100, 'amount_in_usd': 736154.1298631163, 'amount_out': 60870.03019, 'amount_out_usd': 60875.59445152921, 'price': 0.0016428445934371897, 'price_usd': 1.0000914121696973, 'gas_fee': 0.002509313507883, 'path': ['MKR_WETH_0xe8c6c9227491c0a8156a0106a0204d881bb7e531', 'USDC_WETH_0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640', 'USDT_USDC_0x86b32fa55943c9af8c12961d8d2ad7040eeb2f2f'], 'price_impact': 2.392327231605229}
# {'pool': 'USDC_WETH_0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640', 'exchange': 'Uniswap_V3', 'dangerous': False, 'input_token': 'WETH', 'input_amount': 33.76670726268958, 'input_amount_usd': 28490.449600939042, 'output_token': 'USDC', 'output_amount': 60876.154873132706, 'output_amount_usd': 28488.565305980563, 'price_impact': 0.006613777546071731, 'price': 0.0005546787134151322, 'price_usd': 0.21901580428950115, 'gas_fee': 0.000836437835961, 'description': 'Sell 33.76670726268958 WETH for USDC in Uniswap V3 0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640\n    \nExpected return: 60876.154873132706 USDC\n    \nPrice impact: 0.006613777546071731%\n    '}
# {'pool': 'MKR_WETH_0xe8c6c9227491c0a8156a0106a0204d881bb7e531', 'exchange': 'Uniswap_V3', 'dangerous': False, 'input_token': 'MKR', 'input_amount': 100, 'input_amount_usd': 254650.06950639523, 'output_token': 'WETH', 'output_amount': 33.76670726268958, 'output_amount_usd': 248575.01003307817, 'price_impact': 2.3856500353966914, 'price': 2.9614969331195256, 'price_usd': 55516725.062558204, 'gas_fee': 0.000836437835961, 'description': 'Sell 100 MKR for WETH in Uniswap V3 0xe8c6c9227491c0a8156a0106a0204d881bb7e531\n    \nExpected return: 33.76670726268958 WETH\n    \nPrice impact: 2.3856500353966914%\n    '}
# Calculating price impact for DODO pool: 0x86b32fa55943c9af8c12961d8d2ad7040eeb2f2f

# %%
split
# Out:
# {'pool_graph': {'GP_WETH_0x7e3a3a525d9d265d11d1d1db3cad678746b47d09': ['GP_WETH_0x7e3a3a525d9d265d11d1d1db3cad678746b47d09',
#    'TFT_WETH_0x43c4ea688e53aef3aab172b537b5df6d82f4c4dc',
#    'PUNKS_WETH_0xa80ccc104349d2ee29998c54d6e6488012f8afe0',
#    'DSD_WETH_0x7206ae46531093cf2dbbab4c74ac6135e6535a91',
#    'WETH_CRT_0xe8202cccda10a211cc9a5d6a0157fb47ba2ab157',
#    'KCC_WETH_0xec3f403b6b23462d8d657a6a24aef59d3cd622b9',
#    'tiger_WETH_0x207a0856d0cc2648260d05dc5cb3ba78bd5022f9',
#    'EGOD_WETH_0xfb57be17b95872fcea940ddfe98dcecdf2ac8377',
#    'JZo2o_WETH_0xcee2e90275af0aa1ac425dd8a41e3857f7acc6ba',
#    'USDC_WETH_0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640',
#    'MKR_WETH_0xe8c6c9227491c0a8156a0106a0204d881bb7e531',
#    'MKR_WETH_0x3afdc5e6dfc0b0a507a8e023c9dce2cafc310316',
#    'MKR_WETH_0xc2adda861f89bbb333c90c492cb837741916a225',
#    'MKR_WETH_0xba13afecda9beb75de5c56bbaf696b880a5a50dd',
#    'MKR_WETH_0x886072a44bdd944495eff38ace8ce75c1eacdaf6'],
#   'TFT_WETH_0x43c4ea688e53aef3aab172b537b5df6d82f4c4dc': ['GP_WETH_0x7e3a3a525d9d265d11d1d1db3cad678746b47d09',
#    'TFT_WETH_0x43c4ea688e53aef3aab172b537b5df6d82f4c4dc',
#    'PUNKS_WETH_0xa80ccc104349d2ee29998c54d6e6488012f8afe0',
#    'DSD_WETH_0x7206ae46531093cf2dbbab4c74ac6135e6535a91',
#    'WETH_CRT_0xe8202cccda10a211cc9a5d6a0157fb47ba2ab157',
#    'KCC_WETH_0xec3f403b6b23462d8d657a6a24aef59d3cd622b9',
#    'tiger_WETH_0x207a0856d0cc2648260d05dc5cb3ba78bd5022f9',
#    'EGOD_WETH_0xfb57be17b95872fcea940ddfe98dcecdf2ac8377',
#    'JZo2o_WETH_0xcee2e90275af0aa1ac425dd8a41e3857f7acc6ba',
#    'USDC_WETH_0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640',
#    'MKR_WETH_0xe8c6c9227491c0a8156a0106a0204d881bb7e531',
#    'MKR_WETH_0x3afdc5e6dfc0b0a507a8e023c9dce2cafc310316',
#    'MKR_WETH_0xc2adda861f89bbb333c90c492cb837741916a225',
#    'MKR_WETH_0xba13afecda9beb75de5c56bbaf696b880a5a50dd',
#    'MKR_WETH_0x886072a44bdd944495eff38ace8ce75c1eacdaf6'],
#   'PUNKS_WETH_0xa80ccc104349d2ee29998c54d6e6488012f8afe0': ['GP_WETH_0x7e3a3a525d9d265d11d1d1db3cad678746b47d09',
#    'TFT_WETH_0x43c4ea688e53aef3aab172b537b5df6d82f4c4dc',
#    'PUNKS_WETH_0xa80ccc104349d2ee29998c54d6e6488012f8afe0',
#    'DSD_WETH_0x7206ae46531093cf2dbbab4c74ac6135e6535a91',
#    'WETH_CRT_0xe8202cccda10a211cc9a5d6a0157fb47ba2ab157',
#    'KCC_WETH_0xec3f403b6b23462d8d657a6a24aef59d3cd622b9',
#    'tiger_WETH_0x207a0856d0cc2648260d05dc5cb3ba78bd5022f9',
#    'EGOD_WETH_0xfb57be17b95872fcea940ddfe98dcecdf2ac8377',
#    'JZo2o_WETH_0xcee2e90275af0aa1ac425dd8a41e3857f7acc6ba',
#    'USDC_WETH_0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640',
#    'MKR_WETH_0xe8c6c9227491c0a8156a0106a0204d881bb7e531',
#    'MKR_WETH_0x3afdc5e6dfc0b0a507a8e023c9dce2cafc310316',
#    'MKR_WETH_0xc2adda861f89bbb333c90c492cb837741916a225',
#    'MKR_WETH_0xba13afecda9beb75de5c56bbaf696b880a5a50dd',
#    'MKR_WETH_0x886072a44bdd944495eff38ace8ce75c1eacdaf6'],
#   'DSD_WETH_0x7206ae46531093cf2dbbab4c74ac6135e6535a91': ['GP_WETH_0x7e3a3a525d9d265d11d1d1db3cad678746b47d09',
#    'TFT_WETH_0x43c4ea688e53aef3aab172b537b5df6d82f4c4dc',
#    'PUNKS_WETH_0xa80ccc104349d2ee29998c54d6e6488012f8afe0',
#    'DSD_WETH_0x7206ae46531093cf2dbbab4c74ac6135e6535a91',
#    'WETH_CRT_0xe8202cccda10a211cc9a5d6a0157fb47ba2ab157',
#    'KCC_WETH_0xec3f403b6b23462d8d657a6a24aef59d3cd622b9',
#    'tiger_WETH_0x207a0856d0cc2648260d05dc5cb3ba78bd5022f9',
#    'EGOD_WETH_0xfb57be17b95872fcea940ddfe98dcecdf2ac8377',
#    'JZo2o_WETH_0xcee2e90275af0aa1ac425dd8a41e3857f7acc6ba',
#    'USDC_WETH_0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640',
#    'MKR_WETH_0xe8c6c9227491c0a8156a0106a0204d881bb7e531',
#    'MKR_WETH_0x3afdc5e6dfc0b0a507a8e023c9dce2cafc310316',
#    'MKR_WETH_0xc2adda861f89bbb333c90c492cb837741916a225',
#    'MKR_WETH_0xba13afecda9beb75de5c56bbaf696b880a5a50dd',
#    'MKR_WETH_0x886072a44bdd944495eff38ace8ce75c1eacdaf6'],
#   'WETH_CRT_0xe8202cccda10a211cc9a5d6a0157fb47ba2ab157': ['GP_WETH_0x7e3a3a525d9d265d11d1d1db3cad678746b47d09',
#    'TFT_WETH_0x43c4ea688e53aef3aab172b537b5df6d82f4c4dc',
#    'PUNKS_WETH_0xa80ccc104349d2ee29998c54d6e6488012f8afe0',
#    'DSD_WETH_0x7206ae46531093cf2dbbab4c74ac6135e6535a91',
#    'WETH_CRT_0xe8202cccda10a211cc9a5d6a0157fb47ba2ab157',
#    'KCC_WETH_0xec3f403b6b23462d8d657a6a24aef59d3cd622b9',
#    'tiger_WETH_0x207a0856d0cc2648260d05dc5cb3ba78bd5022f9',
#    'EGOD_WETH_0xfb57be17b95872fcea940ddfe98dcecdf2ac8377',
#    'JZo2o_WETH_0xcee2e90275af0aa1ac425dd8a41e3857f7acc6ba',
#    'USDC_WETH_0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640',
#    'MKR_WETH_0xe8c6c9227491c0a8156a0106a0204d881bb7e531',
#    'MKR_WETH_0x3afdc5e6dfc0b0a507a8e023c9dce2cafc310316',
#    'MKR_WETH_0xc2adda861f89bbb333c90c492cb837741916a225',
#    'MKR_WETH_0xba13afecda9beb75de5c56bbaf696b880a5a50dd',
#    'MKR_WETH_0x886072a44bdd944495eff38ace8ce75c1eacdaf6'],
#   'ease.org_ez-cvxsteCRV_0x277667eb3e34f134adf870be9550e9f323d0dc24': ['ease.org_ez-cvxsteCRV_0x277667eb3e34f134adf870be9550e9f323d0dc24',
#    'ease.org_ez-yvCurve-IronBank_0x8c0411f2ad5470a66cb2e9c64536cfb8dcd54d51',
#    'ease.org_ez-SLP-WBTC-WETH_0x055284a4ca6532ecc219ac06b577d540c686669d'],
#   'rtx_USDT_0xb38e41aadd80eef03e1c86a7c106d6d3a25e3a75': ['rtx_USDT_0xb38e41aadd80eef03e1c86a7c106d6d3a25e3a75',
#    'ULST_USDT_0xb529b1d2f108de61415466b81e2cd2aa1c958ca2',
#    'MKR_USDT_0xb5f8d230523c4bdcd00603ee354921441fde39b4',
#    'MKR_USDT_0x0cbe2f86e2fd90040ebb557b99f83400bf8f3717'],
#   'KCC_WETH_0xec3f403b6b23462d8d657a6a24aef59d3cd622b9': ['GP_WETH_0x7e3a3a525d9d265d11d1d1db3cad678746b47d09',
#    'TFT_WETH_0x43c4ea688e53aef3aab172b537b5df6d82f4c4dc',
#    'PUNKS_WETH_0xa80ccc104349d2ee29998c54d6e6488012f8afe0',
#    'DSD_WETH_0x7206ae46531093cf2dbbab4c74ac6135e6535a91',
#    'WETH_CRT_0xe8202cccda10a211cc9a5d6a0157fb47ba2ab157',
#    'KCC_WETH_0xec3f403b6b23462d8d657a6a24aef59d3cd622b9',
#    'tiger_WETH_0x207a0856d0cc2648260d05dc5cb3ba78bd5022f9',
#    'EGOD_WETH_0xfb57be17b95872fcea940ddfe98dcecdf2ac8377',
#    'JZo2o_WETH_0xcee2e90275af0aa1ac425dd8a41e3857f7acc6ba',
#    'USDC_WETH_0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640',
#    'MKR_WETH_0xe8c6c9227491c0a8156a0106a0204d881bb7e531',
#    'MKR_WETH_0x3afdc5e6dfc0b0a507a8e023c9dce2cafc310316',
#    'MKR_WETH_0xc2adda861f89bbb333c90c492cb837741916a225',
#    'MKR_WETH_0xba13afecda9beb75de5c56bbaf696b880a5a50dd',
#    'MKR_WETH_0x886072a44bdd944495eff38ace8ce75c1eacdaf6'],
#   'ULST_USDT_0xb529b1d2f108de61415466b81e2cd2aa1c958ca2': ['rtx_USDT_0xb38e41aadd80eef03e1c86a7c106d6d3a25e3a75',
#    'ULST_USDT_0xb529b1d2f108de61415466b81e2cd2aa1c958ca2',
#    'MKR_USDT_0xb5f8d230523c4bdcd00603ee354921441fde39b4',
#    'MKR_USDT_0x0cbe2f86e2fd90040ebb557b99f83400bf8f3717'],
#   'tiger_WETH_0x207a0856d0cc2648260d05dc5cb3ba78bd5022f9': ['GP_WETH_0x7e3a3a525d9d265d11d1d1db3cad678746b47d09',
#    'TFT_WETH_0x43c4ea688e53aef3aab172b537b5df6d82f4c4dc',
#    'PUNKS_WETH_0xa80ccc104349d2ee29998c54d6e6488012f8afe0',
#    'DSD_WETH_0x7206ae46531093cf2dbbab4c74ac6135e6535a91',
#    'WETH_CRT_0xe8202cccda10a211cc9a5d6a0157fb47ba2ab157',
#    'KCC_WETH_0xec3f403b6b23462d8d657a6a24aef59d3cd622b9',
#    'tiger_WETH_0x207a0856d0cc2648260d05dc5cb3ba78bd5022f9',
#    'EGOD_WETH_0xfb57be17b95872fcea940ddfe98dcecdf2ac8377',
#    'JZo2o_WETH_0xcee2e90275af0aa1ac425dd8a41e3857f7acc6ba',
#    'USDC_WETH_0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640',
#    'MKR_WETH_0xe8c6c9227491c0a8156a0106a0204d881bb7e531',
#    'MKR_WETH_0x3afdc5e6dfc0b0a507a8e023c9dce2cafc310316',
#    'MKR_WETH_0xc2adda861f89bbb333c90c492cb837741916a225',
#    'MKR_WETH_0xba13afecda9beb75de5c56bbaf696b880a5a50dd',
#    'MKR_WETH_0x886072a44bdd944495eff38ace8ce75c1eacdaf6'],
#   'EGOD_WETH_0xfb57be17b95872fcea940ddfe98dcecdf2ac8377': ['GP_WETH_0x7e3a3a525d9d265d11d1d1db3cad678746b47d09',
#    'TFT_WETH_0x43c4ea688e53aef3aab172b537b5df6d82f4c4dc',
#    'PUNKS_WETH_0xa80ccc104349d2ee29998c54d6e6488012f8afe0',
#    'DSD_WETH_0x7206ae46531093cf2dbbab4c74ac6135e6535a91',
#    'WETH_CRT_0xe8202cccda10a211cc9a5d6a0157fb47ba2ab157',
#    'KCC_WETH_0xec3f403b6b23462d8d657a6a24aef59d3cd622b9',
#    'tiger_WETH_0x207a0856d0cc2648260d05dc5cb3ba78bd5022f9',
#    'EGOD_WETH_0xfb57be17b95872fcea940ddfe98dcecdf2ac8377',
#    'JZo2o_WETH_0xcee2e90275af0aa1ac425dd8a41e3857f7acc6ba',
#    'USDC_WETH_0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640',
#    'MKR_WETH_0xe8c6c9227491c0a8156a0106a0204d881bb7e531',
#    'MKR_WETH_0x3afdc5e6dfc0b0a507a8e023c9dce2cafc310316',
#    'MKR_WETH_0xc2adda861f89bbb333c90c492cb837741916a225',
#    'MKR_WETH_0xba13afecda9beb75de5c56bbaf696b880a5a50dd',
#    'MKR_WETH_0x886072a44bdd944495eff38ace8ce75c1eacdaf6'],
#   'ease.org_ez-yvCurve-IronBank_0x8c0411f2ad5470a66cb2e9c64536cfb8dcd54d51': ['ease.org_ez-cvxsteCRV_0x277667eb3e34f134adf870be9550e9f323d0dc24',
#    'ease.org_ez-yvCurve-IronBank_0x8c0411f2ad5470a66cb2e9c64536cfb8dcd54d51',
#    'ease.org_ez-SLP-WBTC-WETH_0x055284a4ca6532ecc219ac06b577d540c686669d'],
#   'ease.org_ez-SLP-WBTC-WETH_0x055284a4ca6532ecc219ac06b577d540c686669d': ['ease.org_ez-cvxsteCRV_0x277667eb3e34f134adf870be9550e9f323d0dc24',
#    'ease.org_ez-yvCurve-IronBank_0x8c0411f2ad5470a66cb2e9c64536cfb8dcd54d51',
#    'ease.org_ez-SLP-WBTC-WETH_0x055284a4ca6532ecc219ac06b577d540c686669d'],
#   'USDT_USDC_0x86b32fa55943c9af8c12961d8d2ad7040eeb2f2f': ['USDT_USDC_0x86b32fa55943c9af8c12961d8d2ad7040eeb2f2f',
#    'FRAX_USDC_0xdcef968d416a41cdac0ed8702fac8128a64241a2',
#    'USDC_WETH_0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640',
#    'MKR_USDC_0xc486ad2764d55c7dc033487d634195d6e4a6917e',
#    'MKR_USDC_0x936198fcac6d8cdec3815f24ba250041f593f6c3'],
#   'JZo2o_WETH_0xcee2e90275af0aa1ac425dd8a41e3857f7acc6ba': ['GP_WETH_0x7e3a3a525d9d265d11d1d1db3cad678746b47d09',
#    'TFT_WETH_0x43c4ea688e53aef3aab172b537b5df6d82f4c4dc',
#    'PUNKS_WETH_0xa80ccc104349d2ee29998c54d6e6488012f8afe0',
#    'DSD_WETH_0x7206ae46531093cf2dbbab4c74ac6135e6535a91',
#    'WETH_CRT_0xe8202cccda10a211cc9a5d6a0157fb47ba2ab157',
#    'KCC_WETH_0xec3f403b6b23462d8d657a6a24aef59d3cd622b9',
#    'tiger_WETH_0x207a0856d0cc2648260d05dc5cb3ba78bd5022f9',
#    'EGOD_WETH_0xfb57be17b95872fcea940ddfe98dcecdf2ac8377',
#    'JZo2o_WETH_0xcee2e90275af0aa1ac425dd8a41e3857f7acc6ba',
#    'USDC_WETH_0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640',
#    'MKR_WETH_0xe8c6c9227491c0a8156a0106a0204d881bb7e531',
#    'MKR_WETH_0x3afdc5e6dfc0b0a507a8e023c9dce2cafc310316',
#    'MKR_WETH_0xc2adda861f89bbb333c90c492cb837741916a225',
#    'MKR_WETH_0xba13afecda9beb75de5c56bbaf696b880a5a50dd',
#    'MKR_WETH_0x886072a44bdd944495eff38ace8ce75c1eacdaf6'],
#   'FRAX_USDC_0xdcef968d416a41cdac0ed8702fac8128a64241a2': ['USDT_USDC_0x86b32fa55943c9af8c12961d8d2ad7040eeb2f2f',
#    'FRAX_USDC_0xdcef968d416a41cdac0ed8702fac8128a64241a2',
#    'USDC_WETH_0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640',
#    'MKR_USDC_0xc486ad2764d55c7dc033487d634195d6e4a6917e',
#    'MKR_USDC_0x936198fcac6d8cdec3815f24ba250041f593f6c3'],
#   'USDC_WETH_0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640': ['GP_WETH_0x7e3a3a525d9d265d11d1d1db3cad678746b47d09',
#    'TFT_WETH_0x43c4ea688e53aef3aab172b537b5df6d82f4c4dc',
#    'PUNKS_WETH_0xa80ccc104349d2ee29998c54d6e6488012f8afe0',
#    'DSD_WETH_0x7206ae46531093cf2dbbab4c74ac6135e6535a91',
#    'WETH_CRT_0xe8202cccda10a211cc9a5d6a0157fb47ba2ab157',
#    'KCC_WETH_0xec3f403b6b23462d8d657a6a24aef59d3cd622b9',
#    'tiger_WETH_0x207a0856d0cc2648260d05dc5cb3ba78bd5022f9',
#    'EGOD_WETH_0xfb57be17b95872fcea940ddfe98dcecdf2ac8377',
#    'USDT_USDC_0x86b32fa55943c9af8c12961d8d2ad7040eeb2f2f',
#    'JZo2o_WETH_0xcee2e90275af0aa1ac425dd8a41e3857f7acc6ba',
#    'FRAX_USDC_0xdcef968d416a41cdac0ed8702fac8128a64241a2',
#    'USDC_WETH_0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640',
#    'MKR_WETH_0xe8c6c9227491c0a8156a0106a0204d881bb7e531',
#    'MKR_WETH_0x3afdc5e6dfc0b0a507a8e023c9dce2cafc310316',
#    'MKR_WETH_0xc2adda861f89bbb333c90c492cb837741916a225',
#    'MKR_WETH_0xba13afecda9beb75de5c56bbaf696b880a5a50dd',
#    'MKR_USDC_0xc486ad2764d55c7dc033487d634195d6e4a6917e',
#    'MKR_WETH_0x886072a44bdd944495eff38ace8ce75c1eacdaf6',
#    'MKR_USDC_0x936198fcac6d8cdec3815f24ba250041f593f6c3'],
#   'MKR_WETH_0xe8c6c9227491c0a8156a0106a0204d881bb7e531': ['GP_WETH_0x7e3a3a525d9d265d11d1d1db3cad678746b47d09',
#    'TFT_WETH_0x43c4ea688e53aef3aab172b537b5df6d82f4c4dc',
#    'PUNKS_WETH_0xa80ccc104349d2ee29998c54d6e6488012f8afe0',
#    'DSD_WETH_0x7206ae46531093cf2dbbab4c74ac6135e6535a91',
#    'WETH_CRT_0xe8202cccda10a211cc9a5d6a0157fb47ba2ab157',
#    'KCC_WETH_0xec3f403b6b23462d8d657a6a24aef59d3cd622b9',
#    'tiger_WETH_0x207a0856d0cc2648260d05dc5cb3ba78bd5022f9',
#    'EGOD_WETH_0xfb57be17b95872fcea940ddfe98dcecdf2ac8377',
#    'JZo2o_WETH_0xcee2e90275af0aa1ac425dd8a41e3857f7acc6ba',
#    'USDC_WETH_0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640',
#    'MKR_WETH_0xe8c6c9227491c0a8156a0106a0204d881bb7e531',
#    'MKR_WETH_0x3afdc5e6dfc0b0a507a8e023c9dce2cafc310316',
#    'MKR_WETH_0xc2adda861f89bbb333c90c492cb837741916a225',
#    'MKR_WETH_0xba13afecda9beb75de5c56bbaf696b880a5a50dd',
#    'RNG_MKR_0xa82656f9e5405af0d80539f7831c8ef3fe4c5bef',
#    'DAI_MKR_0x2a84e2bd2e961b1557d6e516ca647268b432cba4',
#    'MKR_USDC_0xc486ad2764d55c7dc033487d634195d6e4a6917e',
#    'MKR_USD_0xa16a3cbc92d77b720a851d33a91890c4fbfb0299',
#    'MKR_TRIBE_0xe83bad50c0b3f58ded74ecd67f001337e319075f',
#    'MKR_USDT_0xb5f8d230523c4bdcd00603ee354921441fde39b4',
#    'MKR_WETH_0x886072a44bdd944495eff38ace8ce75c1eacdaf6',
#    'MKR_USDT_0x0cbe2f86e2fd90040ebb557b99f83400bf8f3717',
#    'MKR_USDC_0x936198fcac6d8cdec3815f24ba250041f593f6c3'],
#   'MKR_WETH_0x3afdc5e6dfc0b0a507a8e023c9dce2cafc310316': ['GP_WETH_0x7e3a3a525d9d265d11d1d1db3cad678746b47d09',
#    'TFT_WETH_0x43c4ea688e53aef3aab172b537b5df6d82f4c4dc',
#    'PUNKS_WETH_0xa80ccc104349d2ee29998c54d6e6488012f8afe0',
#    'DSD_WETH_0x7206ae46531093cf2dbbab4c74ac6135e6535a91',
#    'WETH_CRT_0xe8202cccda10a211cc9a5d6a0157fb47ba2ab157',
#    'KCC_WETH_0xec3f403b6b23462d8d657a6a24aef59d3cd622b9',
#    'tiger_WETH_0x207a0856d0cc2648260d05dc5cb3ba78bd5022f9',
#    'EGOD_WETH_0xfb57be17b95872fcea940ddfe98dcecdf2ac8377',
#    'JZo2o_WETH_0xcee2e90275af0aa1ac425dd8a41e3857f7acc6ba',
#    'USDC_WETH_0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640',
#    'MKR_WETH_0xe8c6c9227491c0a8156a0106a0204d881bb7e531',
#    'MKR_WETH_0x3afdc5e6dfc0b0a507a8e023c9dce2cafc310316',
#    'MKR_WETH_0xc2adda861f89bbb333c90c492cb837741916a225',
#    'MKR_WETH_0xba13afecda9beb75de5c56bbaf696b880a5a50dd',
#    'RNG_MKR_0xa82656f9e5405af0d80539f7831c8ef3fe4c5bef',
#    'DAI_MKR_0x2a84e2bd2e961b1557d6e516ca647268b432cba4',
#    'MKR_USDC_0xc486ad2764d55c7dc033487d634195d6e4a6917e',
#    'MKR_USD_0xa16a3cbc92d77b720a851d33a91890c4fbfb0299',
#    'MKR_TRIBE_0xe83bad50c0b3f58ded74ecd67f001337e319075f',
#    'MKR_USDT_0xb5f8d230523c4bdcd00603ee354921441fde39b4',
#    'MKR_WETH_0x886072a44bdd944495eff38ace8ce75c1eacdaf6',
#    'MKR_USDT_0x0cbe2f86e2fd90040ebb557b99f83400bf8f3717',
#    'MKR_USDC_0x936198fcac6d8cdec3815f24ba250041f593f6c3'],
#   'MKR_WETH_0xc2adda861f89bbb333c90c492cb837741916a225': ['GP_WETH_0x7e3a3a525d9d265d11d1d1db3cad678746b47d09',
#    'TFT_WETH_0x43c4ea688e53aef3aab172b537b5df6d82f4c4dc',
#    'PUNKS_WETH_0xa80ccc104349d2ee29998c54d6e6488012f8afe0',
#    'DSD_WETH_0x7206ae46531093cf2dbbab4c74ac6135e6535a91',
#    'WETH_CRT_0xe8202cccda10a211cc9a5d6a0157fb47ba2ab157',
#    'KCC_WETH_0xec3f403b6b23462d8d657a6a24aef59d3cd622b9',
#    'tiger_WETH_0x207a0856d0cc2648260d05dc5cb3ba78bd5022f9',
#    'EGOD_WETH_0xfb57be17b95872fcea940ddfe98dcecdf2ac8377',
#    'JZo2o_WETH_0xcee2e90275af0aa1ac425dd8a41e3857f7acc6ba',
#    'USDC_WETH_0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640',
#    'MKR_WETH_0xe8c6c9227491c0a8156a0106a0204d881bb7e531',
#    'MKR_WETH_0x3afdc5e6dfc0b0a507a8e023c9dce2cafc310316',
#    'MKR_WETH_0xc2adda861f89bbb333c90c492cb837741916a225',
#    'MKR_WETH_0xba13afecda9beb75de5c56bbaf696b880a5a50dd',
#    'RNG_MKR_0xa82656f9e5405af0d80539f7831c8ef3fe4c5bef',
#    'DAI_MKR_0x2a84e2bd2e961b1557d6e516ca647268b432cba4',
#    'MKR_USDC_0xc486ad2764d55c7dc033487d634195d6e4a6917e',
#    'MKR_USD_0xa16a3cbc92d77b720a851d33a91890c4fbfb0299',
#    'MKR_TRIBE_0xe83bad50c0b3f58ded74ecd67f001337e319075f',
#    'MKR_USDT_0xb5f8d230523c4bdcd00603ee354921441fde39b4',
#    'MKR_WETH_0x886072a44bdd944495eff38ace8ce75c1eacdaf6',
#    'MKR_USDT_0x0cbe2f86e2fd90040ebb557b99f83400bf8f3717',
#    'MKR_USDC_0x936198fcac6d8cdec3815f24ba250041f593f6c3'],
#   'MKR_WETH_0xba13afecda9beb75de5c56bbaf696b880a5a50dd': ['GP_WETH_0x7e3a3a525d9d265d11d1d1db3cad678746b47d09',
#    'TFT_WETH_0x43c4ea688e53aef3aab172b537b5df6d82f4c4dc',
#    'PUNKS_WETH_0xa80ccc104349d2ee29998c54d6e6488012f8afe0',
#    'DSD_WETH_0x7206ae46531093cf2dbbab4c74ac6135e6535a91',
#    'WETH_CRT_0xe8202cccda10a211cc9a5d6a0157fb47ba2ab157',
#    'KCC_WETH_0xec3f403b6b23462d8d657a6a24aef59d3cd622b9',
#    'tiger_WETH_0x207a0856d0cc2648260d05dc5cb3ba78bd5022f9',
#    'EGOD_WETH_0xfb57be17b95872fcea940ddfe98dcecdf2ac8377',
#    'JZo2o_WETH_0xcee2e90275af0aa1ac425dd8a41e3857f7acc6ba',
#    'USDC_WETH_0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640',
#    'MKR_WETH_0xe8c6c9227491c0a8156a0106a0204d881bb7e531',
#    'MKR_WETH_0x3afdc5e6dfc0b0a507a8e023c9dce2cafc310316',
#    'MKR_WETH_0xc2adda861f89bbb333c90c492cb837741916a225',
#    'MKR_WETH_0xba13afecda9beb75de5c56bbaf696b880a5a50dd',
#    'RNG_MKR_0xa82656f9e5405af0d80539f7831c8ef3fe4c5bef',
#    'DAI_MKR_0x2a84e2bd2e961b1557d6e516ca647268b432cba4',
#    'MKR_USDC_0xc486ad2764d55c7dc033487d634195d6e4a6917e',
#    'MKR_USD_0xa16a3cbc92d77b720a851d33a91890c4fbfb0299',
#    'MKR_TRIBE_0xe83bad50c0b3f58ded74ecd67f001337e319075f',
#    'MKR_USDT_0xb5f8d230523c4bdcd00603ee354921441fde39b4',
#    'MKR_WETH_0x886072a44bdd944495eff38ace8ce75c1eacdaf6',
#    'MKR_USDT_0x0cbe2f86e2fd90040ebb557b99f83400bf8f3717',
#    'MKR_USDC_0x936198fcac6d8cdec3815f24ba250041f593f6c3'],
#   'RNG_MKR_0xa82656f9e5405af0d80539f7831c8ef3fe4c5bef': ['MKR_WETH_0xe8c6c9227491c0a8156a0106a0204d881bb7e531',
#    'MKR_WETH_0x3afdc5e6dfc0b0a507a8e023c9dce2cafc310316',
#    'MKR_WETH_0xc2adda861f89bbb333c90c492cb837741916a225',
#    'MKR_WETH_0xba13afecda9beb75de5c56bbaf696b880a5a50dd',
#    'RNG_MKR_0xa82656f9e5405af0d80539f7831c8ef3fe4c5bef',
#    'DAI_MKR_0x2a84e2bd2e961b1557d6e516ca647268b432cba4',
#    'MKR_USDC_0xc486ad2764d55c7dc033487d634195d6e4a6917e',
#    'MKR_USD_0xa16a3cbc92d77b720a851d33a91890c4fbfb0299',
#    'MKR_TRIBE_0xe83bad50c0b3f58ded74ecd67f001337e319075f',
#    'MKR_USDT_0xb5f8d230523c4bdcd00603ee354921441fde39b4',
#    'MKR_WETH_0x886072a44bdd944495eff38ace8ce75c1eacdaf6',
#    'MKR_USDT_0x0cbe2f86e2fd90040ebb557b99f83400bf8f3717',
#    'MKR_USDC_0x936198fcac6d8cdec3815f24ba250041f593f6c3'],
#   'DAI_MKR_0x2a84e2bd2e961b1557d6e516ca647268b432cba4': ['MKR_WETH_0xe8c6c9227491c0a8156a0106a0204d881bb7e531',
#    'MKR_WETH_0x3afdc5e6dfc0b0a507a8e023c9dce2cafc310316',
#    'MKR_WETH_0xc2adda861f89bbb333c90c492cb837741916a225',
#    'MKR_WETH_0xba13afecda9beb75de5c56bbaf696b880a5a50dd',
#    'RNG_MKR_0xa82656f9e5405af0d80539f7831c8ef3fe4c5bef',
#    'DAI_MKR_0x2a84e2bd2e961b1557d6e516ca647268b432cba4',
#    'MKR_USDC_0xc486ad2764d55c7dc033487d634195d6e4a6917e',
#    'MKR_USD_0xa16a3cbc92d77b720a851d33a91890c4fbfb0299',
#    'MKR_TRIBE_0xe83bad50c0b3f58ded74ecd67f001337e319075f',
#    'MKR_USDT_0xb5f8d230523c4bdcd00603ee354921441fde39b4',
#    'MKR_WETH_0x886072a44bdd944495eff38ace8ce75c1eacdaf6',
#    'MKR_USDT_0x0cbe2f86e2fd90040ebb557b99f83400bf8f3717',
#    'MKR_USDC_0x936198fcac6d8cdec3815f24ba250041f593f6c3'],
#   'MKR_USDC_0xc486ad2764d55c7dc033487d634195d6e4a6917e': ['USDT_USDC_0x86b32fa55943c9af8c12961d8d2ad7040eeb2f2f',
#    'FRAX_USDC_0xdcef968d416a41cdac0ed8702fac8128a64241a2',
#    'USDC_WETH_0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640',
#    'MKR_WETH_0xe8c6c9227491c0a8156a0106a0204d881bb7e531',
#    'MKR_WETH_0x3afdc5e6dfc0b0a507a8e023c9dce2cafc310316',
#    'MKR_WETH_0xc2adda861f89bbb333c90c492cb837741916a225',
#    'MKR_WETH_0xba13afecda9beb75de5c56bbaf696b880a5a50dd',
#    'RNG_MKR_0xa82656f9e5405af0d80539f7831c8ef3fe4c5bef',
#    'DAI_MKR_0x2a84e2bd2e961b1557d6e516ca647268b432cba4',
#    'MKR_USDC_0xc486ad2764d55c7dc033487d634195d6e4a6917e',
#    'MKR_USD_0xa16a3cbc92d77b720a851d33a91890c4fbfb0299',
#    'MKR_TRIBE_0xe83bad50c0b3f58ded74ecd67f001337e319075f',
#    'MKR_USDT_0xb5f8d230523c4bdcd00603ee354921441fde39b4',
#    'MKR_WETH_0x886072a44bdd944495eff38ace8ce75c1eacdaf6',
#    'MKR_USDT_0x0cbe2f86e2fd90040ebb557b99f83400bf8f3717',
#    'MKR_USDC_0x936198fcac6d8cdec3815f24ba250041f593f6c3'],
#   'MKR_USD_0xa16a3cbc92d77b720a851d33a91890c4fbfb0299': ['MKR_WETH_0xe8c6c9227491c0a8156a0106a0204d881bb7e531',
#    'MKR_WETH_0x3afdc5e6dfc0b0a507a8e023c9dce2cafc310316',
#    'MKR_WETH_0xc2adda861f89bbb333c90c492cb837741916a225',
#    'MKR_WETH_0xba13afecda9beb75de5c56bbaf696b880a5a50dd',
#    'RNG_MKR_0xa82656f9e5405af0d80539f7831c8ef3fe4c5bef',
#    'DAI_MKR_0x2a84e2bd2e961b1557d6e516ca647268b432cba4',
#    'MKR_USDC_0xc486ad2764d55c7dc033487d634195d6e4a6917e',
#    'MKR_USD_0xa16a3cbc92d77b720a851d33a91890c4fbfb0299',
#    'MKR_TRIBE_0xe83bad50c0b3f58ded74ecd67f001337e319075f',
#    'MKR_USDT_0xb5f8d230523c4bdcd00603ee354921441fde39b4',
#    'MKR_WETH_0x886072a44bdd944495eff38ace8ce75c1eacdaf6',
#    'MKR_USDT_0x0cbe2f86e2fd90040ebb557b99f83400bf8f3717',
#    'MKR_USDC_0x936198fcac6d8cdec3815f24ba250041f593f6c3'],
#   'MKR_TRIBE_0xe83bad50c0b3f58ded74ecd67f001337e319075f': ['MKR_WETH_0xe8c6c9227491c0a8156a0106a0204d881bb7e531',
#    'MKR_WETH_0x3afdc5e6dfc0b0a507a8e023c9dce2cafc310316',
#    'MKR_WETH_0xc2adda861f89bbb333c90c492cb837741916a225',
#    'MKR_WETH_0xba13afecda9beb75de5c56bbaf696b880a5a50dd',
#    'RNG_MKR_0xa82656f9e5405af0d80539f7831c8ef3fe4c5bef',
#    'DAI_MKR_0x2a84e2bd2e961b1557d6e516ca647268b432cba4',
#    'MKR_USDC_0xc486ad2764d55c7dc033487d634195d6e4a6917e',
#    'MKR_USD_0xa16a3cbc92d77b720a851d33a91890c4fbfb0299',
#    'MKR_TRIBE_0xe83bad50c0b3f58ded74ecd67f001337e319075f',
#    'MKR_USDT_0xb5f8d230523c4bdcd00603ee354921441fde39b4',
#    'MKR_WETH_0x886072a44bdd944495eff38ace8ce75c1eacdaf6',
#    'MKR_USDT_0x0cbe2f86e2fd90040ebb557b99f83400bf8f3717',
#    'MKR_USDC_0x936198fcac6d8cdec3815f24ba250041f593f6c3'],
#   'MKR_USDT_0xb5f8d230523c4bdcd00603ee354921441fde39b4': ['rtx_USDT_0xb38e41aadd80eef03e1c86a7c106d6d3a25e3a75',
#    'ULST_USDT_0xb529b1d2f108de61415466b81e2cd2aa1c958ca2',
#    'MKR_WETH_0xe8c6c9227491c0a8156a0106a0204d881bb7e531',
#    'MKR_WETH_0x3afdc5e6dfc0b0a507a8e023c9dce2cafc310316',
#    'MKR_WETH_0xc2adda861f89bbb333c90c492cb837741916a225',
#    'MKR_WETH_0xba13afecda9beb75de5c56bbaf696b880a5a50dd',
#    'RNG_MKR_0xa82656f9e5405af0d80539f7831c8ef3fe4c5bef',
#    'DAI_MKR_0x2a84e2bd2e961b1557d6e516ca647268b432cba4',
#    'MKR_USDC_0xc486ad2764d55c7dc033487d634195d6e4a6917e',
#    'MKR_USD_0xa16a3cbc92d77b720a851d33a91890c4fbfb0299',
#    'MKR_TRIBE_0xe83bad50c0b3f58ded74ecd67f001337e319075f',
#    'MKR_USDT_0xb5f8d230523c4bdcd00603ee354921441fde39b4',
#    'MKR_WETH_0x886072a44bdd944495eff38ace8ce75c1eacdaf6',
#    'MKR_USDT_0x0cbe2f86e2fd90040ebb557b99f83400bf8f3717',
#    'MKR_USDC_0x936198fcac6d8cdec3815f24ba250041f593f6c3'],
#   'MKR_WETH_0x886072a44bdd944495eff38ace8ce75c1eacdaf6': ['GP_WETH_0x7e3a3a525d9d265d11d1d1db3cad678746b47d09',
#    'TFT_WETH_0x43c4ea688e53aef3aab172b537b5df6d82f4c4dc',
#    'PUNKS_WETH_0xa80ccc104349d2ee29998c54d6e6488012f8afe0',
#    'DSD_WETH_0x7206ae46531093cf2dbbab4c74ac6135e6535a91',
#    'WETH_CRT_0xe8202cccda10a211cc9a5d6a0157fb47ba2ab157',
#    'KCC_WETH_0xec3f403b6b23462d8d657a6a24aef59d3cd622b9',
#    'tiger_WETH_0x207a0856d0cc2648260d05dc5cb3ba78bd5022f9',
#    'EGOD_WETH_0xfb57be17b95872fcea940ddfe98dcecdf2ac8377',
#    'JZo2o_WETH_0xcee2e90275af0aa1ac425dd8a41e3857f7acc6ba',
#    'USDC_WETH_0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640',
#    'MKR_WETH_0xe8c6c9227491c0a8156a0106a0204d881bb7e531',
#    'MKR_WETH_0x3afdc5e6dfc0b0a507a8e023c9dce2cafc310316',
#    'MKR_WETH_0xc2adda861f89bbb333c90c492cb837741916a225',
#    'MKR_WETH_0xba13afecda9beb75de5c56bbaf696b880a5a50dd',
#    'RNG_MKR_0xa82656f9e5405af0d80539f7831c8ef3fe4c5bef',
#    'DAI_MKR_0x2a84e2bd2e961b1557d6e516ca647268b432cba4',
#    'MKR_USDC_0xc486ad2764d55c7dc033487d634195d6e4a6917e',
#    'MKR_USD_0xa16a3cbc92d77b720a851d33a91890c4fbfb0299',
#    'MKR_TRIBE_0xe83bad50c0b3f58ded74ecd67f001337e319075f',
#    'MKR_USDT_0xb5f8d230523c4bdcd00603ee354921441fde39b4',
#    'MKR_WETH_0x886072a44bdd944495eff38ace8ce75c1eacdaf6',
#    'MKR_USDT_0x0cbe2f86e2fd90040ebb557b99f83400bf8f3717',
#    'MKR_USDC_0x936198fcac6d8cdec3815f24ba250041f593f6c3'],
#   'MKR_USDT_0x0cbe2f86e2fd90040ebb557b99f83400bf8f3717': ['rtx_USDT_0xb38e41aadd80eef03e1c86a7c106d6d3a25e3a75',
#    'ULST_USDT_0xb529b1d2f108de61415466b81e2cd2aa1c958ca2',
#    'MKR_WETH_0xe8c6c9227491c0a8156a0106a0204d881bb7e531',
#    'MKR_WETH_0x3afdc5e6dfc0b0a507a8e023c9dce2cafc310316',
#    'MKR_WETH_0xc2adda861f89bbb333c90c492cb837741916a225',
#    'MKR_WETH_0xba13afecda9beb75de5c56bbaf696b880a5a50dd',
#    'RNG_MKR_0xa82656f9e5405af0d80539f7831c8ef3fe4c5bef',
#    'DAI_MKR_0x2a84e2bd2e961b1557d6e516ca647268b432cba4',
#    'MKR_USDC_0xc486ad2764d55c7dc033487d634195d6e4a6917e',
#    'MKR_USD_0xa16a3cbc92d77b720a851d33a91890c4fbfb0299',
#    'MKR_TRIBE_0xe83bad50c0b3f58ded74ecd67f001337e319075f',
#    'MKR_USDT_0xb5f8d230523c4bdcd00603ee354921441fde39b4',
#    'MKR_WETH_0x886072a44bdd944495eff38ace8ce75c1eacdaf6',
#    'MKR_USDT_0x0cbe2f86e2fd90040ebb557b99f83400bf8f3717',
#    'MKR_USDC_0x936198fcac6d8cdec3815f24ba250041f593f6c3'],
#   'MKR_USDC_0x936198fcac6d8cdec3815f24ba250041f593f6c3': ['USDT_USDC_0x86b32fa55943c9af8c12961d8d2ad7040eeb2f2f',
#    'FRAX_USDC_0xdcef968d416a41cdac0ed8702fac8128a64241a2',
#    'USDC_WETH_0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640',
#    'MKR_WETH_0xe8c6c9227491c0a8156a0106a0204d881bb7e531',
#    'MKR_WETH_0x3afdc5e6dfc0b0a507a8e023c9dce2cafc310316',
#    'MKR_WETH_0xc2adda861f89bbb333c90c492cb837741916a225',
#    'MKR_WETH_0xba13afecda9beb75de5c56bbaf696b880a5a50dd',
#    'RNG_MKR_0xa82656f9e5405af0d80539f7831c8ef3fe4c5bef',
#    'DAI_MKR_0x2a84e2bd2e961b1557d6e516ca647268b432cba4',
#    'MKR_USDC_0xc486ad2764d55c7dc033487d634195d6e4a6917e',
#    'MKR_USD_0xa16a3cbc92d77b720a851d33a91890c4fbfb0299',
#    'MKR_TRIBE_0xe83bad50c0b3f58ded74ecd67f001337e319075f',
#    'MKR_USDT_0xb5f8d230523c4bdcd00603ee354921441fde39b4',
#    'MKR_WETH_0x886072a44bdd944495eff38ace8ce75c1eacdaf6',
#    'MKR_USDT_0x0cbe2f86e2fd90040ebb557b99f83400bf8f3717',
#    'MKR_USDC_0x936198fcac6d8cdec3815f24ba250041f593f6c3']},
#  'path_graph': {'MKR_USDC_0xc486ad2764d55c7dc033487d634195d6e4a6917e': ['MKR_WETH_0xe8c6c9227491c0a8156a0106a0204d881bb7e531',
#    'MKR_WETH_0x3afdc5e6dfc0b0a507a8e023c9dce2cafc310316',
#    'MKR_WETH_0xc2adda861f89bbb333c90c492cb837741916a225',
#    'MKR_WETH_0xba13afecda9beb75de5c56bbaf696b880a5a50dd',
#    'RNG_MKR_0xa82656f9e5405af0d80539f7831c8ef3fe4c5bef',
#    'DAI_MKR_0x2a84e2bd2e961b1557d6e516ca647268b432cba4',
#    'USDT_USDC_0x86b32fa55943c9af8c12961d8d2ad7040eeb2f2f',
#    'FRAX_USDC_0xdcef968d416a41cdac0ed8702fac8128a64241a2',
#    'USDC_WETH_0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640',
#    'MKR_USDC_0x936198fcac6d8cdec3815f24ba250041f593f6c3',
#    'MKR_USD_0xa16a3cbc92d77b720a851d33a91890c4fbfb0299',
#    'MKR_TRIBE_0xe83bad50c0b3f58ded74ecd67f001337e319075f',
#    'MKR_USDT_0xb5f8d230523c4bdcd00603ee354921441fde39b4',
#    'MKR_WETH_0x886072a44bdd944495eff38ace8ce75c1eacdaf6',
#    'MKR_USDT_0x0cbe2f86e2fd90040ebb557b99f83400bf8f3717'],
#   'MKR_USDC_0x936198fcac6d8cdec3815f24ba250041f593f6c3': ['MKR_WETH_0xe8c6c9227491c0a8156a0106a0204d881bb7e531',
#    'MKR_WETH_0x3afdc5e6dfc0b0a507a8e023c9dce2cafc310316',
#    'MKR_WETH_0xc2adda861f89bbb333c90c492cb837741916a225',
#    'MKR_WETH_0xba13afecda9beb75de5c56bbaf696b880a5a50dd',
#    'RNG_MKR_0xa82656f9e5405af0d80539f7831c8ef3fe4c5bef',
#    'DAI_MKR_0x2a84e2bd2e961b1557d6e516ca647268b432cba4',
#    'MKR_USDC_0xc486ad2764d55c7dc033487d634195d6e4a6917e',
#    'MKR_USD_0xa16a3cbc92d77b720a851d33a91890c4fbfb0299',
#    'MKR_TRIBE_0xe83bad50c0b3f58ded74ecd67f001337e319075f',
#    'MKR_USDT_0xb5f8d230523c4bdcd00603ee354921441fde39b4',
#    'MKR_WETH_0x886072a44bdd944495eff38ace8ce75c1eacdaf6',
#    'MKR_USDT_0x0cbe2f86e2fd90040ebb557b99f83400bf8f3717',
#    'USDT_USDC_0x86b32fa55943c9af8c12961d8d2ad7040eeb2f2f',
#    'FRAX_USDC_0xdcef968d416a41cdac0ed8702fac8128a64241a2',
#    'USDC_WETH_0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640'],
#   'MKR_WETH_0xe8c6c9227491c0a8156a0106a0204d881bb7e531': ['USDC_WETH_0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640',
#    'MKR_USDC_0xc486ad2764d55c7dc033487d634195d6e4a6917e',
#    'MKR_USDC_0x936198fcac6d8cdec3815f24ba250041f593f6c3',
#    'RNG_MKR_0xa82656f9e5405af0d80539f7831c8ef3fe4c5bef',
#    'DAI_MKR_0x2a84e2bd2e961b1557d6e516ca647268b432cba4',
#    'MKR_USD_0xa16a3cbc92d77b720a851d33a91890c4fbfb0299',
#    'MKR_TRIBE_0xe83bad50c0b3f58ded74ecd67f001337e319075f',
#    'MKR_USDT_0xb5f8d230523c4bdcd00603ee354921441fde39b4',
#    'MKR_USDT_0x0cbe2f86e2fd90040ebb557b99f83400bf8f3717'],
#   'USDC_WETH_0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640': ['MKR_WETH_0xe8c6c9227491c0a8156a0106a0204d881bb7e531',
#    'MKR_WETH_0x3afdc5e6dfc0b0a507a8e023c9dce2cafc310316',
#    'MKR_WETH_0xc2adda861f89bbb333c90c492cb837741916a225',
#    'MKR_WETH_0xba13afecda9beb75de5c56bbaf696b880a5a50dd',
#    'MKR_USDC_0xc486ad2764d55c7dc033487d634195d6e4a6917e',
#    'MKR_WETH_0x886072a44bdd944495eff38ace8ce75c1eacdaf6',
#    'MKR_USDC_0x936198fcac6d8cdec3815f24ba250041f593f6c3',
#    'USDT_USDC_0x86b32fa55943c9af8c12961d8d2ad7040eeb2f2f',
#    'FRAX_USDC_0xdcef968d416a41cdac0ed8702fac8128a64241a2'],
#   'MKR_WETH_0x3afdc5e6dfc0b0a507a8e023c9dce2cafc310316': ['USDC_WETH_0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640',
#    'MKR_USDC_0xc486ad2764d55c7dc033487d634195d6e4a6917e',
#    'MKR_USDC_0x936198fcac6d8cdec3815f24ba250041f593f6c3'],
#   'MKR_WETH_0xc2adda861f89bbb333c90c492cb837741916a225': ['USDC_WETH_0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640',
#    'MKR_USDC_0xc486ad2764d55c7dc033487d634195d6e4a6917e',
#    'MKR_USDC_0x936198fcac6d8cdec3815f24ba250041f593f6c3'],
#   'MKR_WETH_0xba13afecda9beb75de5c56bbaf696b880a5a50dd': ['USDC_WETH_0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640',
#    'MKR_USDC_0xc486ad2764d55c7dc033487d634195d6e4a6917e',
#    'MKR_USDC_0x936198fcac6d8cdec3815f24ba250041f593f6c3'],
#   'RNG_MKR_0xa82656f9e5405af0d80539f7831c8ef3fe4c5bef': ['MKR_USDC_0xc486ad2764d55c7dc033487d634195d6e4a6917e',
#    'MKR_USDC_0x936198fcac6d8cdec3815f24ba250041f593f6c3',
#    'MKR_WETH_0xe8c6c9227491c0a8156a0106a0204d881bb7e531'],
#   'DAI_MKR_0x2a84e2bd2e961b1557d6e516ca647268b432cba4': ['MKR_USDC_0xc486ad2764d55c7dc033487d634195d6e4a6917e',
#    'MKR_USDC_0x936198fcac6d8cdec3815f24ba250041f593f6c3',
#    'MKR_WETH_0xe8c6c9227491c0a8156a0106a0204d881bb7e531'],
#   'USDT_USDC_0x86b32fa55943c9af8c12961d8d2ad7040eeb2f2f': ['MKR_USDC_0xc486ad2764d55c7dc033487d634195d6e4a6917e',
#    'MKR_USDC_0x936198fcac6d8cdec3815f24ba250041f593f6c3',
#    'USDC_WETH_0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640'],
#   'FRAX_USDC_0xdcef968d416a41cdac0ed8702fac8128a64241a2': ['MKR_USDC_0xc486ad2764d55c7dc033487d634195d6e4a6917e',
#    'MKR_USDC_0x936198fcac6d8cdec3815f24ba250041f593f6c3',
#    'USDC_WETH_0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640'],
#   'MKR_USD_0xa16a3cbc92d77b720a851d33a91890c4fbfb0299': ['MKR_USDC_0xc486ad2764d55c7dc033487d634195d6e4a6917e',
#    'MKR_USDC_0x936198fcac6d8cdec3815f24ba250041f593f6c3',
#    'MKR_WETH_0xe8c6c9227491c0a8156a0106a0204d881bb7e531'],
#   'MKR_TRIBE_0xe83bad50c0b3f58ded74ecd67f001337e319075f': ['MKR_USDC_0xc486ad2764d55c7dc033487d634195d6e4a6917e',
#    'MKR_USDC_0x936198fcac6d8cdec3815f24ba250041f593f6c3',
#    'MKR_WETH_0xe8c6c9227491c0a8156a0106a0204d881bb7e531'],
#   'MKR_USDT_0xb5f8d230523c4bdcd00603ee354921441fde39b4': ['MKR_USDC_0xc486ad2764d55c7dc033487d634195d6e4a6917e',
#    'MKR_USDC_0x936198fcac6d8cdec3815f24ba250041f593f6c3',
#    'MKR_WETH_0xe8c6c9227491c0a8156a0106a0204d881bb7e531'],
#   'MKR_WETH_0x886072a44bdd944495eff38ace8ce75c1eacdaf6': ['USDC_WETH_0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640',
#    'MKR_USDC_0xc486ad2764d55c7dc033487d634195d6e4a6917e',
#    'MKR_USDC_0x936198fcac6d8cdec3815f24ba250041f593f6c3'],
#   'MKR_USDT_0x0cbe2f86e2fd90040ebb557b99f83400bf8f3717': ['MKR_USDC_0xc486ad2764d55c7dc033487d634195d6e4a6917e',
#    'MKR_USDC_0x936198fcac6d8cdec3815f24ba250041f593f6c3',
#    'MKR_WETH_0xe8c6c9227491c0a8156a0106a0204d881bb7e531']},
#  'routes': {'paths': [{'percent': 100.0,
#     'swap_0': {'pool': 'MKR_WETH_0xe8c6c9227491c0a8156a0106a0204d881bb7e531',
#      'exchange': 'Uniswap_V3',
#      'dangerous': False,
#      'input_token': 'MKR',
#      'input_amount': 100,
#      'input_amount_usd': 254650.06950639523,
#      'output_token': 'WETH',
#      'output_amount': 33.76670726268958,
#      'output_amount_usd': 248575.01003307817,
#      'price_impact': 2.3856500353966914,
#      'price': 2.9614969331195256,
#      'price_usd': 55516725.062558204,
#      'gas_fee': 0.000836437835961,
#      'description': 'Sell 100 MKR for WETH in Uniswap V3 0xe8c6c9227491c0a8156a0106a0204d881bb7e531\n    \nExpected return: 33.76670726268958 WETH\n    \nPrice impact: 2.3856500353966914%\n    '},
#     'swap_1': {'pool': 'USDC_WETH_0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640',
#      'exchange': 'Uniswap_V3',
#      'dangerous': False,
#      'input_token': 'WETH',
#      'input_amount': 33.76670726268958,
#      'input_amount_usd': 28490.449600939042,
#      'output_token': 'USDC',
#      'output_amount': 60876.154873132706,
#      'output_amount_usd': 28488.565305980563,
#      'price_impact': 0.006613777546071731,
#      'price': 0.0005546787134151322,
#      'price_usd': 0.21901580428950115,
#      'gas_fee': 0.000836437835961,
#      'description': 'Sell 33.76670726268958 WETH for USDC in Uniswap V3 0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640\n    \nExpected return: 60876.154873132706 USDC\n    \nPrice impact: 0.006613777546071731%\n    ',
#      'percent': 100.0},
#     'swap_2': {'pool': 'USDT_USDC_0x86b32fa55943c9af8c12961d8d2ad7040eeb2f2f',
#      'exchange': 'DODO',
#      'dangerous': False,
#      'input_token': 'USDC',
#      'input_amount': 60876.154873132706,
#      'input_amount_usd': 60871.42009064679,
#      'output_token': 'USDT',
#      'output_amount': 60870.03019,
#      'output_amount_usd': 60875.59445152921,
#      'price_impact': 6.341866246595274e-05,
#      'price': 1.000100619025711,
#      'price_usd': 1.0001142481646244,
#      'gas_fee': 0.000836437835961,
#      'description': 'Sell 60876.154873132706 USDC for USDT in DODO 0x86b32fa55943c9af8c12961d8d2ad7040eeb2f2f\nExpected return: 60870.03019 USDT\nPrice impact: 6.341866246595274e-05%',
#      'percent': 100.0}}],
#   'output_amount': 60870.03019,
#   'gas_fee': 0.000836437835961,
#   'price': 0.0016428445934371897,
#   'price_impact': 6.341866246595274e-05}}
